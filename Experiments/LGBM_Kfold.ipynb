# %%
import os
import gc
import glob
from joblib import Parallel, delayed, dump, load
import pandas as pd
from pandas.core.common import flatten
from collections import OrderedDict
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, QuantileTransformer
from sklearn.cluster import KMeans
import scipy as sc
from sklearn.model_selection import KFold, GroupKFold
import lightgbm as lgb
import warnings
warnings.filterwarnings("ignore")
pd.set_option("max_columns", 300)

# %% [markdown]
# # Parameters

# %%
CONFIG = {
    "root_dir": "../../input/optiver-realized-volatility-prediction/",
    "ckpt_dir": "../../ckpts",
    "kfold_seed": 42,
    "n_splits": 5,
    "n_clusters": 7,
}

PARAMS = {
        "objective": "rmse",
        "boosting_type": "gbdt",
        "max_depth": -1,
        "max_bin":100,
        "min_data_in_leaf":500,
        "learning_rate": 0.05,
        "subsample": 0.72,
        "subsample_freq": 4,
        "feature_fraction": 0.5,
        "lambda_l1": 0.5,
        "lambda_l2": 1.0,
        "categorical_column":[0],
        "seed":2021,
        "feature_fraction_seed": 2021,
        "bagging_seed": 2021,
        "drop_seed": 2021,
        "data_random_seed": 2021,
        "n_jobs":-1,
        "verbose": -1
}

# %% [markdown]
# # Read train test

# %%
def read_train_test():
    
    train = pd.read_csv("../../input/optiver-realized-volatility-prediction/train.csv")
    test = pd.read_csv("../../input/optiver-realized-volatility-prediction/test.csv")
    
    # Create a key to merge with book and trade data
    train["row_id"] = train["stock_id"].astype(str) + "-" + train["time_id"].astype(str)
    test["row_id"] = test["stock_id"].astype(str) + "-" + test["time_id"].astype(str)
    
    print("Our training set has {} rows".format(train.shape[0]))
    
    return train, test

# %% [markdown]
# # Define basic metric function

# %%
def activity_counts(df):
    activity_counts_ = df.groupby(["time_id"])["seconds_in_bucket"].agg("count").reset_index()
    activity_counts_ = activity_counts_.rename(columns={"seconds_in_bucket": "activity_counts"})
    return activity_counts_


def calc_wap(df, pos=1):
    wap = (df["bid_price{}".format(pos)] * df["ask_size{}".format(pos)] + df["ask_price{}".format(pos)] * df[
        "bid_size{}".format(pos)]) / (df["bid_size{}".format(pos)] + df["ask_size{}".format(pos)])
    return wap


def calc_wap2(df, pos=1):
    wap = (df["bid_price{}".format(pos)] * df["bid_size{}".format(pos)] + df["ask_price{}".format(pos)] * df[
        "ask_size{}".format(pos)]) / (df["bid_size{}".format(pos)] + df["ask_size{}".format(pos)])
    return wap


def wp(df):
    wp_ = (df["bid_price1"] * df["bid_size1"] + df["ask_price1"] * df["ask_size1"] + df["bid_price2"] * df[
        "bid_size2"] + df["ask_price2"] * df["ask_size2"]) / (
                  df["bid_size1"] + df["ask_size1"] + df["bid_size2"] + df["ask_size2"])
    return wp_


def maximum_drawdown(series, window=600):
    # window for 10 minutes, use min_periods=1 if you want to allow the expanding window
    roll_max = series.rolling(window, min_periods=1).max()
    second_drawdown = series / roll_max - 1.0
    max_drawdown = second_drawdown.rolling(window, min_periods=1).min()

    return max_drawdown


def log_return(series):
    return np.log(series).diff().fillna(0)


def rolling_log_return(series, rolling=60):
    return np.log(series.rolling(rolling)).diff().fillna(0)


def realized_volatility(series):
    return np.sqrt(np.sum(series ** 2))


def diff(series):
    return series.diff().fillna(0)


def time_diff(series):
    return series.diff().fillna(series)


def order_flow_imbalance(df, pos=1):
    df["bid_price{}_diff".format(pos)] = df.groupby(["time_id"])["bid_price{}".format(pos)].apply(diff)
    df["bid_size{}_diff".format(pos)] = df.groupby(["time_id"])["bid_price{}".format(pos)].apply(diff)
    df["bid_order_flow{}".format(pos)] = df["bid_size{}".format(pos)].copy(deep=True)
    df["bid_order_flow{}".format(pos)].loc[df["bid_price{}_diff".format(pos)] < 0] *= -1
    df["bid_order_flow{}".format(pos)].loc[df["bid_price{}_diff".format(pos)] == 0] = \
        df["bid_size{}_diff".format(pos)].loc[df["bid_price{}_diff".format(pos)] == 0]

    df["ask_price{}_diff".format(pos)] = df.groupby(["time_id"])["ask_price{}".format(pos)].apply(diff)
    df["ask_size{}_diff".format(pos)] = df.groupby(["time_id"])["ask_price{}".format(pos)].apply(diff)
    df["ask_order_flow{}".format(pos)] = df["ask_size{}".format(pos)].copy(deep=True)
    df["ask_order_flow{}".format(pos)].loc[df["ask_price{}_diff".format(pos)] < 0] *= -1
    df["ask_order_flow{}".format(pos)].loc[df["ask_price{}_diff".format(pos)] == 0] = \
        df["ask_size{}_diff".format(pos)].loc[df["ask_price{}_diff".format(pos)] == 0]

    order_flow_imbalance_ = df["bid_order_flow{}".format(pos)] - df["ask_order_flow{}".format(pos)]

    df.drop(["bid_price{}_diff".format(pos), "bid_size{}_diff".format(pos), "bid_order_flow{}".format(pos),
             "ask_price{}_diff".format(pos), "ask_size{}_diff".format(pos), "ask_order_flow{}".format(pos)], axis=1,
            inplace=True)

    return order_flow_imbalance_ + 1e-8


def order_book_slope(df):

    df["mid_point"] = (df["bid_price1"] + df["ask_price1"]) / 2
    best_mid_point_ = df.groupby(["time_id"])["mid_point"].agg("max").reset_index()
    best_mid_point_ = best_mid_point_.rename(columns={"mid_point": "best_mid_point"})
    df = df.merge(best_mid_point_, how="left", on="time_id")

    best_mid_point = df["best_mid_point"].copy()
    df.drop(["mid_point", "best_mid_point"], axis=1, inplace=True)

    def ratio(series):
        ratio_ = series / series.shift()
        return ratio_

    bid_price1_ratio = df.groupby(["time_id"])["bid_price1"].apply(ratio)
    bid_price1_mid_point_ratio = df["bid_price1"] / best_mid_point
    bid_price1_ratio = abs(bid_price1_ratio.fillna(bid_price1_mid_point_ratio) - 1)

    bid_size1_ratio = df.groupby(["time_id"])["bid_size1"].apply(ratio) - 1
    bid_size1_ratio = bid_size1_ratio.fillna(df["bid_size1"])
    df["DE"] = (bid_size1_ratio / bid_price1_ratio).replace([np.inf, -np.inf], np.nan).fillna(0)

    ask_price1_ratio = df.groupby(["time_id"])["ask_price1"].apply(ratio)
    ask_price1_mid_point_ratio = df["ask_price1"] / best_mid_point
    ask_price1_ratio = abs(ask_price1_ratio.fillna(ask_price1_mid_point_ratio) - 1)

    ask_size1_ratio = df.groupby(["time_id"])["ask_size1"].apply(ratio) - 1
    ask_size1_ratio = ask_size1_ratio.fillna(df["ask_size1"])
    df["SE"] = (ask_size1_ratio / ask_price1_ratio).replace([np.inf, -np.inf], np.nan).fillna(0)

    df["order_book_slope"] = (df["DE"] + df["SE"]) / 2
    order_book_slope_ = df.groupby(["time_id"])["order_book_slope"].agg("mean").reset_index()
    df.drop(["order_book_slope", "DE", "SE"], axis=1, inplace=True)

    return order_book_slope_


def ldispersion(df):
    LDispersion = 1 / 2 * (
            df["bid_size1"] / (df["bid_size1"] + df["bid_size2"]) * abs(df["bid_price1"] - df["bid_price2"]) + df[
        "ask_size1"] / (df["ask_size1"] + df["ask_size2"]) * abs(df["ask_price1"] - df["ask_price2"]))
    return LDispersion


def depth_imbalance(df, pos=1):
    depth_imbalance_ = (df["bid_size{}".format(pos)] - df["ask_size{}".format(pos)]) / (
            df["bid_size{}".format(pos)] + df["ask_size{}".format(pos)])

    return depth_imbalance_


def height_imbalance(df, pos=1):
    height_imbalance_ = (df["bid_price{}".format(pos)] - df["ask_price{}".format(pos)]) / (
            df["bid_price{}".format(pos)] + df["ask_price{}".format(pos)])

    return height_imbalance_


def pressure_imbalance(df):
    mid_price = (df["bid_price1"] + df["ask_price1"]) / 2

    weight_buy = mid_price / (mid_price - df["bid_price1"]) + mid_price / (mid_price - df["bid_price2"])
    pressure_buy = df["bid_size1"] * (mid_price / (mid_price - df["bid_price1"])) / weight_buy + df["bid_size2"] * (
            mid_price / (mid_price - df["bid_price2"])) / weight_buy

    weight_sell = mid_price / (df["ask_price1"] - mid_price) + mid_price / (df["ask_price2"] - mid_price)
    pressure_sell = df["ask_size1"] * (mid_price / (df["ask_price1"] - mid_price)) / weight_sell + df["ask_size2"] * (
            mid_price / (df["ask_price2"] - mid_price)) / weight_sell

    pressure_imbalance_ = np.log(pressure_buy) - np.log(pressure_sell)

    return pressure_imbalance_


def relative_spread(df, pos=1):
    relative_spread_ = 2 * (df["ask_price{}".format(pos)] - df["bid_price{}".format(pos)]) / (
            df["ask_price{}".format(pos)] + df["bid_price{}".format(pos)])

    return relative_spread_


def count_unique(series):
    return len(np.unique(series))

# %%
# df = pd.read_parquet("../../input/optiver-realized-volatility-prediction/book_train.parquet/stock_id=0")
# df["order_flow_imbalance1"] = order_flow_imbalance(df, 1)
# df["order_flow_imbalance2"] = order_flow_imbalance(df, 2)

# %% [markdown]
# # Processor

# %%
# Function to fill missing seconds (for each stock id)
def fill_missing_seconds(df):
    
    time_ids = list(OrderedDict.fromkeys(df["time_id"]))
    
    filled_df = pd.DataFrame(index=range(len(time_ids) * 600), columns=df.columns)
    
    all_seconds_in_bucket = list(flatten([range(600) for i in range(len(time_ids))]))
    filled_df["seconds_in_bucket"] = all_seconds_in_bucket
    
    all_time_ids = list(flatten([[time_ids[i]] * 600 for i in range(len(time_ids))]))
    filled_df["time_id"] = all_time_ids
    
    filled_df = pd.merge(filled_df, df, on=["time_id", "seconds_in_bucket"], how="left", suffixes=("_to_move", ""))
    
    to_remove_columns = [column for column in filled_df.columns if "to_move" in column]
    filled_df = filled_df.drop(to_remove_columns, axis=1)
    
    filled_df = filled_df.fillna(method="ffill")
    
    return filled_df

# %%
# Function to preprocess book data (for each stock id)
def book_preprocessor(file_path):
    df = pd.read_parquet(file_path)

    # float 64 to float 32
    float_cols = df.select_dtypes(include=[np.float64]).columns
    df[float_cols] = df[float_cols].astype(np.float32)

    # int 64 to int 32
    int_cols = df.select_dtypes(include=[np.int64]).columns
    df[int_cols] = df[int_cols].astype(np.int32)
    
    # rebase seconds_in_bucket
    df["seconds_in_bucket"] = df["seconds_in_bucket"] - df["seconds_in_bucket"].min()

    # Calculate seconds gap
    df["seconds_gap"] = df.groupby(["time_id"])["seconds_in_bucket"].apply(time_diff)

    # Calculate Wap
    df["wap1"] = calc_wap(df, pos=1)
    df["wap2"] = calc_wap(df, pos=2)

    # Calculate wap balance
    df["wap_balance"] = abs(df["wap1"] - df["wap2"])

    # Calculate log returns
    df["log_return1"] = df.groupby(["time_id"])["wap1"].apply(log_return)
    df["log_return2"] = df.groupby(["time_id"])["wap2"].apply(log_return)

    # Calculate spread
    df["bid_ask_spread1"] = df["ask_price1"] / df["bid_price1"] - 1
    df["bid_ask_spread2"] = df["ask_price2"] / df["bid_price2"] - 1

    # order flow imbalance
    df["order_flow_imbalance1"] = order_flow_imbalance(df, 1)
    df["order_flow_imbalance2"] = order_flow_imbalance(df, 2)

    # order book slope
    order_slope_ = order_book_slope(df)
    df = df.merge(order_slope_, how="left", on="time_id")

    # depth imbalance
    df["depth_imbalance1"] = depth_imbalance(df, pos=1)
    df["depth_imbalance2"] = depth_imbalance(df, pos=2)

    # height imbalance
    df["height_imbalance1"] = height_imbalance(df, pos=1)
    df["height_imbalance2"] = height_imbalance(df, pos=2)

    # pressure imbalance
    df["pressure_imbalance"] = pressure_imbalance(df)

    # total volume
    df["total_volume"] = (df["ask_size1"] + df["ask_size2"]) + (df["bid_size1"] + df["bid_size2"])

    # Dict for aggregations
    create_feature_dict = {
        "wap1": [np.sum, np.std],
        "wap2": [np.sum, np.std],
        "log_return1": [realized_volatility],
        "log_return2": [realized_volatility],
        "wap_balance": [np.sum, np.max, np.min, np.std],
        "bid_ask_spread1": [np.sum, np.max, np.min, np.std],
        "bid_ask_spread2": [np.sum, np.max, np.min, np.std],
        "order_flow_imbalance1": [np.sum, np.max, np.min, np.std],
        "order_flow_imbalance2": [np.sum, np.max, np.min, np.std],
        "order_book_slope": [np.mean, np.max],
        "depth_imbalance1": [np.sum, np.max, np.std],
        "depth_imbalance2": [np.sum, np.max, np.std],
        "height_imbalance1": [np.sum, np.max, np.std],
        "height_imbalance2": [np.sum, np.max, np.std],
        "pressure_imbalance": [np.sum, np.max, np.std],
        "total_volume": [np.sum],
        "seconds_gap": [np.mean]
    }
    create_feature_dict_time = {
        "log_return1": [realized_volatility],
        "log_return2": [realized_volatility],
        "wap_balance": [np.sum, np.max, np.min, np.std],
        "bid_ask_spread1": [np.sum, np.max, np.min, np.std],
        "bid_ask_spread2": [np.sum, np.max, np.min, np.std],
        "order_flow_imbalance1": [np.sum, np.max, np.min, np.std],
        "order_flow_imbalance2": [np.sum, np.max, np.min, np.std],
        "total_volume": [np.sum],
        "seconds_gap": [np.mean]
    }

    # Function to get group stats for different windows (seconds in bucket)
    def get_stats_window(feature_dict, seconds_in_bucket, add_suffix=False):
        # Group by the window
        df_feature_ = df[df["seconds_in_bucket"] >= seconds_in_bucket].groupby(["time_id"]).agg(
            feature_dict).reset_index()
        # Rename columns joining suffix
        df_feature_.columns = ["_".join(col) for col in df_feature_.columns]
        # Add a suffix to differentiate windows
        if add_suffix:
            df_feature_ = df_feature_.add_suffix("_" + str(seconds_in_bucket))
        return df_feature_

    # Get the stats for different windows
    windows = [0, 150, 300, 450]
    add_suffixes = [False, True, True, True]
    df_feature = None

    for window, add_suffix in zip(windows, add_suffixes):
        if df_feature is None:
            df_feature = get_stats_window(feature_dict=create_feature_dict, seconds_in_bucket=window,
                                          add_suffix=add_suffix)
        else:
            new_df_feature = get_stats_window(feature_dict=create_feature_dict_time, seconds_in_bucket=window,
                                              add_suffix=add_suffix)
            df_feature = df_feature.merge(new_df_feature, how="left", left_on="time_id_",
                                          right_on="time_id__{}".format(window))

            # Drop unnecesary time_ids
            df_feature.drop(["time_id__{}".format(window)], axis=1, inplace=True)

    # Create row_id so we can merge
    stock_id = file_path.split("=")[1]
    df_feature["row_id"] = df_feature["time_id_"].apply(lambda x: f"{stock_id}-{x}")
    df_feature.drop(["time_id_"], axis=1, inplace=True)

    return df_feature

# %%
# Function to preprocess trade data (for each stock id)
def trade_preprocessor(file_path):
    df = pd.read_parquet(file_path)

    # float 64 to float 32
    float_cols = df.select_dtypes(include=[np.float64]).columns
    df[float_cols] = df[float_cols].astype(np.float32)

    # int 64 to int 32
    int_cols = df.select_dtypes(include=[np.int64]).columns
    df[int_cols] = df[int_cols].astype(np.int32)
    
    # rebase seconds_in_bucket
    df["seconds_in_bucket"] = df["seconds_in_bucket"] - df["seconds_in_bucket"].min()

    # Calculate seconds gap
    df["seconds_gap"] = df.groupby(["time_id"])["seconds_in_bucket"].apply(time_diff)

    # Calculate log return
    df["price_log_return"] = df.groupby("time_id")["price"].apply(log_return)

    # Calculate volumes
    df["volumes"] = df["price"] * df["size"]

    # Dict for aggregations
    create_feature_dict = {
        "price_log_return": [realized_volatility],
        "volumes": [np.sum, np.max, np.std],
        "order_count": [np.sum],
        "seconds_gap": [np.mean]
    }
    create_feature_dict_time = {
        "price_log_return": [realized_volatility],
        "volumes": [np.sum, np.max, np.std],
        "order_count": [np.sum],
        "seconds_gap": [np.mean]
    }

    # Function to get group stats for different windows (seconds in bucket)
    def get_stats_window(feature_dict, seconds_in_bucket, add_suffix=False):
        # Group by the window
        df_feature_ = df[df["seconds_in_bucket"] >= seconds_in_bucket].groupby(["time_id"]).agg(
            feature_dict).reset_index()
        # Rename columns joining suffix
        df_feature_.columns = ["_".join(col) for col in df_feature_.columns]
        # Add a suffix to differentiate windows
        if add_suffix:
            df_feature_ = df_feature_.add_suffix("_" + str(seconds_in_bucket))
        return df_feature_

    # Get the stats for different windows
    windows = [0, 150, 300, 450]
    add_suffixes = [False, True, True, True]
    df_feature = None

    for window, add_suffix in zip(windows, add_suffixes):
        if df_feature is None:
            df_feature = get_stats_window(feature_dict=create_feature_dict, seconds_in_bucket=window,
                                          add_suffix=add_suffix)
        else:
            new_df_feature = get_stats_window(feature_dict=create_feature_dict_time, seconds_in_bucket=window,
                                              add_suffix=add_suffix)
            df_feature = df_feature.merge(new_df_feature, how="left", left_on="time_id_",
                                          right_on="time_id__{}".format(window))

            # Drop unnecesary time_ids
            df_feature.drop(["time_id__{}".format(window)], axis=1, inplace=True)

    def tendency(price, vol):
        df_diff = np.diff(price)
        val = (df_diff / price[1:]) * 100
        power = np.sum(val * vol[1:])
        return (power)

    lis = []
    for n_time_id in df["time_id"].unique():
        
        df_id = df[df["time_id"] == n_time_id]
        
        tendencyV = tendency(df_id["price"].values, df_id["size"].values)
        energy = np.mean(df_id["price"].values ** 2)

        lis.append(
            {
                "time_id": n_time_id,
                "tendency": tendencyV,
                "energy": energy,
            }
        )

    df_lr = pd.DataFrame(lis)
    df_feature = df_feature.merge(df_lr, how="left", left_on="time_id_", right_on="time_id")

    # Create row_id so we can merge
    df_feature = df_feature.add_prefix("trade_")
    stock_id = file_path.split("=")[1]
    df_feature["row_id"] = df_feature["trade_time_id_"].apply(lambda x: f"{stock_id}-{x}")
    df_feature.drop(["trade_time_id_", "trade_time_id"], axis=1, inplace=True)
    return df_feature

# %%
# Funtion to make preprocessing function in parallel (for each stock id)
def preprocessor(list_stock_ids, is_train = True):
    
    # Parrallel for loop
    def for_joblib(stock_id):
        # Train
        if is_train:
            file_path_book = CONFIG["root_dir"] + "book_train.parquet/stock_id=" + str(stock_id)
            file_path_trade = CONFIG["root_dir"] + "trade_train.parquet/stock_id=" + str(stock_id)
        # Test
        else:
            file_path_book = CONFIG["root_dir"] + "book_test.parquet/stock_id=" + str(stock_id)
            file_path_trade = CONFIG["root_dir"] + "trade_test.parquet/stock_id=" + str(stock_id)
    
        # Preprocess book and trade data and merge them
        df_tmp = pd.merge(book_preprocessor(file_path_book), trade_preprocessor(file_path_trade), on = "row_id", how = "left")
        
        # Return the merge dataframe
        return df_tmp
    
    # Use parallel api to call paralle for loop
    df = Parallel(n_jobs = -1, verbose = 1)(delayed(for_joblib)(stock_id) for stock_id in list_stock_ids)
    
    # Concatenate all the dataframes that return from Parallel
    df = pd.concat(df, ignore_index = True)
    
    return df

# %%
# Read train and test
train, test = read_train_test()

# Get unique stock ids 
train_stock_ids = train["stock_id"].unique()

# Preprocess them using Parallel and our single stock id functions
train_ = preprocessor(train_stock_ids, is_train=True)
train = train.merge(train_, on=["row_id"], how="left")

# Get unique stock ids 
test_stock_ids = test["stock_id"].unique()

# Preprocess them using Parallel and our single stock id functions
test_ = preprocessor(test_stock_ids, is_train=False)
test = test.merge(test_, on=["row_id"], how="left")
# Out:
# Our training set has 428932 rows
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:   50.1s
# [Parallel(n_jobs=-1)]: Done 112 out of 112 | elapsed:  4.7min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.1s finished

# %% [markdown]
# # Log Transformation

# %%
# abs log columns
abs_log_columns = [column for column in train.columns if 
                       "order_flow_imbalance" in column or 
                       "order_book_slope" in column or 
                       "depth_imbalance" in column or 
                       "pressure_imbalance" in column or
                       "total_volume" in column or
                       "seconds_gap" in column or
                       "trade_volumes" in column or
                       "trade_order_count" in column or
                       "trade_seconds_gap" in column or
                       "trade_tendency" in column
                      ]

# apply abs + log1p
train[abs_log_columns] = (train[abs_log_columns].apply(np.abs)).apply(np.log1p)
test[abs_log_columns] = (test[abs_log_columns].apply(np.abs)).apply(np.log1p)

# %% [markdown]
# # Fill inf with nan

# %%
train = train.replace([np.inf, -np.inf], np.nan)
test = test.replace([np.inf, -np.inf], np.nan)

train = train.fillna(train.mean())
test = test.fillna(train.mean())

# %%
test.head()
# Out:
#    stock_id  time_id row_id    wap1_sum  wap1_std    wap2_sum  wap2_std  \
# 0         0        4    0-4    3.001215   0.00017    3.001650  0.000153
# 1         0       32   0-32  389.911957   0.00111  389.912109  0.001149
# 2         0       34   0-34  389.911957   0.00111  389.912109  0.001149
#
#    log_return1_realized_volatility  log_return2_realized_volatility  \
# 0                         0.000294                         0.000252
# 1                         0.004233                         0.005808
# 2                         0.004233                         0.005808
#
#    wap_balance_sum  wap_balance_amax  wap_balance_amin  wap_balance_std  \
# 0         0.000436          0.000169          0.000125         0.000022
# 1         0.092346          0.001088          0.000002         0.000216
# 2         0.092346          0.001088          0.000002         0.000216
#
#    bid_ask_spread1_sum  bid_ask_spread1_amax  bid_ask_spread1_amin  \
# 0             0.001672              0.000590              0.000541
# 1             0.222789              0.001408              0.000244
# 2             0.222789              0.001408              0.000244
#
#    bid_ask_spread1_std  bid_ask_spread2_sum  bid_ask_spread2_amax  \
# 0             0.000028             0.003197              0.001230
# 1             0.000220             0.374884              0.001955
# 2             0.000220             0.374884              0.001955
#
#    bid_ask_spread2_amin  bid_ask_spread2_std  order_flow_imbalance1_sum  \
# 0              0.000984             0.000142                   3.044522
# 1              0.000558             0.000266                   8.249782
# 2              0.000558             0.000266                   8.249782
#
#    order_flow_imbalance1_amax  order_flow_imbalance1_amin  \
# 0                1.000000e-08                    3.044522
# 1                6.491791e+00                    6.687731
# 2                6.491791e+00                    6.687731
#
#    order_flow_imbalance1_std  order_flow_imbalance2_sum  \
# 0                   2.529482                   2.772589
# 1                   5.043370                   8.398653
# 2                   5.043370                   8.398653
#
#    order_flow_imbalance2_amax  order_flow_imbalance2_amin  \
# 0                1.000000e-08                    2.772589
# 1                6.728556e+00                    6.659664
# 2                6.728556e+00                    6.659664
#
#    order_flow_imbalance2_std  order_book_slope_mean  order_book_slope_amax  \
# 0                    2.26802              11.666115              11.666115
# 1                    5.17269               9.808773               9.808773
# 2                    5.17269               9.808773               9.808773
#
#    depth_imbalance1_sum  depth_imbalance1_amax  depth_imbalance1_std  \
# 0              0.574773               0.626456              0.425306
# 1              3.441097               0.683116              0.429954
# 2              3.441097               0.683116              0.429954
#
#    depth_imbalance2_sum  depth_imbalance2_amax  depth_imbalance2_std  \
# 0              1.105571               0.554678              0.062526
# 1              3.396104               0.646258              0.396079
# 2              3.396104               0.646258              0.396079
#
#    height_imbalance1_sum  height_imbalance1_amax  height_imbalance1_std  \
# 0              -0.000836               -0.000270               0.000014
# 1              -0.111319               -0.000122               0.000110
# 2              -0.111319               -0.000122               0.000110
#
#    height_imbalance2_sum  height_imbalance2_amax  height_imbalance2_std  \
# 0              -0.001598               -0.000492               0.000071
# 1              -0.187273               -0.000279               0.000133
# 2              -0.187273               -0.000279               0.000133
#
#    pressure_imbalance_sum  pressure_imbalance_amax  pressure_imbalance_std  \
# 0                1.459000                 1.266650                0.812895
# 1                4.305154                 1.469566                0.754611
# 2                4.305154                 1.469566                0.754611
#
#    total_volume_sum  seconds_gap_mean  log_return1_realized_volatility_150  \
# 0          6.959399          0.980829                             0.003572
# 1         12.579921          0.988809                             0.003572
# 2         12.579921          0.988809                             0.003572
#
#    log_return2_realized_volatility_150  wap_balance_sum_150  \
# 0                             0.004899             0.067365
# 1                             0.004899             0.067365
# 2                             0.004899             0.067365
#
#    wap_balance_amax_150  wap_balance_amin_150  wap_balance_std_150  \
# 0              0.001003              0.000002             0.000208
# 1              0.001003              0.000002             0.000208
# 2              0.001003              0.000002             0.000208
#
#    bid_ask_spread1_sum_150  bid_ask_spread1_amax_150  \
# 0                 0.162831                  0.001307
# 1                 0.162831                  0.001307
# 2                 0.162831                  0.001307
#
#    bid_ask_spread1_amin_150  bid_ask_spread1_std_150  bid_ask_spread2_sum_150  \
# 0                  0.000256                 0.000208                 0.275176
# 1                  0.000256                 0.000208                 0.275176
# 2                  0.000256                 0.000208                 0.275176
#
#    bid_ask_spread2_amax_150  bid_ask_spread2_amin_150  \
# 0                  0.001825                  0.000573
# 1                  0.001825                  0.000573
# 2                  0.001825                  0.000573
#
#    bid_ask_spread2_std_150  order_flow_imbalance1_sum_150  \
# 0                 0.000249                       7.975145
# 1                 0.000249                       7.975145
# 2                 0.000249                       7.975145
#
#    order_flow_imbalance1_amax_150  order_flow_imbalance1_amin_150  \
# 0                        6.403742                         6.57931
# 1                        6.403742                         6.57931
# 2                        6.403742                         6.57931
#
#    order_flow_imbalance1_std_150  order_flow_imbalance2_sum_150  \
# 0                       5.025211                       8.114935
# 1                       5.025211                       8.114935
# 2                       5.025211                       8.114935
#
#    order_flow_imbalance2_amax_150  order_flow_imbalance2_amin_150  \
# 0                        6.634922                        6.537457
# 1                        6.634922                        6.537457
# 2                        6.634922                        6.537457
#
#    order_flow_imbalance2_std_150  total_volume_sum_150  seconds_gap_mean_150  \
# 0                       5.153504             12.278653               0.99878
# 1                       5.153504             12.278653               0.99878
# 2                       5.153504             12.278653               0.99878
#
#    log_return1_realized_volatility_300  log_return2_realized_volatility_300  \
# 0                             0.002854                             0.003917
# 1                             0.002854                             0.003917
# 2                             0.002854                             0.003917
#
#    wap_balance_sum_300  wap_balance_amax_300  wap_balance_amin_300  \
# 0              0.04407              0.000926              0.000004
# 1              0.04407              0.000926              0.000004
# 2              0.04407              0.000926              0.000004
#
#    wap_balance_std_300  bid_ask_spread1_sum_300  bid_ask_spread1_amax_300  \
# 0             0.000203                 0.106615                  0.001217
# 1             0.000203                 0.106615                  0.001217
# 2             0.000203                 0.106615                  0.001217
#
#    bid_ask_spread1_amin_300  bid_ask_spread1_std_300  bid_ask_spread2_sum_300  \
# 0                  0.000275                 0.000198                 0.180765
# 1                  0.000275                 0.000198                 0.180765
# 2                  0.000275                 0.000198                 0.180765
#
#    bid_ask_spread2_amax_300  bid_ask_spread2_amin_300  \
# 0                  0.001716                  0.000596
# 1                  0.001716                  0.000596
# 2                  0.001716                  0.000596
#
#    bid_ask_spread2_std_300  order_flow_imbalance1_sum_300  \
# 0                 0.000237                        7.59801
# 1                 0.000237                        7.59801
# 2                 0.000237                        7.59801
#
#    order_flow_imbalance1_amax_300  order_flow_imbalance1_amin_300  \
# 0                         6.27628                        6.423115
# 1                         6.27628                        6.423115
# 2                         6.27628                        6.423115
#
#    order_flow_imbalance1_std_300  order_flow_imbalance2_sum_300  \
# 0                       4.996555                       7.728419
# 1                       4.996555                       7.728419
# 2                       4.996555                       7.728419
#
#    order_flow_imbalance2_amax_300  order_flow_imbalance2_amin_300  \
# 0                        6.504513                        6.363897
# 1                        6.504513                        6.363897
# 2                        6.504513                        6.363897
#
#    order_flow_imbalance2_std_300  total_volume_sum_300  seconds_gap_mean_300  \
# 0                       5.123776             11.861331              1.003915
# 1                       5.123776             11.861331              1.003915
# 2                       5.123776             11.861331              1.003915
#
#    log_return1_realized_volatility_450  log_return2_realized_volatility_450  \
# 0                             0.001968                             0.002703
# 1                             0.001968                             0.002703
# 2                             0.001968                             0.002703
#
#    wap_balance_sum_450  wap_balance_amax_450  wap_balance_amin_450  \
# 0             0.021708              0.000815              0.000009
# 1             0.021708              0.000815              0.000009
# 2             0.021708              0.000815              0.000009
#
#    wap_balance_std_450  bid_ask_spread1_sum_450  bid_ask_spread1_amax_450  \
# 0             0.000195                 0.052529                  0.001094
# 1             0.000195                 0.052529                  0.001094
# 2             0.000195                 0.052529                  0.001094
#
#    bid_ask_spread1_amin_450  bid_ask_spread1_std_450  bid_ask_spread2_sum_450  \
# 0                  0.000315                 0.000182                 0.089294
# 1                  0.000315                 0.000182                 0.089294
# 2                  0.000315                 0.000182                 0.089294
#
#    bid_ask_spread2_amax_450  bid_ask_spread2_amin_450  \
# 0                  0.001573                  0.000645
# 1                  0.001573                  0.000645
# 2                  0.001573                  0.000645
#
#    bid_ask_spread2_std_450  order_flow_imbalance1_sum_450  \
# 0                 0.000218                       6.977112
# 1                 0.000218                       6.977112
# 2                 0.000218                       6.977112
#
#    order_flow_imbalance1_amax_450  order_flow_imbalance1_amin_450  \
# 0                        6.024545                        6.114072
# 1                        6.024545                        6.114072
# 2                        6.024545                        6.114072
#
#    order_flow_imbalance1_std_450  order_flow_imbalance2_sum_450  \
# 0                       4.935852                       7.093202
# 1                       4.935852                       7.093202
# 2                       4.935852                       7.093202
#
#    order_flow_imbalance2_amax_450  order_flow_imbalance2_amin_450  \
# 0                         6.26785                        6.030946
# 1                         6.26785                        6.030946
# 2                         6.26785                        6.030946
#
#    order_flow_imbalance2_std_450  total_volume_sum_450  seconds_gap_mean_450  \
# 0                       5.062688             11.149419              1.010164
# 1                       5.062688             11.149419              1.010164
# 2                       5.062688             11.149419              1.010164
#
#    trade_price_log_return_realized_volatility  trade_volumes_sum  \
# 0                                    0.000295           5.308323
# 1                                    0.002669           9.422328
# 2                                    0.002669           9.422328
#
#    trade_volumes_amax  trade_volumes_std  trade_order_count_sum  \
# 0            4.615179           4.063208               2.484907
# 1            7.170776           5.515116               5.441907
# 2            7.170776           5.515116               5.441907
#
#    trade_seconds_gap_mean  trade_price_log_return_realized_volatility_150  \
# 0                2.036882                                        0.002287
# 1                2.333319                                        0.002287
# 2                2.333319                                        0.002287
#
#    trade_volumes_sum_150  trade_volumes_amax_150  trade_volumes_std_150  \
# 0               9.103288                7.038704               5.472527
# 1               9.103288                7.038704               5.472527
# 2               9.103288                7.038704               5.472527
#
#    trade_order_count_sum_150  trade_seconds_gap_mean_150  \
# 0                    5.13348                     2.36645
# 1                    5.13348                     2.36645
# 2                    5.13348                     2.36645
#
#    trade_price_log_return_realized_volatility_300  trade_volumes_sum_300  \
# 0                                        0.001829               8.659253
# 1                                        0.001829               8.659253
# 2                                        0.001829               8.659253
#
#    trade_volumes_amax_300  trade_volumes_std_300  trade_order_count_sum_300  \
# 0                6.853339               5.409561                   4.708618
# 1                6.853339               5.409561                   4.708618
# 2                6.853339               5.409561                   4.708618
#
#    trade_seconds_gap_mean_300  trade_price_log_return_realized_volatility_450  \
# 0                    2.377667                                        0.001259
# 1                    2.377667                                        0.001259
# 2                    2.377667                                        0.001259
#
#    trade_volumes_sum_450  trade_volumes_amax_450  trade_volumes_std_450  \
# 0               7.882302                6.505188               5.275949
# 1               7.882302                6.505188               5.275949
# 2               7.882302                6.505188               5.275949
#
#    trade_order_count_sum_450  trade_seconds_gap_mean_450  trade_tendency  \
# 0                     3.9877                    2.390836        1.348423
# 1                     3.9877                    2.390836        4.007234
# 2                     3.9877                    2.390836        4.007234
#
#    trade_energy
# 0      1.000302
# 1      1.000005
# 2      1.000005

# %%
train.head()
# Out:
#    stock_id  time_id    target row_id    wap1_sum  wap1_std    wap2_sum  \
# 0         0        5  0.004136    0-5  303.125061  0.000693  303.105530
# 1         0       11  0.001445   0-11  200.047775  0.000262  200.041168
# 2         0       16  0.002168   0-16  187.913849  0.000864  187.939819
# 3         0       31  0.002195   0-31  119.859779  0.000757  119.835945
# 4         0       62  0.001747   0-62  175.932861  0.000258  175.934250
#
#    wap2_std  log_return1_realized_volatility  log_return2_realized_volatility  \
# 0  0.000781                         0.004499                         0.006999
# 1  0.000272                         0.001204                         0.002476
# 2  0.000862                         0.002369                         0.004801
# 3  0.000656                         0.002574                         0.003637
# 4  0.000317                         0.001894                         0.003257
#
#    wap_balance_sum  wap_balance_amax  wap_balance_amin  wap_balance_std  \
# 0         0.117051          0.001414      1.192093e-07         0.000295
# 1         0.042309          0.000639      4.768372e-07         0.000155
# 2         0.062230          0.001135      4.887581e-06         0.000246
# 3         0.045610          0.001082      1.507998e-05         0.000248
# 4         0.044783          0.000724      3.278255e-06         0.000188
#
#    bid_ask_spread1_sum  bid_ask_spread1_amax  bid_ask_spread1_amin  \
# 0             0.257371              0.001394              0.000361
# 1             0.078856              0.000904              0.000151
# 2             0.136380              0.001150              0.000384
# 3             0.103301              0.001624              0.000324
# 4             0.069916              0.000793              0.000093
#
#    bid_ask_spread1_std  bid_ask_spread2_sum  bid_ask_spread2_amax  \
# 0             0.000212             0.355666              0.001701
# 1             0.000157             0.134233              0.001105
# 2             0.000164             0.210687              0.001917
# 3             0.000280             0.139155              0.002041
# 4             0.000130             0.122743              0.001166
#
#    bid_ask_spread2_amin  bid_ask_spread2_std  order_flow_imbalance1_sum  \
# 0              0.000670             0.000213                   7.596894
# 1              0.000301             0.000200                   7.241366
# 2              0.000575             0.000295                   7.341484
# 3              0.000648             0.000366                   7.674617
# 4              0.000373             0.000185                   5.455321
#
#    order_flow_imbalance1_amax  order_flow_imbalance1_amin  \
# 0                    6.008813                    5.313206
# 1                    4.927254                    5.888878
# 2                    5.327876                    5.720312
# 3                    5.916202                    5.308268
# 4                    5.327876                    5.323010
#
#    order_flow_imbalance1_std  order_flow_imbalance2_sum  \
# 0                   4.238948                   7.479300
# 1                   3.918187                   4.615121
# 2                   4.118797                   7.536897
# 3                   4.399096                   7.211557
# 4                   3.930325                   7.921898
#
#    order_flow_imbalance2_amax  order_flow_imbalance2_amin  \
# 0                    5.993961                    5.993961
# 1                    5.888878                    6.222576
# 2                    5.720312                    5.755742
# 3                    5.323010                    5.303305
# 4                    5.811141                    5.351858
#
#    order_flow_imbalance2_std  order_book_slope_mean  order_book_slope_amax  \
# 0                   4.508810              10.452362              10.452362
# 1                   4.496739               9.850664               9.850664
# 2                   4.373154               9.983159               9.983159
# 3                   4.374984              10.739791              10.739791
# 4                   4.226555              10.122064              10.122064
#
#    depth_imbalance1_sum  depth_imbalance1_amax  depth_imbalance1_std  \
# 0              1.071533               0.688160              0.535878
# 1              3.539013               0.689841              0.531865
# 2              3.036534               0.683197              0.459874
# 3              2.049676               0.685083              0.536172
# 4              2.809757               0.688184              0.515773
#
#    depth_imbalance2_sum  depth_imbalance2_amax  depth_imbalance2_std  \
# 0              3.387522               0.686546              0.538637
# 1              0.011786               0.689830              0.453311
# 2              3.714099               0.687785              0.457857
# 3              3.715545               0.629634              0.421633
# 4              3.502687               0.689819              0.516746
#
#    height_imbalance1_sum  height_imbalance1_amax  height_imbalance1_std  \
# 0              -0.128628               -0.000180               0.000106
# 1              -0.039418               -0.000075               0.000079
# 2              -0.068165               -0.000192               0.000082
# 3              -0.051626               -0.000162               0.000140
# 4              -0.034951               -0.000047               0.000065
#
#    height_imbalance2_sum  height_imbalance2_amax  height_imbalance2_std  \
# 0              -0.177725               -0.000335               0.000107
# 1              -0.067091               -0.000151               0.000100
# 2              -0.105282               -0.000288               0.000147
# 3              -0.069533               -0.000324               0.000183
# 4              -0.061349               -0.000186               0.000093
#
#    pressure_imbalance_sum  pressure_imbalance_amax  pressure_imbalance_std  \
# 0                2.947730                 1.723689                1.142321
# 1                4.699373                 1.648913                0.853735
# 2                1.547597                 1.579019                0.830320
# 3                3.237666                 1.543497                0.783040
# 4                5.022252                 1.719904                0.969896
#
#    total_volume_sum  seconds_gap_mean  log_return1_realized_volatility_150  \
# 0         11.489626          1.086397                             0.003796
# 1         11.318017          1.381282                             0.001058
# 2         11.267984          1.430515                             0.002138
# 3         10.863470          1.770706                             0.002196
# 4         11.008877          1.465463                             0.001609
#
#    log_return2_realized_volatility_150  wap_balance_sum_150  \
# 0                             0.006087             0.091996
# 1                             0.002262             0.035451
# 2                             0.004019             0.044348
# 3                             0.003273             0.029322
# 4                             0.002927             0.032718
#
#    wap_balance_amax_150  wap_balance_amin_150  wap_balance_std_150  \
# 0              0.001184          1.192093e-07             0.000281
# 1              0.000639          4.768372e-07             0.000158
# 2              0.001135          1.829863e-05             0.000276
# 3              0.001082          1.507998e-05             0.000247
# 4              0.000724          3.278255e-06             0.000193
#
#    bid_ask_spread1_sum_150  bid_ask_spread1_amax_150  \
# 0                 0.199148                  0.001392
# 1                 0.061031                  0.000753
# 2                 0.080841                  0.001150
# 3                 0.074589                  0.001624
# 4                 0.053359                  0.000793
#
#    bid_ask_spread1_amin_150  bid_ask_spread1_std_150  bid_ask_spread2_sum_150  \
# 0                  0.000361                 0.000221                 0.276655
# 1                  0.000151                 0.000112                 0.107468
# 2                  0.000384                 0.000164                 0.128644
# 3                  0.000324                 0.000297                 0.097188
# 4                  0.000093                 0.000137                 0.094379
#
#    bid_ask_spread2_amax_150  bid_ask_spread2_amin_150  \
# 0                  0.001649                  0.000670
# 1                  0.001054                  0.000301
# 2                  0.001917                  0.000575
# 3                  0.002041                  0.000648
# 4                  0.001120                  0.000373
#
#    bid_ask_spread2_std_150  order_flow_imbalance1_sum_150  \
# 0                 0.000208                       6.926577
# 1                 0.000164                       7.011214
# 2                 0.000301                       7.016610
# 3                 0.000381                       7.415777
# 4                 0.000197                       5.370638
#
#    order_flow_imbalance1_amax_150  order_flow_imbalance1_amin_150  \
# 0                        6.008813                        5.313206
# 1                        4.927254                        5.888878
# 2                        5.327876                        5.720312
# 3                        5.733341                        5.303305
# 4                        5.293305                        5.323010
#
#    order_flow_imbalance1_std_150  order_flow_imbalance2_sum_150  \
# 0                       4.237138                       6.253829
# 1                       3.913854                       4.276666
# 2                       4.175770                       6.701960
# 3                       4.397948                       6.865891
# 4                       3.813997                       7.643004
#
#    order_flow_imbalance2_amax_150  order_flow_imbalance2_amin_150  \
# 0                        5.583496                        5.713733
# 1                        5.888878                        6.222576
# 2                        5.720312                        5.755742
# 3                        5.303305                        5.303305
# 4                        5.811141                        5.351858
#
#    order_flow_imbalance2_std_150  total_volume_sum_150  seconds_gap_mean_150  \
# 0                       4.410463             11.238028              1.069456
# 1                       4.544952             11.191838              1.298757
# 2                       4.423792             10.839522              1.562998
# 3                       4.332281             10.444765              1.853594
# 4                       4.280457             10.822215              1.447355
#
#    log_return1_realized_volatility_300  log_return2_realized_volatility_300  \
# 0                             0.002953                             0.004864
# 1                             0.000981                             0.002009
# 2                             0.001295                             0.003196
# 3                             0.001776                             0.002713
# 4                             0.001520                             0.002188
#
#    wap_balance_sum_300  wap_balance_amax_300  wap_balance_amin_300  \
# 0             0.051757              0.001034          1.192093e-07
# 1             0.027443              0.000639          2.241135e-05
# 2             0.029308              0.001135          1.829863e-05
# 3             0.017524              0.000840          1.507998e-05
# 4             0.022397              0.000660          3.278255e-06
#
#    wap_balance_std_300  bid_ask_spread1_sum_300  bid_ask_spread1_amax_300  \
# 0             0.000273                 0.114324                  0.001340
# 1             0.000158                 0.040599                  0.000753
# 2             0.000294                 0.046882                  0.000958
# 3             0.000228                 0.044180                  0.001624
# 4             0.000188                 0.037829                  0.000793
#
#    bid_ask_spread1_amin_300  bid_ask_spread1_std_300  bid_ask_spread2_sum_300  \
# 0                  0.000361                 0.000237                 0.167702
# 1                  0.000151                 0.000121                 0.073630
# 2                  0.000384                 0.000162                 0.073504
# 3                  0.000324                 0.000278                 0.057634
# 4                  0.000187                 0.000140                 0.065599
#
#    bid_ask_spread2_amax_300  bid_ask_spread2_amin_300  \
# 0                  0.001599                  0.000670
# 1                  0.001054                  0.000301
# 2                  0.001825                  0.000575
# 3                  0.001716                  0.000648
# 4                  0.001120                  0.000420
#
#    bid_ask_spread2_std_300  order_flow_imbalance1_sum_300  \
# 0                 0.000214                       4.219508
# 1                 0.000175                       6.753438
# 2                 0.000321                       5.953243
# 3                 0.000316                       6.452049
# 4                 0.000174                       6.122493
#
#    order_flow_imbalance1_amax_300  order_flow_imbalance1_amin_300  \
# 0                        5.303305                        5.313206
# 1                        4.927254                        5.888878
# 2                        5.327876                        5.720312
# 3                        5.707110                        5.303305
# 4                        5.293305                        4.653960
#
#    order_flow_imbalance1_std_300  order_flow_imbalance2_sum_300  \
# 0                       4.074132                       4.553877
# 1                       4.064560                       6.030685
# 2                       4.320648                       7.414573
# 3                       4.431513                       6.282267
# 4                       3.872014                       7.043160
#
#    order_flow_imbalance2_amax_300  order_flow_imbalance2_amin_300  \
# 0                        5.442418                        5.713733
# 1                        5.888878                        6.222576
# 2                        5.720312                        4.804021
# 3                        5.303305                        5.231109
# 4                        5.811141                        5.323010
#
#    order_flow_imbalance2_std_300  total_volume_sum_300  seconds_gap_mean_300  \
# 0                       4.439823             10.621230              1.138571
# 1                       4.717200             10.928112              1.280934
# 2                       4.323410             10.340354              1.685854
# 3                       4.185490             10.006225              1.861591
# 4                       4.208909             10.498912              1.440953
#
#    log_return1_realized_volatility_450  log_return2_realized_volatility_450  \
# 0                             0.001722                             0.004114
# 1                             0.000918                             0.001883
# 2                             0.001158                             0.002972
# 3                             0.000993                             0.001424
# 4                             0.001378                             0.000966
#
#    wap_balance_sum_450  wap_balance_amax_450  wap_balance_amin_450  \
# 0             0.024869              0.001034          1.192093e-07
# 1             0.014525              0.000639          2.264977e-05
# 2             0.016056              0.001135          1.829863e-05
# 3             0.006441              0.000840          5.167723e-05
# 4             0.013088              0.000660          2.205372e-05
#
#    wap_balance_std_450  bid_ask_spread1_sum_450  bid_ask_spread1_amax_450  \
# 0             0.000277                 0.053258                  0.001135
# 1             0.000175                 0.018817                  0.000753
# 2             0.000282                 0.026617                  0.000815
# 3             0.000253                 0.019057                  0.001160
# 4             0.000203                 0.018705                  0.000793
#
#    bid_ask_spread1_amin_450  bid_ask_spread1_std_450  bid_ask_spread2_sum_450  \
# 0                  0.000361                 0.000181                 0.082251
# 1                  0.000201                 0.000144                 0.039147
# 2                  0.000384                 0.000105                 0.043991
# 3                  0.000973                 0.000074                 0.022027
# 4                  0.000233                 0.000138                 0.030654
#
#    bid_ask_spread2_amax_450  bid_ask_spread2_amin_450  \
# 0                  0.001599                  0.000670
# 1                  0.001054                  0.000502
# 2                  0.001825                  0.000575
# 3                  0.001392                  0.001113
# 4                  0.001027                  0.000606
#
#    bid_ask_spread2_std_450  order_flow_imbalance1_sum_450  \
# 0                 0.000250                       5.541264
# 1                 0.000206                       6.230481
# 2                 0.000314                       5.686975
# 3                 0.000113                       5.446737
# 4                 0.000130                       4.430817
#
#    order_flow_imbalance1_amax_450  order_flow_imbalance1_amin_450  \
# 0                        4.844187                        5.313206
# 1                        4.672829                        5.888878
# 2                        5.327876                        5.720312
# 3                        5.707110                        5.303305
# 4                        5.293305                        4.624973
#
#    order_flow_imbalance1_std_450  order_flow_imbalance2_sum_450  \
# 0                       4.007175                       5.389072
# 1                       4.281894                       7.061334
# 2                       4.506372                       7.398174
# 3                       4.696914                       3.610918
# 4                       3.877972                       2.197225
#
#    order_flow_imbalance2_amax_450  order_flow_imbalance2_amin_450  \
# 0                        5.442418                        5.713733
# 1                        5.888878                        5.937536
# 2                        5.720312                        4.615121
# 3                        4.844187                        5.231109
# 4                        5.273000                        5.323010
#
#    order_flow_imbalance2_std_450  total_volume_sum_450  seconds_gap_mean_450  \
# 0                       4.551579              9.795290              1.137079
# 1                       4.678709             10.093777              1.358123
# 2                       4.459797              9.913537              1.543687
# 3                       4.290236              9.182044              2.153053
# 4                       4.161524              9.554710              1.581267
#
#    trade_price_log_return_realized_volatility  trade_volumes_sum  \
# 0                                    0.002006           8.068133
# 1                                    0.000901           7.162672
# 2                                    0.001961           7.677682
# 3                                    0.001561           7.581008
# 4                                    0.000871           7.490672
#
#    trade_volumes_amax  trade_volumes_std  trade_order_count_sum  \
# 0            6.217788           4.785643               4.709530
# 1            5.638426           4.367356               4.060443
# 2            5.969841           4.740140               4.234107
# 3            6.109442           4.980851               4.094345
# 4            5.834239           4.777958               4.499810
#
#    trade_seconds_gap_mean  trade_price_log_return_realized_volatility_150  \
# 0                2.748872                                        0.001701
# 1                2.990720                                        0.000813
# 2                3.215671                                        0.001621
# 3                3.673766                                        0.001401
# 4                3.315838                                        0.000550
#
#    trade_volumes_sum_150  trade_volumes_amax_150  trade_volumes_std_150  \
# 0               7.638966                6.217788               4.817781
# 1               7.068471                5.638426               4.440647
# 2               7.605216                5.969841               4.802625
# 3               7.396166                6.109442               5.082127
# 4               7.359025                5.834239               4.853212
#
#    trade_order_count_sum_150  trade_seconds_gap_mean_150  \
# 0                   4.304065                    2.747271
# 1                   3.912023                    2.953173
# 2                   4.094345                    3.212858
# 3                   3.931826                    3.754838
# 4                   4.290459                    3.362976
#
#    trade_price_log_return_realized_volatility_300  trade_volumes_sum_300  \
# 0                                        0.001308               7.373764
# 1                                        0.000587               6.803867
# 2                                        0.001137               7.079922
# 3                                        0.001089               7.349132
# 4                                        0.000453               7.106132
#
#    trade_volumes_amax_300  trade_volumes_std_300  trade_order_count_sum_300  \
# 0                6.217788               4.964091                   4.007333
# 1                5.638426               4.516671                   3.610918
# 2                5.969841               4.878626                   3.663562
# 3                6.109442               5.126717                   3.850148
# 4                5.834239               4.948701                   4.007333
#
#    trade_seconds_gap_mean_300  trade_price_log_return_realized_volatility_450  \
# 0                    2.748491                                        0.001060
# 1                    2.904165                                        0.000501
# 2                    3.258096                                        0.001048
# 3                    3.561677                                        0.000802
# 4                    3.338677                                        0.000360
#
#    trade_volumes_sum_450  trade_volumes_amax_450  trade_volumes_std_450  \
# 0               6.953078                6.217788               4.936772
# 1               6.720592                5.638426               4.684676
# 2               6.988346                5.969841               4.971290
# 3               6.242149                6.109442               5.494478
# 4               3.783891                3.555104               2.808331
#
#    trade_order_count_sum_450  trade_seconds_gap_mean_450  trade_tendency  \
# 0                   3.637586                    2.460809        3.008903
# 1                   3.135494                    2.821379        1.916797
# 2                   3.526361                    3.049799        3.929138
# 3                   2.484907                    4.143135        2.770287
# 4                   2.708050                    3.663562        2.445418
#
#    trade_energy
# 0      1.007459
# 1      1.000413
# 2      0.998409
# 3      0.998041
# 4      0.999237

# %%
# Process agg by kmeans
def get_kmeans_idx(n_clusters=7):
    train_p = pd.read_csv("../../input/optiver-realized-volatility-prediction/train.csv")
    train_p = train_p.pivot(index="time_id", columns="stock_id", values="target")

    corr = train_p.corr()

    ids = corr.index

    kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(corr.values)

    kmeans_clusters = []
    for n in range(n_clusters):
        kmeans_clusters.append ([(x - 1) for x in ((ids + 1)*(kmeans.labels_ == n)) if x > 0])
        
    return kmeans_clusters
    

def agg_stat_features_by_clusters(df, n_clusters=7, function=np.nanmean, post_fix="_cluster_mean"):

    kmeans_clusters = get_kmeans_idx(n_clusters=n_clusters)

    clusters = []
    agg_columns = [
        "time_id",
        "stock_id",
        "log_return1_realized_volatility",
        "log_return2_realized_volatility",
        "order_flow_imbalance1_sum",
        "order_flow_imbalance2_sum",
        "order_book_slope_mean",
        "depth_imbalance1_std",
        "depth_imbalance2_std",
        "height_imbalance1_sum",
        "height_imbalance2_sum",
        "pressure_imbalance_std",
        "total_volume_sum",
        "seconds_gap_mean",
        "trade_price_log_return_realized_volatility",
        "trade_volumes_sum",
        "trade_order_count_sum",
        "trade_seconds_gap_mean",
        "trade_tendency",
        "trade_energy"
    ]

    for cluster_idx, ind in enumerate(kmeans_clusters):
        cluster_df = df.loc[df["stock_id"].isin(ind), agg_columns].groupby(["time_id"]).agg(function)
        cluster_df.loc[:, "stock_id"] = str(cluster_idx) + post_fix
        clusters.append(cluster_df)

    clusters_df = pd.concat(clusters).reset_index()
    # multi index (column, c1)
    clusters_df = clusters_df.pivot(index="time_id", columns="stock_id")
    # ravel multi index to list of tuple [(target, c1), ...]
    clusters_df.columns = ["_".join(x) for x in clusters_df.columns.ravel()]
    clusters_df.reset_index(inplace=True)

    postfixes = [
        "0" + post_fix,
        "1" + post_fix,
        "3" + post_fix,
        "4" + post_fix,
        "6" + post_fix,
    ]
    merge_columns = []
    for column in agg_columns:
        if column == "time_id":
            merge_columns.append(column)
        elif column == "stock_id":
            continue
        else:
            for postfix in postfixes:
                merge_columns.append(column + "_" + postfix)
                
    not_exist_columns = [column for column in merge_columns if column not in clusters_df.columns]
    clusters_df[not_exist_columns] = 0
    
    df = pd.merge(df, clusters_df[merge_columns], how="left", on="time_id")

    return df


# Function to get group stats for the time_id
def agg_stat_features_by_market(df, operations=None, operations_names=None):
    def percentile(n):
        def percentile_(x):
            return np.percentile(x, n)

        percentile_.__name__ = "percentile_%s" % n
        return percentile_

    if operations is None:
        operations = [
            np.nanmean,
        ]
        operations_names = [
            "mean",
        ]

    # Get realized volatility columns
    vol_cols = [
        "log_return1_realized_volatility",
        "log_return1_realized_volatility_150",
        "log_return1_realized_volatility_300",
        "log_return1_realized_volatility_450",
    ]

    # Group by the stock id
    df_stock_id = df.groupby(["stock_id"])[vol_cols].agg(operations).reset_index()
    # Rename columns joining suffix
    df_stock_id.columns = ["_".join(col) for col in df_stock_id.columns]
    df_stock_id = df_stock_id.add_suffix("_" + "stock")

    # Group by the stock id
    df_time_id = df.groupby(["time_id"])[vol_cols].agg(operations).reset_index()
    # Rename columns joining suffix
    df_time_id.columns = ["_".join(col) for col in df_time_id.columns]
    df_time_id = df_time_id.add_suffix("_" + "time")

    # Merge with original dataframe
    df = df.merge(df_stock_id, how="left", left_on=["stock_id"], right_on=["stock_id__stock"])
    df.drop("stock_id__stock", axis=1, inplace=True)

    df = df.merge(df_time_id, how="left", left_on=["time_id"], right_on=["time_id__time"])
    df.drop("time_id__time", axis=1, inplace=True)

    return df

# %%
test.head()
# Out:
#    stock_id  time_id row_id    wap1_sum  wap1_std    wap2_sum  wap2_std  \
# 0         0        4    0-4    3.001215   0.00017    3.001650  0.000153
# 1         0       32   0-32  389.911957   0.00111  389.912109  0.001149
# 2         0       34   0-34  389.911957   0.00111  389.912109  0.001149
#
#    log_return1_realized_volatility  log_return2_realized_volatility  \
# 0                         0.000294                         0.000252
# 1                         0.004233                         0.005808
# 2                         0.004233                         0.005808
#
#    wap_balance_sum  wap_balance_amax  wap_balance_amin  wap_balance_std  \
# 0         0.000436          0.000169          0.000125         0.000022
# 1         0.092346          0.001088          0.000002         0.000216
# 2         0.092346          0.001088          0.000002         0.000216
#
#    bid_ask_spread1_sum  bid_ask_spread1_amax  bid_ask_spread1_amin  \
# 0             0.001672              0.000590              0.000541
# 1             0.222789              0.001408              0.000244
# 2             0.222789              0.001408              0.000244
#
#    bid_ask_spread1_std  bid_ask_spread2_sum  bid_ask_spread2_amax  \
# 0             0.000028             0.003197              0.001230
# 1             0.000220             0.374884              0.001955
# 2             0.000220             0.374884              0.001955
#
#    bid_ask_spread2_amin  bid_ask_spread2_std  order_flow_imbalance1_sum  \
# 0              0.000984             0.000142                   3.044522
# 1              0.000558             0.000266                   8.249782
# 2              0.000558             0.000266                   8.249782
#
#    order_flow_imbalance1_amax  order_flow_imbalance1_amin  \
# 0                1.000000e-08                    3.044522
# 1                6.491791e+00                    6.687731
# 2                6.491791e+00                    6.687731
#
#    order_flow_imbalance1_std  order_flow_imbalance2_sum  \
# 0                   2.529482                   2.772589
# 1                   5.043370                   8.398653
# 2                   5.043370                   8.398653
#
#    order_flow_imbalance2_amax  order_flow_imbalance2_amin  \
# 0                1.000000e-08                    2.772589
# 1                6.728556e+00                    6.659664
# 2                6.728556e+00                    6.659664
#
#    order_flow_imbalance2_std  order_book_slope_mean  order_book_slope_amax  \
# 0                    2.26802              11.666115              11.666115
# 1                    5.17269               9.808773               9.808773
# 2                    5.17269               9.808773               9.808773
#
#    depth_imbalance1_sum  depth_imbalance1_amax  depth_imbalance1_std  \
# 0              0.574773               0.626456              0.425306
# 1              3.441097               0.683116              0.429954
# 2              3.441097               0.683116              0.429954
#
#    depth_imbalance2_sum  depth_imbalance2_amax  depth_imbalance2_std  \
# 0              1.105571               0.554678              0.062526
# 1              3.396104               0.646258              0.396079
# 2              3.396104               0.646258              0.396079
#
#    height_imbalance1_sum  height_imbalance1_amax  height_imbalance1_std  \
# 0              -0.000836               -0.000270               0.000014
# 1              -0.111319               -0.000122               0.000110
# 2              -0.111319               -0.000122               0.000110
#
#    height_imbalance2_sum  height_imbalance2_amax  height_imbalance2_std  \
# 0              -0.001598               -0.000492               0.000071
# 1              -0.187273               -0.000279               0.000133
# 2              -0.187273               -0.000279               0.000133
#
#    pressure_imbalance_sum  pressure_imbalance_amax  pressure_imbalance_std  \
# 0                1.459000                 1.266650                0.812895
# 1                4.305154                 1.469566                0.754611
# 2                4.305154                 1.469566                0.754611
#
#    total_volume_sum  seconds_gap_mean  log_return1_realized_volatility_150  \
# 0          6.959399          0.980829                             0.003572
# 1         12.579921          0.988809                             0.003572
# 2         12.579921          0.988809                             0.003572
#
#    log_return2_realized_volatility_150  wap_balance_sum_150  \
# 0                             0.004899             0.067365
# 1                             0.004899             0.067365
# 2                             0.004899             0.067365
#
#    wap_balance_amax_150  wap_balance_amin_150  wap_balance_std_150  \
# 0              0.001003              0.000002             0.000208
# 1              0.001003              0.000002             0.000208
# 2              0.001003              0.000002             0.000208
#
#    bid_ask_spread1_sum_150  bid_ask_spread1_amax_150  \
# 0                 0.162831                  0.001307
# 1                 0.162831                  0.001307
# 2                 0.162831                  0.001307
#
#    bid_ask_spread1_amin_150  bid_ask_spread1_std_150  bid_ask_spread2_sum_150  \
# 0                  0.000256                 0.000208                 0.275176
# 1                  0.000256                 0.000208                 0.275176
# 2                  0.000256                 0.000208                 0.275176
#
#    bid_ask_spread2_amax_150  bid_ask_spread2_amin_150  \
# 0                  0.001825                  0.000573
# 1                  0.001825                  0.000573
# 2                  0.001825                  0.000573
#
#    bid_ask_spread2_std_150  order_flow_imbalance1_sum_150  \
# 0                 0.000249                       7.975145
# 1                 0.000249                       7.975145
# 2                 0.000249                       7.975145
#
#    order_flow_imbalance1_amax_150  order_flow_imbalance1_amin_150  \
# 0                        6.403742                         6.57931
# 1                        6.403742                         6.57931
# 2                        6.403742                         6.57931
#
#    order_flow_imbalance1_std_150  order_flow_imbalance2_sum_150  \
# 0                       5.025211                       8.114935
# 1                       5.025211                       8.114935
# 2                       5.025211                       8.114935
#
#    order_flow_imbalance2_amax_150  order_flow_imbalance2_amin_150  \
# 0                        6.634922                        6.537457
# 1                        6.634922                        6.537457
# 2                        6.634922                        6.537457
#
#    order_flow_imbalance2_std_150  total_volume_sum_150  seconds_gap_mean_150  \
# 0                       5.153504             12.278653               0.99878
# 1                       5.153504             12.278653               0.99878
# 2                       5.153504             12.278653               0.99878
#
#    log_return1_realized_volatility_300  log_return2_realized_volatility_300  \
# 0                             0.002854                             0.003917
# 1                             0.002854                             0.003917
# 2                             0.002854                             0.003917
#
#    wap_balance_sum_300  wap_balance_amax_300  wap_balance_amin_300  \
# 0              0.04407              0.000926              0.000004
# 1              0.04407              0.000926              0.000004
# 2              0.04407              0.000926              0.000004
#
#    wap_balance_std_300  bid_ask_spread1_sum_300  bid_ask_spread1_amax_300  \
# 0             0.000203                 0.106615                  0.001217
# 1             0.000203                 0.106615                  0.001217
# 2             0.000203                 0.106615                  0.001217
#
#    bid_ask_spread1_amin_300  bid_ask_spread1_std_300  bid_ask_spread2_sum_300  \
# 0                  0.000275                 0.000198                 0.180765
# 1                  0.000275                 0.000198                 0.180765
# 2                  0.000275                 0.000198                 0.180765
#
#    bid_ask_spread2_amax_300  bid_ask_spread2_amin_300  \
# 0                  0.001716                  0.000596
# 1                  0.001716                  0.000596
# 2                  0.001716                  0.000596
#
#    bid_ask_spread2_std_300  order_flow_imbalance1_sum_300  \
# 0                 0.000237                        7.59801
# 1                 0.000237                        7.59801
# 2                 0.000237                        7.59801
#
#    order_flow_imbalance1_amax_300  order_flow_imbalance1_amin_300  \
# 0                         6.27628                        6.423115
# 1                         6.27628                        6.423115
# 2                         6.27628                        6.423115
#
#    order_flow_imbalance1_std_300  order_flow_imbalance2_sum_300  \
# 0                       4.996555                       7.728419
# 1                       4.996555                       7.728419
# 2                       4.996555                       7.728419
#
#    order_flow_imbalance2_amax_300  order_flow_imbalance2_amin_300  \
# 0                        6.504513                        6.363897
# 1                        6.504513                        6.363897
# 2                        6.504513                        6.363897
#
#    order_flow_imbalance2_std_300  total_volume_sum_300  seconds_gap_mean_300  \
# 0                       5.123776             11.861331              1.003915
# 1                       5.123776             11.861331              1.003915
# 2                       5.123776             11.861331              1.003915
#
#    log_return1_realized_volatility_450  log_return2_realized_volatility_450  \
# 0                             0.001968                             0.002703
# 1                             0.001968                             0.002703
# 2                             0.001968                             0.002703
#
#    wap_balance_sum_450  wap_balance_amax_450  wap_balance_amin_450  \
# 0             0.021708              0.000815              0.000009
# 1             0.021708              0.000815              0.000009
# 2             0.021708              0.000815              0.000009
#
#    wap_balance_std_450  bid_ask_spread1_sum_450  bid_ask_spread1_amax_450  \
# 0             0.000195                 0.052529                  0.001094
# 1             0.000195                 0.052529                  0.001094
# 2             0.000195                 0.052529                  0.001094
#
#    bid_ask_spread1_amin_450  bid_ask_spread1_std_450  bid_ask_spread2_sum_450  \
# 0                  0.000315                 0.000182                 0.089294
# 1                  0.000315                 0.000182                 0.089294
# 2                  0.000315                 0.000182                 0.089294
#
#    bid_ask_spread2_amax_450  bid_ask_spread2_amin_450  \
# 0                  0.001573                  0.000645
# 1                  0.001573                  0.000645
# 2                  0.001573                  0.000645
#
#    bid_ask_spread2_std_450  order_flow_imbalance1_sum_450  \
# 0                 0.000218                       6.977112
# 1                 0.000218                       6.977112
# 2                 0.000218                       6.977112
#
#    order_flow_imbalance1_amax_450  order_flow_imbalance1_amin_450  \
# 0                        6.024545                        6.114072
# 1                        6.024545                        6.114072
# 2                        6.024545                        6.114072
#
#    order_flow_imbalance1_std_450  order_flow_imbalance2_sum_450  \
# 0                       4.935852                       7.093202
# 1                       4.935852                       7.093202
# 2                       4.935852                       7.093202
#
#    order_flow_imbalance2_amax_450  order_flow_imbalance2_amin_450  \
# 0                         6.26785                        6.030946
# 1                         6.26785                        6.030946
# 2                         6.26785                        6.030946
#
#    order_flow_imbalance2_std_450  total_volume_sum_450  seconds_gap_mean_450  \
# 0                       5.062688             11.149419              1.010164
# 1                       5.062688             11.149419              1.010164
# 2                       5.062688             11.149419              1.010164
#
#    trade_price_log_return_realized_volatility  trade_volumes_sum  \
# 0                                    0.000295           5.308323
# 1                                    0.002669           9.422328
# 2                                    0.002669           9.422328
#
#    trade_volumes_amax  trade_volumes_std  trade_order_count_sum  \
# 0            4.615179           4.063208               2.484907
# 1            7.170776           5.515116               5.441907
# 2            7.170776           5.515116               5.441907
#
#    trade_seconds_gap_mean  trade_price_log_return_realized_volatility_150  \
# 0                2.036882                                        0.002287
# 1                2.333319                                        0.002287
# 2                2.333319                                        0.002287
#
#    trade_volumes_sum_150  trade_volumes_amax_150  trade_volumes_std_150  \
# 0               9.103288                7.038704               5.472527
# 1               9.103288                7.038704               5.472527
# 2               9.103288                7.038704               5.472527
#
#    trade_order_count_sum_150  trade_seconds_gap_mean_150  \
# 0                    5.13348                     2.36645
# 1                    5.13348                     2.36645
# 2                    5.13348                     2.36645
#
#    trade_price_log_return_realized_volatility_300  trade_volumes_sum_300  \
# 0                                        0.001829               8.659253
# 1                                        0.001829               8.659253
# 2                                        0.001829               8.659253
#
#    trade_volumes_amax_300  trade_volumes_std_300  trade_order_count_sum_300  \
# 0                6.853339               5.409561                   4.708618
# 1                6.853339               5.409561                   4.708618
# 2                6.853339               5.409561                   4.708618
#
#    trade_seconds_gap_mean_300  trade_price_log_return_realized_volatility_450  \
# 0                    2.377667                                        0.001259
# 1                    2.377667                                        0.001259
# 2                    2.377667                                        0.001259
#
#    trade_volumes_sum_450  trade_volumes_amax_450  trade_volumes_std_450  \
# 0               7.882302                6.505188               5.275949
# 1               7.882302                6.505188               5.275949
# 2               7.882302                6.505188               5.275949
#
#    trade_order_count_sum_450  trade_seconds_gap_mean_450  trade_tendency  \
# 0                     3.9877                    2.390836        1.348423
# 1                     3.9877                    2.390836        4.007234
# 2                     3.9877                    2.390836        4.007234
#
#    trade_energy
# 0      1.000302
# 1      1.000005
# 2      1.000005

# %%
train.head()
# Out:
#    stock_id  time_id    target row_id    wap1_sum  wap1_std    wap2_sum  \
# 0         0        5  0.004136    0-5  303.125061  0.000693  303.105530
# 1         0       11  0.001445   0-11  200.047775  0.000262  200.041168
# 2         0       16  0.002168   0-16  187.913849  0.000864  187.939819
# 3         0       31  0.002195   0-31  119.859779  0.000757  119.835945
# 4         0       62  0.001747   0-62  175.932861  0.000258  175.934250
#
#    wap2_std  log_return1_realized_volatility  log_return2_realized_volatility  \
# 0  0.000781                         0.004499                         0.006999
# 1  0.000272                         0.001204                         0.002476
# 2  0.000862                         0.002369                         0.004801
# 3  0.000656                         0.002574                         0.003637
# 4  0.000317                         0.001894                         0.003257
#
#    wap_balance_sum  wap_balance_amax  wap_balance_amin  wap_balance_std  \
# 0         0.117051          0.001414      1.192093e-07         0.000295
# 1         0.042309          0.000639      4.768372e-07         0.000155
# 2         0.062230          0.001135      4.887581e-06         0.000246
# 3         0.045610          0.001082      1.507998e-05         0.000248
# 4         0.044783          0.000724      3.278255e-06         0.000188
#
#    bid_ask_spread1_sum  bid_ask_spread1_amax  bid_ask_spread1_amin  \
# 0             0.257371              0.001394              0.000361
# 1             0.078856              0.000904              0.000151
# 2             0.136380              0.001150              0.000384
# 3             0.103301              0.001624              0.000324
# 4             0.069916              0.000793              0.000093
#
#    bid_ask_spread1_std  bid_ask_spread2_sum  bid_ask_spread2_amax  \
# 0             0.000212             0.355666              0.001701
# 1             0.000157             0.134233              0.001105
# 2             0.000164             0.210687              0.001917
# 3             0.000280             0.139155              0.002041
# 4             0.000130             0.122743              0.001166
#
#    bid_ask_spread2_amin  bid_ask_spread2_std  order_flow_imbalance1_sum  \
# 0              0.000670             0.000213                   7.596894
# 1              0.000301             0.000200                   7.241366
# 2              0.000575             0.000295                   7.341484
# 3              0.000648             0.000366                   7.674617
# 4              0.000373             0.000185                   5.455321
#
#    order_flow_imbalance1_amax  order_flow_imbalance1_amin  \
# 0                    6.008813                    5.313206
# 1                    4.927254                    5.888878
# 2                    5.327876                    5.720312
# 3                    5.916202                    5.308268
# 4                    5.327876                    5.323010
#
#    order_flow_imbalance1_std  order_flow_imbalance2_sum  \
# 0                   4.238948                   7.479300
# 1                   3.918187                   4.615121
# 2                   4.118797                   7.536897
# 3                   4.399096                   7.211557
# 4                   3.930325                   7.921898
#
#    order_flow_imbalance2_amax  order_flow_imbalance2_amin  \
# 0                    5.993961                    5.993961
# 1                    5.888878                    6.222576
# 2                    5.720312                    5.755742
# 3                    5.323010                    5.303305
# 4                    5.811141                    5.351858
#
#    order_flow_imbalance2_std  order_book_slope_mean  order_book_slope_amax  \
# 0                   4.508810              10.452362              10.452362
# 1                   4.496739               9.850664               9.850664
# 2                   4.373154               9.983159               9.983159
# 3                   4.374984              10.739791              10.739791
# 4                   4.226555              10.122064              10.122064
#
#    depth_imbalance1_sum  depth_imbalance1_amax  depth_imbalance1_std  \
# 0              1.071533               0.688160              0.535878
# 1              3.539013               0.689841              0.531865
# 2              3.036534               0.683197              0.459874
# 3              2.049676               0.685083              0.536172
# 4              2.809757               0.688184              0.515773
#
#    depth_imbalance2_sum  depth_imbalance2_amax  depth_imbalance2_std  \
# 0              3.387522               0.686546              0.538637
# 1              0.011786               0.689830              0.453311
# 2              3.714099               0.687785              0.457857
# 3              3.715545               0.629634              0.421633
# 4              3.502687               0.689819              0.516746
#
#    height_imbalance1_sum  height_imbalance1_amax  height_imbalance1_std  \
# 0              -0.128628               -0.000180               0.000106
# 1              -0.039418               -0.000075               0.000079
# 2              -0.068165               -0.000192               0.000082
# 3              -0.051626               -0.000162               0.000140
# 4              -0.034951               -0.000047               0.000065
#
#    height_imbalance2_sum  height_imbalance2_amax  height_imbalance2_std  \
# 0              -0.177725               -0.000335               0.000107
# 1              -0.067091               -0.000151               0.000100
# 2              -0.105282               -0.000288               0.000147
# 3              -0.069533               -0.000324               0.000183
# 4              -0.061349               -0.000186               0.000093
#
#    pressure_imbalance_sum  pressure_imbalance_amax  pressure_imbalance_std  \
# 0                2.947730                 1.723689                1.142321
# 1                4.699373                 1.648913                0.853735
# 2                1.547597                 1.579019                0.830320
# 3                3.237666                 1.543497                0.783040
# 4                5.022252                 1.719904                0.969896
#
#    total_volume_sum  seconds_gap_mean  log_return1_realized_volatility_150  \
# 0         11.489626          1.086397                             0.003796
# 1         11.318017          1.381282                             0.001058
# 2         11.267984          1.430515                             0.002138
# 3         10.863470          1.770706                             0.002196
# 4         11.008877          1.465463                             0.001609
#
#    log_return2_realized_volatility_150  wap_balance_sum_150  \
# 0                             0.006087             0.091996
# 1                             0.002262             0.035451
# 2                             0.004019             0.044348
# 3                             0.003273             0.029322
# 4                             0.002927             0.032718
#
#    wap_balance_amax_150  wap_balance_amin_150  wap_balance_std_150  \
# 0              0.001184          1.192093e-07             0.000281
# 1              0.000639          4.768372e-07             0.000158
# 2              0.001135          1.829863e-05             0.000276
# 3              0.001082          1.507998e-05             0.000247
# 4              0.000724          3.278255e-06             0.000193
#
#    bid_ask_spread1_sum_150  bid_ask_spread1_amax_150  \
# 0                 0.199148                  0.001392
# 1                 0.061031                  0.000753
# 2                 0.080841                  0.001150
# 3                 0.074589                  0.001624
# 4                 0.053359                  0.000793
#
#    bid_ask_spread1_amin_150  bid_ask_spread1_std_150  bid_ask_spread2_sum_150  \
# 0                  0.000361                 0.000221                 0.276655
# 1                  0.000151                 0.000112                 0.107468
# 2                  0.000384                 0.000164                 0.128644
# 3                  0.000324                 0.000297                 0.097188
# 4                  0.000093                 0.000137                 0.094379
#
#    bid_ask_spread2_amax_150  bid_ask_spread2_amin_150  \
# 0                  0.001649                  0.000670
# 1                  0.001054                  0.000301
# 2                  0.001917                  0.000575
# 3                  0.002041                  0.000648
# 4                  0.001120                  0.000373
#
#    bid_ask_spread2_std_150  order_flow_imbalance1_sum_150  \
# 0                 0.000208                       6.926577
# 1                 0.000164                       7.011214
# 2                 0.000301                       7.016610
# 3                 0.000381                       7.415777
# 4                 0.000197                       5.370638
#
#    order_flow_imbalance1_amax_150  order_flow_imbalance1_amin_150  \
# 0                        6.008813                        5.313206
# 1                        4.927254                        5.888878
# 2                        5.327876                        5.720312
# 3                        5.733341                        5.303305
# 4                        5.293305                        5.323010
#
#    order_flow_imbalance1_std_150  order_flow_imbalance2_sum_150  \
# 0                       4.237138                       6.253829
# 1                       3.913854                       4.276666
# 2                       4.175770                       6.701960
# 3                       4.397948                       6.865891
# 4                       3.813997                       7.643004
#
#    order_flow_imbalance2_amax_150  order_flow_imbalance2_amin_150  \
# 0                        5.583496                        5.713733
# 1                        5.888878                        6.222576
# 2                        5.720312                        5.755742
# 3                        5.303305                        5.303305
# 4                        5.811141                        5.351858
#
#    order_flow_imbalance2_std_150  total_volume_sum_150  seconds_gap_mean_150  \
# 0                       4.410463             11.238028              1.069456
# 1                       4.544952             11.191838              1.298757
# 2                       4.423792             10.839522              1.562998
# 3                       4.332281             10.444765              1.853594
# 4                       4.280457             10.822215              1.447355
#
#    log_return1_realized_volatility_300  log_return2_realized_volatility_300  \
# 0                             0.002953                             0.004864
# 1                             0.000981                             0.002009
# 2                             0.001295                             0.003196
# 3                             0.001776                             0.002713
# 4                             0.001520                             0.002188
#
#    wap_balance_sum_300  wap_balance_amax_300  wap_balance_amin_300  \
# 0             0.051757              0.001034          1.192093e-07
# 1             0.027443              0.000639          2.241135e-05
# 2             0.029308              0.001135          1.829863e-05
# 3             0.017524              0.000840          1.507998e-05
# 4             0.022397              0.000660          3.278255e-06
#
#    wap_balance_std_300  bid_ask_spread1_sum_300  bid_ask_spread1_amax_300  \
# 0             0.000273                 0.114324                  0.001340
# 1             0.000158                 0.040599                  0.000753
# 2             0.000294                 0.046882                  0.000958
# 3             0.000228                 0.044180                  0.001624
# 4             0.000188                 0.037829                  0.000793
#
#    bid_ask_spread1_amin_300  bid_ask_spread1_std_300  bid_ask_spread2_sum_300  \
# 0                  0.000361                 0.000237                 0.167702
# 1                  0.000151                 0.000121                 0.073630
# 2                  0.000384                 0.000162                 0.073504
# 3                  0.000324                 0.000278                 0.057634
# 4                  0.000187                 0.000140                 0.065599
#
#    bid_ask_spread2_amax_300  bid_ask_spread2_amin_300  \
# 0                  0.001599                  0.000670
# 1                  0.001054                  0.000301
# 2                  0.001825                  0.000575
# 3                  0.001716                  0.000648
# 4                  0.001120                  0.000420
#
#    bid_ask_spread2_std_300  order_flow_imbalance1_sum_300  \
# 0                 0.000214                       4.219508
# 1                 0.000175                       6.753438
# 2                 0.000321                       5.953243
# 3                 0.000316                       6.452049
# 4                 0.000174                       6.122493
#
#    order_flow_imbalance1_amax_300  order_flow_imbalance1_amin_300  \
# 0                        5.303305                        5.313206
# 1                        4.927254                        5.888878
# 2                        5.327876                        5.720312
# 3                        5.707110                        5.303305
# 4                        5.293305                        4.653960
#
#    order_flow_imbalance1_std_300  order_flow_imbalance2_sum_300  \
# 0                       4.074132                       4.553877
# 1                       4.064560                       6.030685
# 2                       4.320648                       7.414573
# 3                       4.431513                       6.282267
# 4                       3.872014                       7.043160
#
#    order_flow_imbalance2_amax_300  order_flow_imbalance2_amin_300  \
# 0                        5.442418                        5.713733
# 1                        5.888878                        6.222576
# 2                        5.720312                        4.804021
# 3                        5.303305                        5.231109
# 4                        5.811141                        5.323010
#
#    order_flow_imbalance2_std_300  total_volume_sum_300  seconds_gap_mean_300  \
# 0                       4.439823             10.621230              1.138571
# 1                       4.717200             10.928112              1.280934
# 2                       4.323410             10.340354              1.685854
# 3                       4.185490             10.006225              1.861591
# 4                       4.208909             10.498912              1.440953
#
#    log_return1_realized_volatility_450  log_return2_realized_volatility_450  \
# 0                             0.001722                             0.004114
# 1                             0.000918                             0.001883
# 2                             0.001158                             0.002972
# 3                             0.000993                             0.001424
# 4                             0.001378                             0.000966
#
#    wap_balance_sum_450  wap_balance_amax_450  wap_balance_amin_450  \
# 0             0.024869              0.001034          1.192093e-07
# 1             0.014525              0.000639          2.264977e-05
# 2             0.016056              0.001135          1.829863e-05
# 3             0.006441              0.000840          5.167723e-05
# 4             0.013088              0.000660          2.205372e-05
#
#    wap_balance_std_450  bid_ask_spread1_sum_450  bid_ask_spread1_amax_450  \
# 0             0.000277                 0.053258                  0.001135
# 1             0.000175                 0.018817                  0.000753
# 2             0.000282                 0.026617                  0.000815
# 3             0.000253                 0.019057                  0.001160
# 4             0.000203                 0.018705                  0.000793
#
#    bid_ask_spread1_amin_450  bid_ask_spread1_std_450  bid_ask_spread2_sum_450  \
# 0                  0.000361                 0.000181                 0.082251
# 1                  0.000201                 0.000144                 0.039147
# 2                  0.000384                 0.000105                 0.043991
# 3                  0.000973                 0.000074                 0.022027
# 4                  0.000233                 0.000138                 0.030654
#
#    bid_ask_spread2_amax_450  bid_ask_spread2_amin_450  \
# 0                  0.001599                  0.000670
# 1                  0.001054                  0.000502
# 2                  0.001825                  0.000575
# 3                  0.001392                  0.001113
# 4                  0.001027                  0.000606
#
#    bid_ask_spread2_std_450  order_flow_imbalance1_sum_450  \
# 0                 0.000250                       5.541264
# 1                 0.000206                       6.230481
# 2                 0.000314                       5.686975
# 3                 0.000113                       5.446737
# 4                 0.000130                       4.430817
#
#    order_flow_imbalance1_amax_450  order_flow_imbalance1_amin_450  \
# 0                        4.844187                        5.313206
# 1                        4.672829                        5.888878
# 2                        5.327876                        5.720312
# 3                        5.707110                        5.303305
# 4                        5.293305                        4.624973
#
#    order_flow_imbalance1_std_450  order_flow_imbalance2_sum_450  \
# 0                       4.007175                       5.389072
# 1                       4.281894                       7.061334
# 2                       4.506372                       7.398174
# 3                       4.696914                       3.610918
# 4                       3.877972                       2.197225
#
#    order_flow_imbalance2_amax_450  order_flow_imbalance2_amin_450  \
# 0                        5.442418                        5.713733
# 1                        5.888878                        5.937536
# 2                        5.720312                        4.615121
# 3                        4.844187                        5.231109
# 4                        5.273000                        5.323010
#
#    order_flow_imbalance2_std_450  total_volume_sum_450  seconds_gap_mean_450  \
# 0                       4.551579              9.795290              1.137079
# 1                       4.678709             10.093777              1.358123
# 2                       4.459797              9.913537              1.543687
# 3                       4.290236              9.182044              2.153053
# 4                       4.161524              9.554710              1.581267
#
#    trade_price_log_return_realized_volatility  trade_volumes_sum  \
# 0                                    0.002006           8.068133
# 1                                    0.000901           7.162672
# 2                                    0.001961           7.677682
# 3                                    0.001561           7.581008
# 4                                    0.000871           7.490672
#
#    trade_volumes_amax  trade_volumes_std  trade_order_count_sum  \
# 0            6.217788           4.785643               4.709530
# 1            5.638426           4.367356               4.060443
# 2            5.969841           4.740140               4.234107
# 3            6.109442           4.980851               4.094345
# 4            5.834239           4.777958               4.499810
#
#    trade_seconds_gap_mean  trade_price_log_return_realized_volatility_150  \
# 0                2.748872                                        0.001701
# 1                2.990720                                        0.000813
# 2                3.215671                                        0.001621
# 3                3.673766                                        0.001401
# 4                3.315838                                        0.000550
#
#    trade_volumes_sum_150  trade_volumes_amax_150  trade_volumes_std_150  \
# 0               7.638966                6.217788               4.817781
# 1               7.068471                5.638426               4.440647
# 2               7.605216                5.969841               4.802625
# 3               7.396166                6.109442               5.082127
# 4               7.359025                5.834239               4.853212
#
#    trade_order_count_sum_150  trade_seconds_gap_mean_150  \
# 0                   4.304065                    2.747271
# 1                   3.912023                    2.953173
# 2                   4.094345                    3.212858
# 3                   3.931826                    3.754838
# 4                   4.290459                    3.362976
#
#    trade_price_log_return_realized_volatility_300  trade_volumes_sum_300  \
# 0                                        0.001308               7.373764
# 1                                        0.000587               6.803867
# 2                                        0.001137               7.079922
# 3                                        0.001089               7.349132
# 4                                        0.000453               7.106132
#
#    trade_volumes_amax_300  trade_volumes_std_300  trade_order_count_sum_300  \
# 0                6.217788               4.964091                   4.007333
# 1                5.638426               4.516671                   3.610918
# 2                5.969841               4.878626                   3.663562
# 3                6.109442               5.126717                   3.850148
# 4                5.834239               4.948701                   4.007333
#
#    trade_seconds_gap_mean_300  trade_price_log_return_realized_volatility_450  \
# 0                    2.748491                                        0.001060
# 1                    2.904165                                        0.000501
# 2                    3.258096                                        0.001048
# 3                    3.561677                                        0.000802
# 4                    3.338677                                        0.000360
#
#    trade_volumes_sum_450  trade_volumes_amax_450  trade_volumes_std_450  \
# 0               6.953078                6.217788               4.936772
# 1               6.720592                5.638426               4.684676
# 2               6.988346                5.969841               4.971290
# 3               6.242149                6.109442               5.494478
# 4               3.783891                3.555104               2.808331
#
#    trade_order_count_sum_450  trade_seconds_gap_mean_450  trade_tendency  \
# 0                   3.637586                    2.460809        3.008903
# 1                   3.135494                    2.821379        1.916797
# 2                   3.526361                    3.049799        3.929138
# 3                   2.484907                    4.143135        2.770287
# 4                   2.708050                    3.663562        2.445418
#
#    trade_energy
# 0      1.007459
# 1      1.000413
# 2      0.998409
# 3      0.998041
# 4      0.999237

# %%
# Function to calculate the root mean squared percentage error
def rmspe(y_true, y_pred):
    return np.sqrt(np.mean(np.square((y_true - y_pred) / y_true)))

# Function to early stop with root mean squared percentage error
def feval_rmspe(y_pred, lgb_train):
    y_true = lgb_train.get_label()
    return "RMSPE", rmspe(y_true, y_pred), False

def train_and_evaluate(train, test):
    
    # scale
    # scaler = QuantileTransformer(n_quantiles=2000, random_state=2021)
    scaler = StandardScaler()
    
    # Split features and target
    x = train.drop(["row_id", "target"], axis=1)
    y = train["target"]
    
    # x_test with train feature
    x_test = test.drop("row_id", axis=1)
    x_test = agg_stat_features_by_market(x_test)
    x_test = agg_stat_features_by_clusters(x_test, n_clusters=CONFIG["n_clusters"], function=np.nanmean, post_fix="_cluster_mean")
    x_test = agg_stat_features_by_clusters(x_test, n_clusters=CONFIG["n_clusters"], function=np.nanmax, post_fix="_cluster_max")
    x_test = agg_stat_features_by_clusters(x_test, n_clusters=CONFIG["n_clusters"], function=np.nanmin, post_fix="_cluster_min")
    x_test = agg_stat_features_by_clusters(x_test, n_clusters=CONFIG["n_clusters"], function=np.nanstd, post_fix="_cluster_std")
    
    # define normalize columns
    except_columns = ["stock_id", "time_id", "target", "row_id"]
    normalized_columns = [column for column in x_test.columns if column not in except_columns]
    x_test.drop("time_id", axis=1, inplace=True)
    
    # Transform stock id to a numeric value
    x["stock_id"] = x["stock_id"].astype(int)
    x_test["stock_id"] = x_test["stock_id"].astype(int)
    
    # Create out of folds array
    oof_predictions = np.zeros(x.shape[0])
    
    # Create test array to store predictions
    test_predictions = np.zeros(x_test.shape[0])
    
    # Create a KFold object
    kfold = KFold(n_splits=CONFIG["n_splits"], random_state=2020, shuffle=True)
    
    # Iterate through each fold
    for fold, (trn_ind, val_ind) in enumerate(kfold.split(x)):
        
        print(f"Training fold {fold + 1}")
        x_train = x.iloc[trn_ind]
        x_train = agg_stat_features_by_market(x_train)
        x_train = agg_stat_features_by_clusters(x_train, n_clusters=CONFIG["n_clusters"], function=np.nanmean, post_fix="_cluster_mean")
        x_train = agg_stat_features_by_clusters(x_train, n_clusters=CONFIG["n_clusters"], function=np.nanmax, post_fix="_cluster_max")
        x_train = agg_stat_features_by_clusters(x_train, n_clusters=CONFIG["n_clusters"], function=np.nanmin, post_fix="_cluster_min")
        x_train = agg_stat_features_by_clusters(x_train, n_clusters=CONFIG["n_clusters"], function=np.nanstd, post_fix="_cluster_std")
        x_train.drop("time_id", axis=1, inplace=True)
        scaler = scaler.fit(x_train[normalized_columns])
        dump(scaler, os.path.join(CONFIG["ckpt_dir"], "std_scaler_fold_{}.bin".format(fold + 1)), compress=True)
        x_train[normalized_columns] = scaler.transform(x_train[normalized_columns])
        
        x_val = x.iloc[val_ind]
        x_val = agg_stat_features_by_market(x_val)
        x_val = agg_stat_features_by_clusters(x_val, n_clusters=CONFIG["n_clusters"], function=np.nanmean, post_fix="_cluster_mean")
        x_val = agg_stat_features_by_clusters(x_val, n_clusters=CONFIG["n_clusters"], function=np.nanmax, post_fix="_cluster_max")
        x_val = agg_stat_features_by_clusters(x_val, n_clusters=CONFIG["n_clusters"], function=np.nanmin, post_fix="_cluster_min")
        x_val = agg_stat_features_by_clusters(x_val, n_clusters=CONFIG["n_clusters"], function=np.nanstd, post_fix="_cluster_std")
        x_val.drop("time_id", axis=1, inplace=True)
        x_val[normalized_columns] = scaler.transform(x_val[normalized_columns])
        
        y_train, y_val = y.iloc[trn_ind], y.iloc[val_ind]
        
        # Root mean squared percentage error weights
        train_weights = 1 / np.square(y_train)
        val_weights = 1 / np.square(y_val)
        train_dataset = lgb.Dataset(x_train, y_train, weight = train_weights, categorical_feature = ["stock_id"])
        val_dataset = lgb.Dataset(x_val, y_val, weight = val_weights, categorical_feature = ["stock_id"])
        
        # Train
        model = lgb.train(params = PARAMS, 
                          train_set = train_dataset, 
                          valid_sets = [train_dataset, val_dataset], 
                          num_boost_round = 6000, 
                          early_stopping_rounds = 300, 
                          verbose_eval = 100,
                          feval = feval_rmspe
                         )
        
        model.save_model(os.path.join(CONFIG["ckpt_dir"], "lgbm_fold_{}.txt".format(fold + 1)))
        
        # Feature Importance
        fig, ax = plt.subplots(figsize=(12, 30))
        for feature, importance in zip(model.feature_name(), model.feature_importance()):
            print(feature, importance)
        lgb.plot_importance(model, max_num_features=50, ax=ax)
        plt.title("Feature importance")
        plt.show()
        
        # Add predictions to the out of folds array
        oof_predictions[val_ind] = model.predict(x_val)
        
        # Predict the test set
        x_test_ = x_test.copy()
        x_test_[normalized_columns] = scaler.transform(x_test_[normalized_columns])
        test_predictions += model.predict(x_test_) / CONFIG["n_splits"]
        
    rmspe_score = rmspe(y, oof_predictions)
    print(f"Our out of folds RMSPE is {rmspe_score}")
    
    # Return test predictions
    return test_predictions

# %%
# Traing and evaluate
test_predictions = train_and_evaluate(train, test)

# Save test predictions
# test["target"] = test_predictions
# test[["row_id", "target"]].to_csv("submission.csv",index = False)
# Out:
# Training fold 1
# Training until validation scores don't improve for 300 rounds
# [100]	training's rmse: 0.000454802	training's RMSPE: 0.210381	valid_1's rmse: 0.000500316	valid_1's RMSPE: 0.232024
# [200]	training's rmse: 0.000430193	training's RMSPE: 0.198997	valid_1's rmse: 0.000508024	valid_1's RMSPE: 0.235599
# [300]	training's rmse: 0.000415554	training's RMSPE: 0.192226	valid_1's rmse: 0.00051567	valid_1's RMSPE: 0.239145
# Early stopping, best iteration is:
# [72]	training's rmse: 0.000467855	training's RMSPE: 0.216419	valid_1's rmse: 0.000498679	valid_1's RMSPE: 0.231265
# stock_id 281
# wap1_sum 0
# wap1_std 1
# wap2_sum 2
# wap2_std 1
# log_return1_realized_volatility 110
# log_return2_realized_volatility 60
# wap_balance_sum 6
# wap_balance_amax 1
# wap_balance_amin 0
# wap_balance_std 2
# bid_ask_spread1_sum 10
# bid_ask_spread1_amax 4
# bid_ask_spread1_amin 4
# bid_ask_spread1_std 2
# bid_ask_spread2_sum 0
# bid_ask_spread2_amax 12
# bid_ask_spread2_amin 0
# bid_ask_spread2_std 1
# order_flow_imbalance1_sum 0
# order_flow_imbalance1_amax 2
# order_flow_imbalance1_amin 0
# order_flow_imbalance1_std 1
# order_flow_imbalance2_sum 0
# order_flow_imbalance2_amax 0
# order_flow_imbalance2_amin 0
# order_flow_imbalance2_std 0
# order_book_slope_mean 0
# order_book_slope_amax 1
# depth_imbalance1_sum 0
# depth_imbalance1_amax 0
# depth_imbalance1_std 0
# depth_imbalance2_sum 0
# depth_imbalance2_amax 0
# depth_imbalance2_std 0
# height_imbalance1_sum 10
# height_imbalance1_amax 2
# height_imbalance1_std 0
# height_imbalance2_sum 4
# height_imbalance2_amax 2
# height_imbalance2_std 5
# pressure_imbalance_sum 0
# pressure_imbalance_amax 0
# pressure_imbalance_std 1
# total_volume_sum 0
# seconds_gap_mean 0
# log_return1_realized_volatility_150 95
# log_return2_realized_volatility_150 50
# wap_balance_sum_150 13
# wap_balance_amax_150 0
# wap_balance_amin_150 5
# wap_balance_std_150 1
# bid_ask_spread1_sum_150 6
# bid_ask_spread1_amax_150 6
# bid_ask_spread1_amin_150 10
# bid_ask_spread1_std_150 1
# bid_ask_spread2_sum_150 5
# bid_ask_spread2_amax_150 4
# bid_ask_spread2_amin_150 1
# bid_ask_spread2_std_150 0
# order_flow_imbalance1_sum_150 0
# order_flow_imbalance1_amax_150 0
# order_flow_imbalance1_amin_150 0
# order_flow_imbalance1_std_150 1
# order_flow_imbalance2_sum_150 0
# order_flow_imbalance2_amax_150 0
# order_flow_imbalance2_amin_150 0
# order_flow_imbalance2_std_150 1
# total_volume_sum_150 0
# seconds_gap_mean_150 0
# log_return1_realized_volatility_300 60
# log_return2_realized_volatility_300 22
# wap_balance_sum_300 2
# wap_balance_amax_300 0
# wap_balance_amin_300 0
# wap_balance_std_300 2
# bid_ask_spread1_sum_300 4
# bid_ask_spread1_amax_300 0
# bid_ask_spread1_amin_300 1
# bid_ask_spread1_std_300 0
# bid_ask_spread2_sum_300 2
# bid_ask_spread2_amax_300 10
# bid_ask_spread2_amin_300 2
# bid_ask_spread2_std_300 1
# order_flow_imbalance1_sum_300 0
# order_flow_imbalance1_amax_300 0
# order_flow_imbalance1_amin_300 1
# order_flow_imbalance1_std_300 3
# order_flow_imbalance2_sum_300 0
# order_flow_imbalance2_amax_300 0
# order_flow_imbalance2_amin_300 0
# order_flow_imbalance2_std_300 0
# total_volume_sum_300 0
# seconds_gap_mean_300 1
# log_return1_realized_volatility_450 17
# log_return2_realized_volatility_450 27
# wap_balance_sum_450 2
# wap_balance_amax_450 0
# wap_balance_amin_450 0
# wap_balance_std_450 2
# bid_ask_spread1_sum_450 8
# bid_ask_spread1_amax_450 6
# bid_ask_spread1_amin_450 2
# bid_ask_spread1_std_450 0
# bid_ask_spread2_sum_450 1
# bid_ask_spread2_amax_450 11
# bid_ask_spread2_amin_450 0
# bid_ask_spread2_std_450 1
# order_flow_imbalance1_sum_450 0
# order_flow_imbalance1_amax_450 1
# order_flow_imbalance1_amin_450 0
# order_flow_imbalance1_std_450 1
# order_flow_imbalance2_sum_450 0
# order_flow_imbalance2_amax_450 1
# order_flow_imbalance2_amin_450 0
# order_flow_imbalance2_std_450 0
# total_volume_sum_450 0
# seconds_gap_mean_450 0
# trade_price_log_return_realized_volatility 28
# trade_volumes_sum 0
# trade_volumes_amax 4
# trade_volumes_std 4
# trade_order_count_sum 0
# trade_seconds_gap_mean 0
# trade_price_log_return_realized_volatility_150 10
# trade_volumes_sum_150 0
# trade_volumes_amax_150 4
# trade_volumes_std_150 1
# trade_order_count_sum_150 0
# trade_seconds_gap_mean_150 1
# trade_price_log_return_realized_volatility_300 5
# trade_volumes_sum_300 0
# trade_volumes_amax_300 2
# trade_volumes_std_300 0
# trade_order_count_sum_300 0
# trade_seconds_gap_mean_300 1
# trade_price_log_return_realized_volatility_450 19
# trade_volumes_sum_450 0
# trade_volumes_amax_450 0
# trade_volumes_std_450 0
# trade_order_count_sum_450 0
# trade_seconds_gap_mean_450 2
# trade_tendency 2
# trade_energy 0
# log_return1_realized_volatility_nanmean_stock 30
# log_return1_realized_volatility_150_nanmean_stock 40
# log_return1_realized_volatility_300_nanmean_stock 15
# log_return1_realized_volatility_450_nanmean_stock 35
# log_return1_realized_volatility_nanmean_time 0
# log_return1_realized_volatility_150_nanmean_time 0
# log_return1_realized_volatility_300_nanmean_time 3
# log_return1_realized_volatility_450_nanmean_time 21
# log_return1_realized_volatility_0_cluster_mean 4
# log_return1_realized_volatility_1_cluster_mean 0
# log_return1_realized_volatility_3_cluster_mean 1
# log_return1_realized_volatility_4_cluster_mean 3
# log_return1_realized_volatility_6_cluster_mean 1
# log_return2_realized_volatility_0_cluster_mean 2
# log_return2_realized_volatility_1_cluster_mean 2
# log_return2_realized_volatility_3_cluster_mean 14
# log_return2_realized_volatility_4_cluster_mean 2
# log_return2_realized_volatility_6_cluster_mean 2
# order_flow_imbalance1_sum_0_cluster_mean 2
# order_flow_imbalance1_sum_1_cluster_mean 0
# order_flow_imbalance1_sum_3_cluster_mean 0
# order_flow_imbalance1_sum_4_cluster_mean 0
# order_flow_imbalance1_sum_6_cluster_mean 0
# order_flow_imbalance2_sum_0_cluster_mean 9
# order_flow_imbalance2_sum_1_cluster_mean 1
# order_flow_imbalance2_sum_3_cluster_mean 49
# order_flow_imbalance2_sum_4_cluster_mean 6
# order_flow_imbalance2_sum_6_cluster_mean 0
# order_book_slope_mean_0_cluster_mean 1
# order_book_slope_mean_1_cluster_mean 0
# order_book_slope_mean_3_cluster_mean 14
# order_book_slope_mean_4_cluster_mean 0
# order_book_slope_mean_6_cluster_mean 1
# depth_imbalance1_std_0_cluster_mean 0
# depth_imbalance1_std_1_cluster_mean 0
# depth_imbalance1_std_3_cluster_mean 0
# depth_imbalance1_std_4_cluster_mean 3
# depth_imbalance1_std_6_cluster_mean 0
# depth_imbalance2_std_0_cluster_mean 1
# depth_imbalance2_std_1_cluster_mean 0
# depth_imbalance2_std_3_cluster_mean 19
# depth_imbalance2_std_4_cluster_mean 0
# depth_imbalance2_std_6_cluster_mean 0
# height_imbalance1_sum_0_cluster_mean 2
# height_imbalance1_sum_1_cluster_mean 0
# height_imbalance1_sum_3_cluster_mean 15
# height_imbalance1_sum_4_cluster_mean 0
# height_imbalance1_sum_6_cluster_mean 6
# height_imbalance2_sum_0_cluster_mean 4
# height_imbalance2_sum_1_cluster_mean 2
# height_imbalance2_sum_3_cluster_mean 37
# height_imbalance2_sum_4_cluster_mean 5
# height_imbalance2_sum_6_cluster_mean 0
# pressure_imbalance_std_0_cluster_mean 2
# pressure_imbalance_std_1_cluster_mean 0
# pressure_imbalance_std_3_cluster_mean 0
# pressure_imbalance_std_4_cluster_mean 0
# pressure_imbalance_std_6_cluster_mean 0
# total_volume_sum_0_cluster_mean 3
# total_volume_sum_1_cluster_mean 1
# total_volume_sum_3_cluster_mean 0
# total_volume_sum_4_cluster_mean 4
# total_volume_sum_6_cluster_mean 1
# seconds_gap_mean_0_cluster_mean 24
# seconds_gap_mean_1_cluster_mean 1
# seconds_gap_mean_3_cluster_mean 97
# seconds_gap_mean_4_cluster_mean 2
# seconds_gap_mean_6_cluster_mean 9
# trade_price_log_return_realized_volatility_0_cluster_mean 3
# trade_price_log_return_realized_volatility_1_cluster_mean 6
# trade_price_log_return_realized_volatility_3_cluster_mean 13
# trade_price_log_return_realized_volatility_4_cluster_mean 1
# trade_price_log_return_realized_volatility_6_cluster_mean 1
# trade_volumes_sum_0_cluster_mean 6
# trade_volumes_sum_1_cluster_mean 0
# trade_volumes_sum_3_cluster_mean 10
# trade_volumes_sum_4_cluster_mean 1
# trade_volumes_sum_6_cluster_mean 0
# trade_order_count_sum_0_cluster_mean 24
# trade_order_count_sum_1_cluster_mean 7
# trade_order_count_sum_3_cluster_mean 67
# trade_order_count_sum_4_cluster_mean 5
# trade_order_count_sum_6_cluster_mean 20
# trade_seconds_gap_mean_0_cluster_mean 7
# trade_seconds_gap_mean_1_cluster_mean 1
# trade_seconds_gap_mean_3_cluster_mean 15
# trade_seconds_gap_mean_4_cluster_mean 0
# trade_seconds_gap_mean_6_cluster_mean 5
# trade_tendency_0_cluster_mean 3
# trade_tendency_1_cluster_mean 0
# trade_tendency_3_cluster_mean 14
# trade_tendency_4_cluster_mean 2
# trade_tendency_6_cluster_mean 1
# trade_energy_0_cluster_mean 0
# trade_energy_1_cluster_mean 0
# trade_energy_3_cluster_mean 1
# trade_energy_4_cluster_mean 0
# trade_energy_6_cluster_mean 0
# log_return1_realized_volatility_0_cluster_max 1
# log_return1_realized_volatility_1_cluster_max 1
# log_return1_realized_volatility_3_cluster_max 0
# log_return1_realized_volatility_4_cluster_max 0
# log_return1_realized_volatility_6_cluster_max 0
# log_return2_realized_volatility_0_cluster_max 0
# log_return2_realized_volatility_1_cluster_max 0
# log_return2_realized_volatility_3_cluster_max 2
# log_return2_realized_volatility_4_cluster_max 0
# log_return2_realized_volatility_6_cluster_max 0
# order_flow_imbalance1_sum_0_cluster_max 1
# order_flow_imbalance1_sum_1_cluster_max 0
# order_flow_imbalance1_sum_3_cluster_max 0
# order_flow_imbalance1_sum_4_cluster_max 0
# order_flow_imbalance1_sum_6_cluster_max 0
# order_flow_imbalance2_sum_0_cluster_max 1
# order_flow_imbalance2_sum_1_cluster_max 1
# order_flow_imbalance2_sum_3_cluster_max 1
# order_flow_imbalance2_sum_4_cluster_max 1
# order_flow_imbalance2_sum_6_cluster_max 8
# order_book_slope_mean_0_cluster_max 0
# order_book_slope_mean_1_cluster_max 1
# order_book_slope_mean_3_cluster_max 0
# order_book_slope_mean_4_cluster_max 0
# order_book_slope_mean_6_cluster_max 0
# depth_imbalance1_std_0_cluster_max 0
# depth_imbalance1_std_1_cluster_max 0
# depth_imbalance1_std_3_cluster_max 0
# depth_imbalance1_std_4_cluster_max 0
# depth_imbalance1_std_6_cluster_max 1
# depth_imbalance2_std_0_cluster_max 0
# depth_imbalance2_std_1_cluster_max 0
# depth_imbalance2_std_3_cluster_max 0
# depth_imbalance2_std_4_cluster_max 0
# depth_imbalance2_std_6_cluster_max 0
# height_imbalance1_sum_0_cluster_max 0
# height_imbalance1_sum_1_cluster_max 0
# height_imbalance1_sum_3_cluster_max 4
# height_imbalance1_sum_4_cluster_max 1
# height_imbalance1_sum_6_cluster_max 0
# height_imbalance2_sum_0_cluster_max 7
# height_imbalance2_sum_1_cluster_max 0
# height_imbalance2_sum_3_cluster_max 12
# height_imbalance2_sum_4_cluster_max 0
# height_imbalance2_sum_6_cluster_max 1
# pressure_imbalance_std_0_cluster_max 0
# pressure_imbalance_std_1_cluster_max 0
# pressure_imbalance_std_3_cluster_max 0
# pressure_imbalance_std_4_cluster_max 0
# pressure_imbalance_std_6_cluster_max 0
# total_volume_sum_0_cluster_max 21
# total_volume_sum_1_cluster_max 2
# total_volume_sum_3_cluster_max 1
# total_volume_sum_4_cluster_max 2
# total_volume_sum_6_cluster_max 0
# seconds_gap_mean_0_cluster_max 1
# seconds_gap_mean_1_cluster_max 2
# seconds_gap_mean_3_cluster_max 2
# seconds_gap_mean_4_cluster_max 0
# seconds_gap_mean_6_cluster_max 3
# trade_price_log_return_realized_volatility_0_cluster_max 1
# trade_price_log_return_realized_volatility_1_cluster_max 0
# trade_price_log_return_realized_volatility_3_cluster_max 0
# trade_price_log_return_realized_volatility_4_cluster_max 1
# trade_price_log_return_realized_volatility_6_cluster_max 5
# trade_volumes_sum_0_cluster_max 0
# trade_volumes_sum_1_cluster_max 0
# trade_volumes_sum_3_cluster_max 1
# trade_volumes_sum_4_cluster_max 0
# trade_volumes_sum_6_cluster_max 0
# trade_order_count_sum_0_cluster_max 0
# trade_order_count_sum_1_cluster_max 0
# trade_order_count_sum_3_cluster_max 2
# trade_order_count_sum_4_cluster_max 2
# trade_order_count_sum_6_cluster_max 0
# trade_seconds_gap_mean_0_cluster_max 4
# trade_seconds_gap_mean_1_cluster_max 0
# trade_seconds_gap_mean_3_cluster_max 4
# trade_seconds_gap_mean_4_cluster_max 0
# trade_seconds_gap_mean_6_cluster_max 0
# trade_tendency_0_cluster_max 0
# trade_tendency_1_cluster_max 0
# trade_tendency_3_cluster_max 1
# trade_tendency_4_cluster_max 1
# trade_tendency_6_cluster_max 1
# trade_energy_0_cluster_max 3
# trade_energy_1_cluster_max 1
# trade_energy_3_cluster_max 2
# trade_energy_4_cluster_max 1
# trade_energy_6_cluster_max 0
# log_return1_realized_volatility_0_cluster_min 1
# log_return1_realized_volatility_1_cluster_min 3
# log_return1_realized_volatility_3_cluster_min 19
# log_return1_realized_volatility_4_cluster_min 0
# log_return1_realized_volatility_6_cluster_min 0
# log_return2_realized_volatility_0_cluster_min 0
# log_return2_realized_volatility_1_cluster_min 2
# log_return2_realized_volatility_3_cluster_min 5
# log_return2_realized_volatility_4_cluster_min 1
# log_return2_realized_volatility_6_cluster_min 3
# order_flow_imbalance1_sum_0_cluster_min 0
# order_flow_imbalance1_sum_1_cluster_min 0
# order_flow_imbalance1_sum_3_cluster_min 0
# order_flow_imbalance1_sum_4_cluster_min 1
# order_flow_imbalance1_sum_6_cluster_min 0
# order_flow_imbalance2_sum_0_cluster_min 0
# order_flow_imbalance2_sum_1_cluster_min 1
# order_flow_imbalance2_sum_3_cluster_min 1
# order_flow_imbalance2_sum_4_cluster_min 0
# order_flow_imbalance2_sum_6_cluster_min 0
# order_book_slope_mean_0_cluster_min 0
# order_book_slope_mean_1_cluster_min 1
# order_book_slope_mean_3_cluster_min 1
# order_book_slope_mean_4_cluster_min 0
# order_book_slope_mean_6_cluster_min 1
# depth_imbalance1_std_0_cluster_min 2
# depth_imbalance1_std_1_cluster_min 0
# depth_imbalance1_std_3_cluster_min 0
# depth_imbalance1_std_4_cluster_min 0
# depth_imbalance1_std_6_cluster_min 1
# depth_imbalance2_std_0_cluster_min 12
# depth_imbalance2_std_1_cluster_min 0
# depth_imbalance2_std_3_cluster_min 2
# depth_imbalance2_std_4_cluster_min 0
# depth_imbalance2_std_6_cluster_min 0
# height_imbalance1_sum_0_cluster_min 0
# height_imbalance1_sum_1_cluster_min 0
# height_imbalance1_sum_3_cluster_min 8
# height_imbalance1_sum_4_cluster_min 0
# height_imbalance1_sum_6_cluster_min 2
# height_imbalance2_sum_0_cluster_min 0
# height_imbalance2_sum_1_cluster_min 0
# height_imbalance2_sum_3_cluster_min 10
# height_imbalance2_sum_4_cluster_min 0
# height_imbalance2_sum_6_cluster_min 2
# pressure_imbalance_std_0_cluster_min 0
# pressure_imbalance_std_1_cluster_min 0
# pressure_imbalance_std_3_cluster_min 1
# pressure_imbalance_std_4_cluster_min 0
# pressure_imbalance_std_6_cluster_min 1
# total_volume_sum_0_cluster_min 0
# total_volume_sum_1_cluster_min 1
# total_volume_sum_3_cluster_min 2
# total_volume_sum_4_cluster_min 0
# total_volume_sum_6_cluster_min 6
# seconds_gap_mean_0_cluster_min 1
# seconds_gap_mean_1_cluster_min 0
# seconds_gap_mean_3_cluster_min 0
# seconds_gap_mean_4_cluster_min 0
# seconds_gap_mean_6_cluster_min 1
# trade_price_log_return_realized_volatility_0_cluster_min 2
# trade_price_log_return_realized_volatility_1_cluster_min 1
# trade_price_log_return_realized_volatility_3_cluster_min 12
# trade_price_log_return_realized_volatility_4_cluster_min 0
# trade_price_log_return_realized_volatility_6_cluster_min 2
# trade_volumes_sum_0_cluster_min 1
# trade_volumes_sum_1_cluster_min 1
# trade_volumes_sum_3_cluster_min 0
# trade_volumes_sum_4_cluster_min 0
# trade_volumes_sum_6_cluster_min 1
# trade_order_count_sum_0_cluster_min 10
# trade_order_count_sum_1_cluster_min 2
# trade_order_count_sum_3_cluster_min 4
# trade_order_count_sum_4_cluster_min 2
# trade_order_count_sum_6_cluster_min 3
# trade_seconds_gap_mean_0_cluster_min 3
# trade_seconds_gap_mean_1_cluster_min 1
# trade_seconds_gap_mean_3_cluster_min 21
# trade_seconds_gap_mean_4_cluster_min 0
# trade_seconds_gap_mean_6_cluster_min 0
# trade_tendency_0_cluster_min 0
# trade_tendency_1_cluster_min 0
# trade_tendency_3_cluster_min 0
# trade_tendency_4_cluster_min 0
# trade_tendency_6_cluster_min 1
# trade_energy_0_cluster_min 0
# trade_energy_1_cluster_min 0
# trade_energy_3_cluster_min 3
# trade_energy_4_cluster_min 0
# trade_energy_6_cluster_min 0
# log_return1_realized_volatility_0_cluster_std 0
# log_return1_realized_volatility_1_cluster_std 0
# log_return1_realized_volatility_3_cluster_std 1
# log_return1_realized_volatility_4_cluster_std 1
# log_return1_realized_volatility_6_cluster_std 0
# log_return2_realized_volatility_0_cluster_std 1
# log_return2_realized_volatility_1_cluster_std 0
# log_return2_realized_volatility_3_cluster_std 3
# log_return2_realized_volatility_4_cluster_std 0
# log_return2_realized_volatility_6_cluster_std 0
# order_flow_imbalance1_sum_0_cluster_std 0
# order_flow_imbalance1_sum_1_cluster_std 0
# order_flow_imbalance1_sum_3_cluster_std 0
# order_flow_imbalance1_sum_4_cluster_std 0
# order_flow_imbalance1_sum_6_cluster_std 0
# order_flow_imbalance2_sum_0_cluster_std 1
# order_flow_imbalance2_sum_1_cluster_std 0
# order_flow_imbalance2_sum_3_cluster_std 1
# order_flow_imbalance2_sum_4_cluster_std 0
# order_flow_imbalance2_sum_6_cluster_std 15
# order_book_slope_mean_0_cluster_std 2
# order_book_slope_mean_1_cluster_std 1
# order_book_slope_mean_3_cluster_std 0
# order_book_slope_mean_4_cluster_std 0
# order_book_slope_mean_6_cluster_std 0
# depth_imbalance1_std_0_cluster_std 18
# depth_imbalance1_std_1_cluster_std 0
# depth_imbalance1_std_3_cluster_std 1
# depth_imbalance1_std_4_cluster_std 0
# depth_imbalance1_std_6_cluster_std 1
# depth_imbalance2_std_0_cluster_std 4
# depth_imbalance2_std_1_cluster_std 0
# depth_imbalance2_std_3_cluster_std 2
# depth_imbalance2_std_4_cluster_std 0
# depth_imbalance2_std_6_cluster_std 0
# height_imbalance1_sum_0_cluster_std 1
# height_imbalance1_sum_1_cluster_std 0
# height_imbalance1_sum_3_cluster_std 1
# height_imbalance1_sum_4_cluster_std 2
# height_imbalance1_sum_6_cluster_std 0
# height_imbalance2_sum_0_cluster_std 0
# height_imbalance2_sum_1_cluster_std 2
# height_imbalance2_sum_3_cluster_std 5
# height_imbalance2_sum_4_cluster_std 0
# height_imbalance2_sum_6_cluster_std 0
# pressure_imbalance_std_0_cluster_std 0
# pressure_imbalance_std_1_cluster_std 1
# pressure_imbalance_std_3_cluster_std 1
# pressure_imbalance_std_4_cluster_std 0
# pressure_imbalance_std_6_cluster_std 0
# total_volume_sum_0_cluster_std 9
# total_volume_sum_1_cluster_std 0
# total_volume_sum_3_cluster_std 1
# total_volume_sum_4_cluster_std 0
# total_volume_sum_6_cluster_std 1
# seconds_gap_mean_0_cluster_std 26
# seconds_gap_mean_1_cluster_std 0
# seconds_gap_mean_3_cluster_std 14
# seconds_gap_mean_4_cluster_std 0
# seconds_gap_mean_6_cluster_std 10
# trade_price_log_return_realized_volatility_0_cluster_std 0
# trade_price_log_return_realized_volatility_1_cluster_std 0
# trade_price_log_return_realized_volatility_3_cluster_std 0
# trade_price_log_return_realized_volatility_4_cluster_std 2
# trade_price_log_return_realized_volatility_6_cluster_std 0
# trade_volumes_sum_0_cluster_std 0
# trade_volumes_sum_1_cluster_std 0
# trade_volumes_sum_3_cluster_std 1
# trade_volumes_sum_4_cluster_std 1
# trade_volumes_sum_6_cluster_std 0
# trade_order_count_sum_0_cluster_std 1
# trade_order_count_sum_1_cluster_std 0
# trade_order_count_sum_3_cluster_std 1
# trade_order_count_sum_4_cluster_std 1
# trade_order_count_sum_6_cluster_std 0
# trade_seconds_gap_mean_0_cluster_std 6
# trade_seconds_gap_mean_1_cluster_std 0
# trade_seconds_gap_mean_3_cluster_std 0
# trade_seconds_gap_mean_4_cluster_std 0
# trade_seconds_gap_mean_6_cluster_std 0
# trade_tendency_0_cluster_std 1
# trade_tendency_1_cluster_std 0
# trade_tendency_3_cluster_std 0
# trade_tendency_4_cluster_std 0
# trade_tendency_6_cluster_std 0
# trade_energy_0_cluster_std 13
# trade_energy_1_cluster_std 0
# trade_energy_3_cluster_std 11
# trade_energy_4_cluster_std 15
# trade_energy_6_cluster_std 4
# Training fold 2
# Training until validation scores don't improve for 300 rounds
# [100]	training's rmse: 0.000453771	training's RMSPE: 0.21033	valid_1's rmse: 0.000522506	valid_1's RMSPE: 0.240349
# [200]	training's rmse: 0.000429287	training's RMSPE: 0.198981	valid_1's rmse: 0.000518937	valid_1's RMSPE: 0.238707
# [300]	training's rmse: 0.000414498	training's RMSPE: 0.192126	valid_1's rmse: 0.00051989	valid_1's RMSPE: 0.239145
# [400]	training's rmse: 0.000404064	training's RMSPE: 0.18729	valid_1's rmse: 0.000522941	valid_1's RMSPE: 0.240549
# [500]	training's rmse: 0.000396269	training's RMSPE: 0.183677	valid_1's rmse: 0.000526753	valid_1's RMSPE: 0.242302
# Early stopping, best iteration is:
# [200]	training's rmse: 0.000429287	training's RMSPE: 0.198981	valid_1's rmse: 0.000518937	valid_1's RMSPE: 0.238707
# stock_id 732
# wap1_sum 4
# wap1_std 6
# wap2_sum 3
# wap2_std 14
# log_return1_realized_volatility 121
# log_return2_realized_volatility 73
# wap_balance_sum 9
# wap_balance_amax 1
# wap_balance_amin 2
# wap_balance_std 7
# bid_ask_spread1_sum 32
# bid_ask_spread1_amax 5
# bid_ask_spread1_amin 20
# bid_ask_spread1_std 8
# bid_ask_spread2_sum 1
# bid_ask_spread2_amax 9
# bid_ask_spread2_amin 3
# bid_ask_spread2_std 2
# order_flow_imbalance1_sum 2
# order_flow_imbalance1_amax 3
# order_flow_imbalance1_amin 3
# order_flow_imbalance1_std 4
# order_flow_imbalance2_sum 8
# order_flow_imbalance2_amax 1
# order_flow_imbalance2_amin 1
# order_flow_imbalance2_std 3
# order_book_slope_mean 1
# order_book_slope_amax 2
# depth_imbalance1_sum 0
# depth_imbalance1_amax 1
# depth_imbalance1_std 2
# depth_imbalance2_sum 0
# depth_imbalance2_amax 2
# depth_imbalance2_std 3
# height_imbalance1_sum 21
# height_imbalance1_amax 13
# height_imbalance1_std 6
# height_imbalance2_sum 1
# height_imbalance2_amax 9
# height_imbalance2_std 3
# pressure_imbalance_sum 8
# pressure_imbalance_amax 0
# pressure_imbalance_std 1
# total_volume_sum 8
# seconds_gap_mean 7
# log_return1_realized_volatility_150 190
# log_return2_realized_volatility_150 56
# wap_balance_sum_150 10
# wap_balance_amax_150 1
# wap_balance_amin_150 1
# wap_balance_std_150 6
# bid_ask_spread1_sum_150 4
# bid_ask_spread1_amax_150 10
# bid_ask_spread1_amin_150 15
# bid_ask_spread1_std_150 2
# bid_ask_spread2_sum_150 6
# bid_ask_spread2_amax_150 17
# bid_ask_spread2_amin_150 1
# bid_ask_spread2_std_150 4
# order_flow_imbalance1_sum_150 1
# order_flow_imbalance1_amax_150 2
# order_flow_imbalance1_amin_150 1
# order_flow_imbalance1_std_150 1
# order_flow_imbalance2_sum_150 2
# order_flow_imbalance2_amax_150 1
# order_flow_imbalance2_amin_150 0
# order_flow_imbalance2_std_150 2
# total_volume_sum_150 7
# seconds_gap_mean_150 5
# log_return1_realized_volatility_300 96
# log_return2_realized_volatility_300 34
# wap_balance_sum_300 10
# wap_balance_amax_300 3
# wap_balance_amin_300 4
# wap_balance_std_300 2
# bid_ask_spread1_sum_300 16
# bid_ask_spread1_amax_300 4
# bid_ask_spread1_amin_300 4
# bid_ask_spread1_std_300 2
# bid_ask_spread2_sum_300 4
# bid_ask_spread2_amax_300 8
# bid_ask_spread2_amin_300 4
# bid_ask_spread2_std_300 0
# order_flow_imbalance1_sum_300 1
# order_flow_imbalance1_amax_300 4
# order_flow_imbalance1_amin_300 3
# order_flow_imbalance1_std_300 2
# order_flow_imbalance2_sum_300 5
# order_flow_imbalance2_amax_300 1
# order_flow_imbalance2_amin_300 3
# order_flow_imbalance2_std_300 1
# total_volume_sum_300 5
# seconds_gap_mean_300 2
# log_return1_realized_volatility_450 23
# log_return2_realized_volatility_450 34
# wap_balance_sum_450 4
# wap_balance_amax_450 6
# wap_balance_amin_450 1
# wap_balance_std_450 2
# bid_ask_spread1_sum_450 14
# bid_ask_spread1_amax_450 5
# bid_ask_spread1_amin_450 7
# bid_ask_spread1_std_450 0
# bid_ask_spread2_sum_450 5
# bid_ask_spread2_amax_450 15
# bid_ask_spread2_amin_450 6
# bid_ask_spread2_std_450 0
# order_flow_imbalance1_sum_450 1
# order_flow_imbalance1_amax_450 3
# order_flow_imbalance1_amin_450 4
# order_flow_imbalance1_std_450 4
# order_flow_imbalance2_sum_450 1
# order_flow_imbalance2_amax_450 2
# order_flow_imbalance2_amin_450 3
# order_flow_imbalance2_std_450 5
# total_volume_sum_450 0
# seconds_gap_mean_450 2
# trade_price_log_return_realized_volatility 32
# trade_volumes_sum 4
# trade_volumes_amax 15
# trade_volumes_std 16
# trade_order_count_sum 1
# trade_seconds_gap_mean 2
# trade_price_log_return_realized_volatility_150 8
# trade_volumes_sum_150 2
# trade_volumes_amax_150 6
# trade_volumes_std_150 5
# trade_order_count_sum_150 4
# trade_seconds_gap_mean_150 8
# trade_price_log_return_realized_volatility_300 11
# trade_volumes_sum_300 2
# trade_volumes_amax_300 3
# trade_volumes_std_300 2
# trade_order_count_sum_300 1
# trade_seconds_gap_mean_300 8
# trade_price_log_return_realized_volatility_450 44
# trade_volumes_sum_450 0
# trade_volumes_amax_450 4
# trade_volumes_std_450 1
# trade_order_count_sum_450 8
# trade_seconds_gap_mean_450 2
# trade_tendency 28
# trade_energy 20
# log_return1_realized_volatility_nanmean_stock 35
# log_return1_realized_volatility_150_nanmean_stock 49
# log_return1_realized_volatility_300_nanmean_stock 23
# log_return1_realized_volatility_450_nanmean_stock 33
# log_return1_realized_volatility_nanmean_time 0
# log_return1_realized_volatility_150_nanmean_time 4
# log_return1_realized_volatility_300_nanmean_time 8
# log_return1_realized_volatility_450_nanmean_time 39
# log_return1_realized_volatility_0_cluster_mean 0
# log_return1_realized_volatility_1_cluster_mean 4
# log_return1_realized_volatility_3_cluster_mean 4
# log_return1_realized_volatility_4_cluster_mean 2
# log_return1_realized_volatility_6_cluster_mean 1
# log_return2_realized_volatility_0_cluster_mean 7
# log_return2_realized_volatility_1_cluster_mean 1
# log_return2_realized_volatility_3_cluster_mean 10
# log_return2_realized_volatility_4_cluster_mean 4
# log_return2_realized_volatility_6_cluster_mean 7
# order_flow_imbalance1_sum_0_cluster_mean 4
# order_flow_imbalance1_sum_1_cluster_mean 5
# order_flow_imbalance1_sum_3_cluster_mean 5
# order_flow_imbalance1_sum_4_cluster_mean 19
# order_flow_imbalance1_sum_6_cluster_mean 6
# order_flow_imbalance2_sum_0_cluster_mean 46
# order_flow_imbalance2_sum_1_cluster_mean 7
# order_flow_imbalance2_sum_3_cluster_mean 57
# order_flow_imbalance2_sum_4_cluster_mean 22
# order_flow_imbalance2_sum_6_cluster_mean 3
# order_book_slope_mean_0_cluster_mean 8
# order_book_slope_mean_1_cluster_mean 8
# order_book_slope_mean_3_cluster_mean 18
# order_book_slope_mean_4_cluster_mean 8
# order_book_slope_mean_6_cluster_mean 4
# depth_imbalance1_std_0_cluster_mean 8
# depth_imbalance1_std_1_cluster_mean 2
# depth_imbalance1_std_3_cluster_mean 5
# depth_imbalance1_std_4_cluster_mean 8
# depth_imbalance1_std_6_cluster_mean 5
# depth_imbalance2_std_0_cluster_mean 9
# depth_imbalance2_std_1_cluster_mean 7
# depth_imbalance2_std_3_cluster_mean 27
# depth_imbalance2_std_4_cluster_mean 18
# depth_imbalance2_std_6_cluster_mean 6
# height_imbalance1_sum_0_cluster_mean 3
# height_imbalance1_sum_1_cluster_mean 5
# height_imbalance1_sum_3_cluster_mean 12
# height_imbalance1_sum_4_cluster_mean 2
# height_imbalance1_sum_6_cluster_mean 4
# height_imbalance2_sum_0_cluster_mean 2
# height_imbalance2_sum_1_cluster_mean 7
# height_imbalance2_sum_3_cluster_mean 56
# height_imbalance2_sum_4_cluster_mean 2
# height_imbalance2_sum_6_cluster_mean 8
# pressure_imbalance_std_0_cluster_mean 8
# pressure_imbalance_std_1_cluster_mean 6
# pressure_imbalance_std_3_cluster_mean 4
# pressure_imbalance_std_4_cluster_mean 10
# pressure_imbalance_std_6_cluster_mean 10
# total_volume_sum_0_cluster_mean 17
# total_volume_sum_1_cluster_mean 4
# total_volume_sum_3_cluster_mean 7
# total_volume_sum_4_cluster_mean 14
# total_volume_sum_6_cluster_mean 4
# seconds_gap_mean_0_cluster_mean 43
# seconds_gap_mean_1_cluster_mean 15
# seconds_gap_mean_3_cluster_mean 89
# seconds_gap_mean_4_cluster_mean 5
# seconds_gap_mean_6_cluster_mean 8
# trade_price_log_return_realized_volatility_0_cluster_mean 11
# trade_price_log_return_realized_volatility_1_cluster_mean 9
# trade_price_log_return_realized_volatility_3_cluster_mean 4
# trade_price_log_return_realized_volatility_4_cluster_mean 2
# trade_price_log_return_realized_volatility_6_cluster_mean 6
# trade_volumes_sum_0_cluster_mean 5
# trade_volumes_sum_1_cluster_mean 5
# trade_volumes_sum_3_cluster_mean 14
# trade_volumes_sum_4_cluster_mean 8
# trade_volumes_sum_6_cluster_mean 12
# trade_order_count_sum_0_cluster_mean 27
# trade_order_count_sum_1_cluster_mean 25
# trade_order_count_sum_3_cluster_mean 86
# trade_order_count_sum_4_cluster_mean 19
# trade_order_count_sum_6_cluster_mean 23
# trade_seconds_gap_mean_0_cluster_mean 25
# trade_seconds_gap_mean_1_cluster_mean 6
# trade_seconds_gap_mean_3_cluster_mean 35
# trade_seconds_gap_mean_4_cluster_mean 13
# trade_seconds_gap_mean_6_cluster_mean 13
# trade_tendency_0_cluster_mean 22
# trade_tendency_1_cluster_mean 6
# trade_tendency_3_cluster_mean 48
# trade_tendency_4_cluster_mean 7
# trade_tendency_6_cluster_mean 6
# trade_energy_0_cluster_mean 9
# trade_energy_1_cluster_mean 5
# trade_energy_3_cluster_mean 11
# trade_energy_4_cluster_mean 17
# trade_energy_6_cluster_mean 11
# log_return1_realized_volatility_0_cluster_max 2
# log_return1_realized_volatility_1_cluster_max 4
# log_return1_realized_volatility_3_cluster_max 8
# log_return1_realized_volatility_4_cluster_max 3
# log_return1_realized_volatility_6_cluster_max 9
# log_return2_realized_volatility_0_cluster_max 4
# log_return2_realized_volatility_1_cluster_max 3
# log_return2_realized_volatility_3_cluster_max 3
# log_return2_realized_volatility_4_cluster_max 4
# log_return2_realized_volatility_6_cluster_max 2
# order_flow_imbalance1_sum_0_cluster_max 19
# order_flow_imbalance1_sum_1_cluster_max 6
# order_flow_imbalance1_sum_3_cluster_max 10
# order_flow_imbalance1_sum_4_cluster_max 10
# order_flow_imbalance1_sum_6_cluster_max 7
# order_flow_imbalance2_sum_0_cluster_max 3
# order_flow_imbalance2_sum_1_cluster_max 12
# order_flow_imbalance2_sum_3_cluster_max 8
# order_flow_imbalance2_sum_4_cluster_max 9
# order_flow_imbalance2_sum_6_cluster_max 23
# order_book_slope_mean_0_cluster_max 9
# order_book_slope_mean_1_cluster_max 5
# order_book_slope_mean_3_cluster_max 2
# order_book_slope_mean_4_cluster_max 8
# order_book_slope_mean_6_cluster_max 3
# depth_imbalance1_std_0_cluster_max 6
# depth_imbalance1_std_1_cluster_max 7
# depth_imbalance1_std_3_cluster_max 10
# depth_imbalance1_std_4_cluster_max 6
# depth_imbalance1_std_6_cluster_max 16
# depth_imbalance2_std_0_cluster_max 13
# depth_imbalance2_std_1_cluster_max 13
# depth_imbalance2_std_3_cluster_max 6
# depth_imbalance2_std_4_cluster_max 27
# depth_imbalance2_std_6_cluster_max 3
# height_imbalance1_sum_0_cluster_max 17
# height_imbalance1_sum_1_cluster_max 9
# height_imbalance1_sum_3_cluster_max 17
# height_imbalance1_sum_4_cluster_max 5
# height_imbalance1_sum_6_cluster_max 3
# height_imbalance2_sum_0_cluster_max 18
# height_imbalance2_sum_1_cluster_max 6
# height_imbalance2_sum_3_cluster_max 30
# height_imbalance2_sum_4_cluster_max 7
# height_imbalance2_sum_6_cluster_max 0
# pressure_imbalance_std_0_cluster_max 9
# pressure_imbalance_std_1_cluster_max 5
# pressure_imbalance_std_3_cluster_max 7
# pressure_imbalance_std_4_cluster_max 3
# pressure_imbalance_std_6_cluster_max 4
# total_volume_sum_0_cluster_max 36
# total_volume_sum_1_cluster_max 8
# total_volume_sum_3_cluster_max 6
# total_volume_sum_4_cluster_max 10
# total_volume_sum_6_cluster_max 5
# seconds_gap_mean_0_cluster_max 10
# seconds_gap_mean_1_cluster_max 8
# seconds_gap_mean_3_cluster_max 13
# seconds_gap_mean_4_cluster_max 8
# seconds_gap_mean_6_cluster_max 12
# trade_price_log_return_realized_volatility_0_cluster_max 6
# trade_price_log_return_realized_volatility_1_cluster_max 7
# trade_price_log_return_realized_volatility_3_cluster_max 3
# trade_price_log_return_realized_volatility_4_cluster_max 2
# trade_price_log_return_realized_volatility_6_cluster_max 5
# trade_volumes_sum_0_cluster_max 3
# trade_volumes_sum_1_cluster_max 4
# trade_volumes_sum_3_cluster_max 16
# trade_volumes_sum_4_cluster_max 6
# trade_volumes_sum_6_cluster_max 12
# trade_order_count_sum_0_cluster_max 2
# trade_order_count_sum_1_cluster_max 5
# trade_order_count_sum_3_cluster_max 9
# trade_order_count_sum_4_cluster_max 10
# trade_order_count_sum_6_cluster_max 14
# trade_seconds_gap_mean_0_cluster_max 4
# trade_seconds_gap_mean_1_cluster_max 9
# trade_seconds_gap_mean_3_cluster_max 3
# trade_seconds_gap_mean_4_cluster_max 15
# trade_seconds_gap_mean_6_cluster_max 7
# trade_tendency_0_cluster_max 8
# trade_tendency_1_cluster_max 7
# trade_tendency_3_cluster_max 8
# trade_tendency_4_cluster_max 9
# trade_tendency_6_cluster_max 4
# trade_energy_0_cluster_max 11
# trade_energy_1_cluster_max 4
# trade_energy_3_cluster_max 7
# trade_energy_4_cluster_max 16
# trade_energy_6_cluster_max 6
# log_return1_realized_volatility_0_cluster_min 7
# log_return1_realized_volatility_1_cluster_min 9
# log_return1_realized_volatility_3_cluster_min 36
# log_return1_realized_volatility_4_cluster_min 8
# log_return1_realized_volatility_6_cluster_min 3
# log_return2_realized_volatility_0_cluster_min 10
# log_return2_realized_volatility_1_cluster_min 5
# log_return2_realized_volatility_3_cluster_min 11
# log_return2_realized_volatility_4_cluster_min 8
# log_return2_realized_volatility_6_cluster_min 8
# order_flow_imbalance1_sum_0_cluster_min 11
# order_flow_imbalance1_sum_1_cluster_min 3
# order_flow_imbalance1_sum_3_cluster_min 6
# order_flow_imbalance1_sum_4_cluster_min 7
# order_flow_imbalance1_sum_6_cluster_min 11
# order_flow_imbalance2_sum_0_cluster_min 4
# order_flow_imbalance2_sum_1_cluster_min 20
# order_flow_imbalance2_sum_3_cluster_min 10
# order_flow_imbalance2_sum_4_cluster_min 8
# order_flow_imbalance2_sum_6_cluster_min 6
# order_book_slope_mean_0_cluster_min 19
# order_book_slope_mean_1_cluster_min 9
# order_book_slope_mean_3_cluster_min 29
# order_book_slope_mean_4_cluster_min 15
# order_book_slope_mean_6_cluster_min 9
# depth_imbalance1_std_0_cluster_min 5
# depth_imbalance1_std_1_cluster_min 4
# depth_imbalance1_std_3_cluster_min 7
# depth_imbalance1_std_4_cluster_min 9
# depth_imbalance1_std_6_cluster_min 9
# depth_imbalance2_std_0_cluster_min 18
# depth_imbalance2_std_1_cluster_min 8
# depth_imbalance2_std_3_cluster_min 9
# depth_imbalance2_std_4_cluster_min 11
# depth_imbalance2_std_6_cluster_min 11
# height_imbalance1_sum_0_cluster_min 5
# height_imbalance1_sum_1_cluster_min 7
# height_imbalance1_sum_3_cluster_min 6
# height_imbalance1_sum_4_cluster_min 2
# height_imbalance1_sum_6_cluster_min 8
# height_imbalance2_sum_0_cluster_min 4
# height_imbalance2_sum_1_cluster_min 3
# height_imbalance2_sum_3_cluster_min 30
# height_imbalance2_sum_4_cluster_min 7
# height_imbalance2_sum_6_cluster_min 8
# pressure_imbalance_std_0_cluster_min 19
# pressure_imbalance_std_1_cluster_min 5
# pressure_imbalance_std_3_cluster_min 9
# pressure_imbalance_std_4_cluster_min 4
# pressure_imbalance_std_6_cluster_min 5
# total_volume_sum_0_cluster_min 23
# total_volume_sum_1_cluster_min 8
# total_volume_sum_3_cluster_min 8
# total_volume_sum_4_cluster_min 10
# total_volume_sum_6_cluster_min 15
# seconds_gap_mean_0_cluster_min 5
# seconds_gap_mean_1_cluster_min 5
# seconds_gap_mean_3_cluster_min 6
# seconds_gap_mean_4_cluster_min 0
# seconds_gap_mean_6_cluster_min 2
# trade_price_log_return_realized_volatility_0_cluster_min 3
# trade_price_log_return_realized_volatility_1_cluster_min 8
# trade_price_log_return_realized_volatility_3_cluster_min 34
# trade_price_log_return_realized_volatility_4_cluster_min 5
# trade_price_log_return_realized_volatility_6_cluster_min 5
# trade_volumes_sum_0_cluster_min 8
# trade_volumes_sum_1_cluster_min 6
# trade_volumes_sum_3_cluster_min 2
# trade_volumes_sum_4_cluster_min 9
# trade_volumes_sum_6_cluster_min 7
# trade_order_count_sum_0_cluster_min 21
# trade_order_count_sum_1_cluster_min 8
# trade_order_count_sum_3_cluster_min 6
# trade_order_count_sum_4_cluster_min 23
# trade_order_count_sum_6_cluster_min 8
# trade_seconds_gap_mean_0_cluster_min 29
# trade_seconds_gap_mean_1_cluster_min 18
# trade_seconds_gap_mean_3_cluster_min 23
# trade_seconds_gap_mean_4_cluster_min 5
# trade_seconds_gap_mean_6_cluster_min 7
# trade_tendency_0_cluster_min 7
# trade_tendency_1_cluster_min 6
# trade_tendency_3_cluster_min 12
# trade_tendency_4_cluster_min 4
# trade_tendency_6_cluster_min 1
# trade_energy_0_cluster_min 4
# trade_energy_1_cluster_min 10
# trade_energy_3_cluster_min 8
# trade_energy_4_cluster_min 3
# trade_energy_6_cluster_min 8
# log_return1_realized_volatility_0_cluster_std 3
# log_return1_realized_volatility_1_cluster_std 7
# log_return1_realized_volatility_3_cluster_std 13
# log_return1_realized_volatility_4_cluster_std 3
# log_return1_realized_volatility_6_cluster_std 7
# log_return2_realized_volatility_0_cluster_std 5
# log_return2_realized_volatility_1_cluster_std 6
# log_return2_realized_volatility_3_cluster_std 6
# log_return2_realized_volatility_4_cluster_std 2
# log_return2_realized_volatility_6_cluster_std 5
# order_flow_imbalance1_sum_0_cluster_std 4
# order_flow_imbalance1_sum_1_cluster_std 3
# order_flow_imbalance1_sum_3_cluster_std 9
# order_flow_imbalance1_sum_4_cluster_std 13
# order_flow_imbalance1_sum_6_cluster_std 9
# order_flow_imbalance2_sum_0_cluster_std 3
# order_flow_imbalance2_sum_1_cluster_std 4
# order_flow_imbalance2_sum_3_cluster_std 29
# order_flow_imbalance2_sum_4_cluster_std 6
# order_flow_imbalance2_sum_6_cluster_std 27
# order_book_slope_mean_0_cluster_std 14
# order_book_slope_mean_1_cluster_std 5
# order_book_slope_mean_3_cluster_std 10
# order_book_slope_mean_4_cluster_std 5
# order_book_slope_mean_6_cluster_std 4
# depth_imbalance1_std_0_cluster_std 42
# depth_imbalance1_std_1_cluster_std 10
# depth_imbalance1_std_3_cluster_std 31
# depth_imbalance1_std_4_cluster_std 5
# depth_imbalance1_std_6_cluster_std 11
# depth_imbalance2_std_0_cluster_std 14
# depth_imbalance2_std_1_cluster_std 5
# depth_imbalance2_std_3_cluster_std 15
# depth_imbalance2_std_4_cluster_std 9
# depth_imbalance2_std_6_cluster_std 18
# height_imbalance1_sum_0_cluster_std 2
# height_imbalance1_sum_1_cluster_std 2
# height_imbalance1_sum_3_cluster_std 8
# height_imbalance1_sum_4_cluster_std 1
# height_imbalance1_sum_6_cluster_std 0
# height_imbalance2_sum_0_cluster_std 3
# height_imbalance2_sum_1_cluster_std 7
# height_imbalance2_sum_3_cluster_std 17
# height_imbalance2_sum_4_cluster_std 1
# height_imbalance2_sum_6_cluster_std 13
# pressure_imbalance_std_0_cluster_std 8
# pressure_imbalance_std_1_cluster_std 6
# pressure_imbalance_std_3_cluster_std 6
# pressure_imbalance_std_4_cluster_std 9
# pressure_imbalance_std_6_cluster_std 3
# total_volume_sum_0_cluster_std 11
# total_volume_sum_1_cluster_std 4
# total_volume_sum_3_cluster_std 8
# total_volume_sum_4_cluster_std 4
# total_volume_sum_6_cluster_std 11
# seconds_gap_mean_0_cluster_std 23
# seconds_gap_mean_1_cluster_std 7
# seconds_gap_mean_3_cluster_std 27
# seconds_gap_mean_4_cluster_std 6
# seconds_gap_mean_6_cluster_std 14
# trade_price_log_return_realized_volatility_0_cluster_std 6
# trade_price_log_return_realized_volatility_1_cluster_std 4
# trade_price_log_return_realized_volatility_3_cluster_std 4
# trade_price_log_return_realized_volatility_4_cluster_std 12
# trade_price_log_return_realized_volatility_6_cluster_std 11
# trade_volumes_sum_0_cluster_std 1
# trade_volumes_sum_1_cluster_std 5
# trade_volumes_sum_3_cluster_std 9
# trade_volumes_sum_4_cluster_std 8
# trade_volumes_sum_6_cluster_std 10
# trade_order_count_sum_0_cluster_std 5
# trade_order_count_sum_1_cluster_std 4
# trade_order_count_sum_3_cluster_std 3
# trade_order_count_sum_4_cluster_std 10
# trade_order_count_sum_6_cluster_std 4
# trade_seconds_gap_mean_0_cluster_std 10
# trade_seconds_gap_mean_1_cluster_std 8
# trade_seconds_gap_mean_3_cluster_std 20
# trade_seconds_gap_mean_4_cluster_std 9
# trade_seconds_gap_mean_6_cluster_std 8
# trade_tendency_0_cluster_std 23
# trade_tendency_1_cluster_std 13
# trade_tendency_3_cluster_std 7
# trade_tendency_4_cluster_std 24
# trade_tendency_6_cluster_std 5
# trade_energy_0_cluster_std 23
# trade_energy_1_cluster_std 8
# trade_energy_3_cluster_std 23
# trade_energy_4_cluster_std 20
# trade_energy_6_cluster_std 21
# Training fold 3
# Training until validation scores don't improve for 300 rounds
# [100]	training's rmse: 0.000454611	training's RMSPE: 0.210199	valid_1's rmse: 0.000498712	valid_1's RMSPE: 0.231689
# [200]	training's rmse: 0.00043001	training's RMSPE: 0.198825	valid_1's rmse: 0.000504173	valid_1's RMSPE: 0.234226
# [300]	training's rmse: 0.000415435	training's RMSPE: 0.192085	valid_1's rmse: 0.000511825	valid_1's RMSPE: 0.23778
# Early stopping, best iteration is:
# [70]	training's rmse: 0.000469218	training's RMSPE: 0.216953	valid_1's rmse: 0.000495964	valid_1's RMSPE: 0.230412
# stock_id 281
# wap1_sum 0
# wap1_std 1
# wap2_sum 0
# wap2_std 0
# log_return1_realized_volatility 113
# log_return2_realized_volatility 67
# wap_balance_sum 5
# wap_balance_amax 0
# wap_balance_amin 2
# wap_balance_std 2
# bid_ask_spread1_sum 10
# bid_ask_spread1_amax 2
# bid_ask_spread1_amin 2
# bid_ask_spread1_std 2
# bid_ask_spread2_sum 2
# bid_ask_spread2_amax 14
# bid_ask_spread2_amin 1
# bid_ask_spread2_std 3
# order_flow_imbalance1_sum 0
# order_flow_imbalance1_amax 0
# order_flow_imbalance1_amin 0
# order_flow_imbalance1_std 0
# order_flow_imbalance2_sum 2
# order_flow_imbalance2_amax 2
# order_flow_imbalance2_amin 0
# order_flow_imbalance2_std 4
# order_book_slope_mean 0
# order_book_slope_amax 1
# depth_imbalance1_sum 0
# depth_imbalance1_amax 0
# depth_imbalance1_std 0
# depth_imbalance2_sum 0
# depth_imbalance2_amax 0
# depth_imbalance2_std 0
# height_imbalance1_sum 6
# height_imbalance1_amax 1
# height_imbalance1_std 1
# height_imbalance2_sum 3
# height_imbalance2_amax 4
# height_imbalance2_std 3
# pressure_imbalance_sum 0
# pressure_imbalance_amax 0
# pressure_imbalance_std 0
# total_volume_sum 1
# seconds_gap_mean 0
# log_return1_realized_volatility_150 90
# log_return2_realized_volatility_150 44
# wap_balance_sum_150 8
# wap_balance_amax_150 2
# wap_balance_amin_150 4
# wap_balance_std_150 0
# bid_ask_spread1_sum_150 7
# bid_ask_spread1_amax_150 2
# bid_ask_spread1_amin_150 10
# bid_ask_spread1_std_150 0
# bid_ask_spread2_sum_150 4
# bid_ask_spread2_amax_150 3
# bid_ask_spread2_amin_150 0
# bid_ask_spread2_std_150 0
# order_flow_imbalance1_sum_150 0
# order_flow_imbalance1_amax_150 0
# order_flow_imbalance1_amin_150 0
# order_flow_imbalance1_std_150 3
# order_flow_imbalance2_sum_150 0
# order_flow_imbalance2_amax_150 0
# order_flow_imbalance2_amin_150 0
# order_flow_imbalance2_std_150 1
# total_volume_sum_150 3
# seconds_gap_mean_150 0
# log_return1_realized_volatility_300 51
# log_return2_realized_volatility_300 26
# wap_balance_sum_300 1
# wap_balance_amax_300 0
# wap_balance_amin_300 1
# wap_balance_std_300 0
# bid_ask_spread1_sum_300 7
# bid_ask_spread1_amax_300 1
# bid_ask_spread1_amin_300 10
# bid_ask_spread1_std_300 0
# bid_ask_spread2_sum_300 1
# bid_ask_spread2_amax_300 3
# bid_ask_spread2_amin_300 2
# bid_ask_spread2_std_300 0
# order_flow_imbalance1_sum_300 0
# order_flow_imbalance1_amax_300 0
# order_flow_imbalance1_amin_300 0
# order_flow_imbalance1_std_300 0
# order_flow_imbalance2_sum_300 0
# order_flow_imbalance2_amax_300 0
# order_flow_imbalance2_amin_300 1
# order_flow_imbalance2_std_300 1
# total_volume_sum_300 0
# seconds_gap_mean_300 0
# log_return1_realized_volatility_450 17
# log_return2_realized_volatility_450 25
# wap_balance_sum_450 0
# wap_balance_amax_450 5
# wap_balance_amin_450 0
# wap_balance_std_450 4
# bid_ask_spread1_sum_450 5
# bid_ask_spread1_amax_450 7
# bid_ask_spread1_amin_450 1
# bid_ask_spread1_std_450 1
# bid_ask_spread2_sum_450 1
# bid_ask_spread2_amax_450 9
# bid_ask_spread2_amin_450 1
# bid_ask_spread2_std_450 0
# order_flow_imbalance1_sum_450 0
# order_flow_imbalance1_amax_450 0
# order_flow_imbalance1_amin_450 0
# order_flow_imbalance1_std_450 1
# order_flow_imbalance2_sum_450 1
# order_flow_imbalance2_amax_450 0
# order_flow_imbalance2_amin_450 1
# order_flow_imbalance2_std_450 1
# total_volume_sum_450 0
# seconds_gap_mean_450 0
# trade_price_log_return_realized_volatility 32
# trade_volumes_sum 0
# trade_volumes_amax 4
# trade_volumes_std 2
# trade_order_count_sum 0
# trade_seconds_gap_mean 2
# trade_price_log_return_realized_volatility_150 10
# trade_volumes_sum_150 0
# trade_volumes_amax_150 2
# trade_volumes_std_150 2
# trade_order_count_sum_150 0
# trade_seconds_gap_mean_150 3
# trade_price_log_return_realized_volatility_300 8
# trade_volumes_sum_300 0
# trade_volumes_amax_300 1
# trade_volumes_std_300 0
# trade_order_count_sum_300 0
# trade_seconds_gap_mean_300 0
# trade_price_log_return_realized_volatility_450 22
# trade_volumes_sum_450 0
# trade_volumes_amax_450 1
# trade_volumes_std_450 0
# trade_order_count_sum_450 0
# trade_seconds_gap_mean_450 0
# trade_tendency 2
# trade_energy 0
# log_return1_realized_volatility_nanmean_stock 23
# log_return1_realized_volatility_150_nanmean_stock 36
# log_return1_realized_volatility_300_nanmean_stock 20
# log_return1_realized_volatility_450_nanmean_stock 31
# log_return1_realized_volatility_nanmean_time 2
# log_return1_realized_volatility_150_nanmean_time 1
# log_return1_realized_volatility_300_nanmean_time 6
# log_return1_realized_volatility_450_nanmean_time 22
# log_return1_realized_volatility_0_cluster_mean 2
# log_return1_realized_volatility_1_cluster_mean 4
# log_return1_realized_volatility_3_cluster_mean 6
# log_return1_realized_volatility_4_cluster_mean 0
# log_return1_realized_volatility_6_cluster_mean 2
# log_return2_realized_volatility_0_cluster_mean 4
# log_return2_realized_volatility_1_cluster_mean 1
# log_return2_realized_volatility_3_cluster_mean 13
# log_return2_realized_volatility_4_cluster_mean 1
# log_return2_realized_volatility_6_cluster_mean 0
# order_flow_imbalance1_sum_0_cluster_mean 2
# order_flow_imbalance1_sum_1_cluster_mean 0
# order_flow_imbalance1_sum_3_cluster_mean 0
# order_flow_imbalance1_sum_4_cluster_mean 2
# order_flow_imbalance1_sum_6_cluster_mean 0
# order_flow_imbalance2_sum_0_cluster_mean 13
# order_flow_imbalance2_sum_1_cluster_mean 1
# order_flow_imbalance2_sum_3_cluster_mean 43
# order_flow_imbalance2_sum_4_cluster_mean 4
# order_flow_imbalance2_sum_6_cluster_mean 2
# order_book_slope_mean_0_cluster_mean 4
# order_book_slope_mean_1_cluster_mean 0
# order_book_slope_mean_3_cluster_mean 10
# order_book_slope_mean_4_cluster_mean 1
# order_book_slope_mean_6_cluster_mean 0
# depth_imbalance1_std_0_cluster_mean 0
# depth_imbalance1_std_1_cluster_mean 1
# depth_imbalance1_std_3_cluster_mean 0
# depth_imbalance1_std_4_cluster_mean 0
# depth_imbalance1_std_6_cluster_mean 0
# depth_imbalance2_std_0_cluster_mean 1
# depth_imbalance2_std_1_cluster_mean 0
# depth_imbalance2_std_3_cluster_mean 18
# depth_imbalance2_std_4_cluster_mean 0
# depth_imbalance2_std_6_cluster_mean 0
# height_imbalance1_sum_0_cluster_mean 1
# height_imbalance1_sum_1_cluster_mean 2
# height_imbalance1_sum_3_cluster_mean 11
# height_imbalance1_sum_4_cluster_mean 0
# height_imbalance1_sum_6_cluster_mean 12
# height_imbalance2_sum_0_cluster_mean 0
# height_imbalance2_sum_1_cluster_mean 2
# height_imbalance2_sum_3_cluster_mean 29
# height_imbalance2_sum_4_cluster_mean 0
# height_imbalance2_sum_6_cluster_mean 1
# pressure_imbalance_std_0_cluster_mean 1
# pressure_imbalance_std_1_cluster_mean 0
# pressure_imbalance_std_3_cluster_mean 1
# pressure_imbalance_std_4_cluster_mean 0
# pressure_imbalance_std_6_cluster_mean 1
# total_volume_sum_0_cluster_mean 8
# total_volume_sum_1_cluster_mean 1
# total_volume_sum_3_cluster_mean 1
# total_volume_sum_4_cluster_mean 4
# total_volume_sum_6_cluster_mean 0
# seconds_gap_mean_0_cluster_mean 21
# seconds_gap_mean_1_cluster_mean 12
# seconds_gap_mean_3_cluster_mean 84
# seconds_gap_mean_4_cluster_mean 2
# seconds_gap_mean_6_cluster_mean 6
# trade_price_log_return_realized_volatility_0_cluster_mean 3
# trade_price_log_return_realized_volatility_1_cluster_mean 8
# trade_price_log_return_realized_volatility_3_cluster_mean 11
# trade_price_log_return_realized_volatility_4_cluster_mean 0
# trade_price_log_return_realized_volatility_6_cluster_mean 0
# trade_volumes_sum_0_cluster_mean 5
# trade_volumes_sum_1_cluster_mean 1
# trade_volumes_sum_3_cluster_mean 15
# trade_volumes_sum_4_cluster_mean 0
# trade_volumes_sum_6_cluster_mean 1
# trade_order_count_sum_0_cluster_mean 22
# trade_order_count_sum_1_cluster_mean 5
# trade_order_count_sum_3_cluster_mean 65
# trade_order_count_sum_4_cluster_mean 5
# trade_order_count_sum_6_cluster_mean 15
# trade_seconds_gap_mean_0_cluster_mean 5
# trade_seconds_gap_mean_1_cluster_mean 3
# trade_seconds_gap_mean_3_cluster_mean 14
# trade_seconds_gap_mean_4_cluster_mean 2
# trade_seconds_gap_mean_6_cluster_mean 2
# trade_tendency_0_cluster_mean 9
# trade_tendency_1_cluster_mean 0
# trade_tendency_3_cluster_mean 9
# trade_tendency_4_cluster_mean 1
# trade_tendency_6_cluster_mean 2
# trade_energy_0_cluster_mean 0
# trade_energy_1_cluster_mean 0
# trade_energy_3_cluster_mean 1
# trade_energy_4_cluster_mean 0
# trade_energy_6_cluster_mean 0
# log_return1_realized_volatility_0_cluster_max 0
# log_return1_realized_volatility_1_cluster_max 0
# log_return1_realized_volatility_3_cluster_max 1
# log_return1_realized_volatility_4_cluster_max 1
# log_return1_realized_volatility_6_cluster_max 0
# log_return2_realized_volatility_0_cluster_max 1
# log_return2_realized_volatility_1_cluster_max 0
# log_return2_realized_volatility_3_cluster_max 1
# log_return2_realized_volatility_4_cluster_max 2
# log_return2_realized_volatility_6_cluster_max 0
# order_flow_imbalance1_sum_0_cluster_max 0
# order_flow_imbalance1_sum_1_cluster_max 0
# order_flow_imbalance1_sum_3_cluster_max 0
# order_flow_imbalance1_sum_4_cluster_max 0
# order_flow_imbalance1_sum_6_cluster_max 0
# order_flow_imbalance2_sum_0_cluster_max 0
# order_flow_imbalance2_sum_1_cluster_max 1
# order_flow_imbalance2_sum_3_cluster_max 0
# order_flow_imbalance2_sum_4_cluster_max 2
# order_flow_imbalance2_sum_6_cluster_max 7
# order_book_slope_mean_0_cluster_max 0
# order_book_slope_mean_1_cluster_max 1
# order_book_slope_mean_3_cluster_max 1
# order_book_slope_mean_4_cluster_max 0
# order_book_slope_mean_6_cluster_max 0
# depth_imbalance1_std_0_cluster_max 2
# depth_imbalance1_std_1_cluster_max 0
# ...
# wap_balance_sum_450 3
# wap_balance_amax_450 2
# wap_balance_amin_450 1
# wap_balance_std_450 3
# bid_ask_spread1_sum_450 6
# bid_ask_spread1_amax_450 6
# bid_ask_spread1_amin_450 0
# bid_ask_spread1_std_450 0
# bid_ask_spread2_sum_450 3
# bid_ask_spread2_amax_450 9
# bid_ask_spread2_amin_450 1
# bid_ask_spread2_std_450 2
# order_flow_imbalance1_sum_450 0
# order_flow_imbalance1_amax_450 0
# order_flow_imbalance1_amin_450 1
# order_flow_imbalance1_std_450 1
# order_flow_imbalance2_sum_450 0
# order_flow_imbalance2_amax_450 0
# order_flow_imbalance2_amin_450 0
# order_flow_imbalance2_std_450 0
# total_volume_sum_450 0
# seconds_gap_mean_450 0
# trade_price_log_return_realized_volatility 29
# trade_volumes_sum 0
# trade_volumes_amax 7
# trade_volumes_std 3
# trade_order_count_sum 1
# trade_seconds_gap_mean 0
# trade_price_log_return_realized_volatility_150 8
# trade_volumes_sum_150 0
# trade_volumes_amax_150 2
# trade_volumes_std_150 0
# trade_order_count_sum_150 0
# trade_seconds_gap_mean_150 1
# trade_price_log_return_realized_volatility_300 5
# trade_volumes_sum_300 2
# trade_volumes_amax_300 3
# trade_volumes_std_300 0
# trade_order_count_sum_300 0
# trade_seconds_gap_mean_300 0
# trade_price_log_return_realized_volatility_450 24
# trade_volumes_sum_450 0
# trade_volumes_amax_450 0
# trade_volumes_std_450 0
# trade_order_count_sum_450 0
# trade_seconds_gap_mean_450 2
# trade_tendency 2
# trade_energy 0
# log_return1_realized_volatility_nanmean_stock 26
# log_return1_realized_volatility_150_nanmean_stock 36
# log_return1_realized_volatility_300_nanmean_stock 26
# log_return1_realized_volatility_450_nanmean_stock 30
# log_return1_realized_volatility_nanmean_time 0
# log_return1_realized_volatility_150_nanmean_time 0
# log_return1_realized_volatility_300_nanmean_time 10
# log_return1_realized_volatility_450_nanmean_time 27
# log_return1_realized_volatility_0_cluster_mean 0
# log_return1_realized_volatility_1_cluster_mean 0
# log_return1_realized_volatility_3_cluster_mean 2
# log_return1_realized_volatility_4_cluster_mean 4
# log_return1_realized_volatility_6_cluster_mean 1
# log_return2_realized_volatility_0_cluster_mean 9
# log_return2_realized_volatility_1_cluster_mean 1
# log_return2_realized_volatility_3_cluster_mean 9
# log_return2_realized_volatility_4_cluster_mean 2
# log_return2_realized_volatility_6_cluster_mean 0
# order_flow_imbalance1_sum_0_cluster_mean 0
# order_flow_imbalance1_sum_1_cluster_mean 0
# order_flow_imbalance1_sum_3_cluster_mean 0
# order_flow_imbalance1_sum_4_cluster_mean 0
# order_flow_imbalance1_sum_6_cluster_mean 0
# order_flow_imbalance2_sum_0_cluster_mean 9
# order_flow_imbalance2_sum_1_cluster_mean 1
# order_flow_imbalance2_sum_3_cluster_mean 35
# order_flow_imbalance2_sum_4_cluster_mean 4
# order_flow_imbalance2_sum_6_cluster_mean 0
# order_book_slope_mean_0_cluster_mean 2
# order_book_slope_mean_1_cluster_mean 3
# order_book_slope_mean_3_cluster_mean 10
# order_book_slope_mean_4_cluster_mean 1
# order_book_slope_mean_6_cluster_mean 0
# depth_imbalance1_std_0_cluster_mean 0
# depth_imbalance1_std_1_cluster_mean 2
# depth_imbalance1_std_3_cluster_mean 1
# depth_imbalance1_std_4_cluster_mean 0
# depth_imbalance1_std_6_cluster_mean 0
# depth_imbalance2_std_0_cluster_mean 0
# depth_imbalance2_std_1_cluster_mean 0
# depth_imbalance2_std_3_cluster_mean 19
# depth_imbalance2_std_4_cluster_mean 1
# depth_imbalance2_std_6_cluster_mean 0
# height_imbalance1_sum_0_cluster_mean 1
# height_imbalance1_sum_1_cluster_mean 0
# height_imbalance1_sum_3_cluster_mean 14
# height_imbalance1_sum_4_cluster_mean 1
# height_imbalance1_sum_6_cluster_mean 0
# height_imbalance2_sum_0_cluster_mean 0
# height_imbalance2_sum_1_cluster_mean 1
# height_imbalance2_sum_3_cluster_mean 20
# height_imbalance2_sum_4_cluster_mean 2
# height_imbalance2_sum_6_cluster_mean 1
# pressure_imbalance_std_0_cluster_mean 2
# pressure_imbalance_std_1_cluster_mean 0
# pressure_imbalance_std_3_cluster_mean 0
# pressure_imbalance_std_4_cluster_mean 0
# pressure_imbalance_std_6_cluster_mean 0
# total_volume_sum_0_cluster_mean 9
# total_volume_sum_1_cluster_mean 1
# total_volume_sum_3_cluster_mean 0
# total_volume_sum_4_cluster_mean 3
# total_volume_sum_6_cluster_mean 0
# seconds_gap_mean_0_cluster_mean 16
# seconds_gap_mean_1_cluster_mean 8
# seconds_gap_mean_3_cluster_mean 78
# seconds_gap_mean_4_cluster_mean 0
# seconds_gap_mean_6_cluster_mean 22
# trade_price_log_return_realized_volatility_0_cluster_mean 6
# trade_price_log_return_realized_volatility_1_cluster_mean 1
# trade_price_log_return_realized_volatility_3_cluster_mean 6
# trade_price_log_return_realized_volatility_4_cluster_mean 2
# trade_price_log_return_realized_volatility_6_cluster_mean 0
# trade_volumes_sum_0_cluster_mean 3
# trade_volumes_sum_1_cluster_mean 0
# trade_volumes_sum_3_cluster_mean 3
# trade_volumes_sum_4_cluster_mean 1
# trade_volumes_sum_6_cluster_mean 1
# trade_order_count_sum_0_cluster_mean 21
# trade_order_count_sum_1_cluster_mean 10
# trade_order_count_sum_3_cluster_mean 55
# trade_order_count_sum_4_cluster_mean 11
# trade_order_count_sum_6_cluster_mean 19
# trade_seconds_gap_mean_0_cluster_mean 18
# trade_seconds_gap_mean_1_cluster_mean 4
# trade_seconds_gap_mean_3_cluster_mean 26
# trade_seconds_gap_mean_4_cluster_mean 0
# trade_seconds_gap_mean_6_cluster_mean 6
# trade_tendency_0_cluster_mean 7
# trade_tendency_1_cluster_mean 0
# trade_tendency_3_cluster_mean 12
# trade_tendency_4_cluster_mean 0
# trade_tendency_6_cluster_mean 0
# trade_energy_0_cluster_mean 0
# trade_energy_1_cluster_mean 0
# trade_energy_3_cluster_mean 0
# trade_energy_4_cluster_mean 0
# trade_energy_6_cluster_mean 0
# log_return1_realized_volatility_0_cluster_max 0
# log_return1_realized_volatility_1_cluster_max 0
# log_return1_realized_volatility_3_cluster_max 1
# log_return1_realized_volatility_4_cluster_max 1
# log_return1_realized_volatility_6_cluster_max 0
# log_return2_realized_volatility_0_cluster_max 2
# log_return2_realized_volatility_1_cluster_max 0
# log_return2_realized_volatility_3_cluster_max 0
# log_return2_realized_volatility_4_cluster_max 0
# log_return2_realized_volatility_6_cluster_max 0
# order_flow_imbalance1_sum_0_cluster_max 1
# order_flow_imbalance1_sum_1_cluster_max 0
# order_flow_imbalance1_sum_3_cluster_max 0
# order_flow_imbalance1_sum_4_cluster_max 0
# order_flow_imbalance1_sum_6_cluster_max 0
# order_flow_imbalance2_sum_0_cluster_max 0
# order_flow_imbalance2_sum_1_cluster_max 0
# order_flow_imbalance2_sum_3_cluster_max 0
# order_flow_imbalance2_sum_4_cluster_max 0
# order_flow_imbalance2_sum_6_cluster_max 5
# order_book_slope_mean_0_cluster_max 0
# order_book_slope_mean_1_cluster_max 1
# order_book_slope_mean_3_cluster_max 0
# order_book_slope_mean_4_cluster_max 0
# order_book_slope_mean_6_cluster_max 0
# depth_imbalance1_std_0_cluster_max 0
# depth_imbalance1_std_1_cluster_max 0
# depth_imbalance1_std_3_cluster_max 0
# depth_imbalance1_std_4_cluster_max 0
# depth_imbalance1_std_6_cluster_max 0
# depth_imbalance2_std_0_cluster_max 0
# depth_imbalance2_std_1_cluster_max 0
# depth_imbalance2_std_3_cluster_max 0
# depth_imbalance2_std_4_cluster_max 0
# depth_imbalance2_std_6_cluster_max 0
# height_imbalance1_sum_0_cluster_max 0
# height_imbalance1_sum_1_cluster_max 1
# height_imbalance1_sum_3_cluster_max 5
# height_imbalance1_sum_4_cluster_max 1
# height_imbalance1_sum_6_cluster_max 2
# height_imbalance2_sum_0_cluster_max 5
# height_imbalance2_sum_1_cluster_max 1
# height_imbalance2_sum_3_cluster_max 17
# height_imbalance2_sum_4_cluster_max 1
# height_imbalance2_sum_6_cluster_max 3
# pressure_imbalance_std_0_cluster_max 1
# pressure_imbalance_std_1_cluster_max 1
# pressure_imbalance_std_3_cluster_max 0
# pressure_imbalance_std_4_cluster_max 0
# pressure_imbalance_std_6_cluster_max 0
# total_volume_sum_0_cluster_max 16
# total_volume_sum_1_cluster_max 1
# total_volume_sum_3_cluster_max 2
# total_volume_sum_4_cluster_max 9
# total_volume_sum_6_cluster_max 0
# seconds_gap_mean_0_cluster_max 1
# seconds_gap_mean_1_cluster_max 0
# seconds_gap_mean_3_cluster_max 9
# seconds_gap_mean_4_cluster_max 1
# seconds_gap_mean_6_cluster_max 1
# trade_price_log_return_realized_volatility_0_cluster_max 0
# trade_price_log_return_realized_volatility_1_cluster_max 0
# trade_price_log_return_realized_volatility_3_cluster_max 0
# trade_price_log_return_realized_volatility_4_cluster_max 2
# trade_price_log_return_realized_volatility_6_cluster_max 1
# trade_volumes_sum_0_cluster_max 0
# trade_volumes_sum_1_cluster_max 2
# trade_volumes_sum_3_cluster_max 3
# trade_volumes_sum_4_cluster_max 0
# trade_volumes_sum_6_cluster_max 0
# trade_order_count_sum_0_cluster_max 0
# trade_order_count_sum_1_cluster_max 0
# trade_order_count_sum_3_cluster_max 2
# trade_order_count_sum_4_cluster_max 0
# trade_order_count_sum_6_cluster_max 1
# trade_seconds_gap_mean_0_cluster_max 1
# trade_seconds_gap_mean_1_cluster_max 0
# trade_seconds_gap_mean_3_cluster_max 3
# trade_seconds_gap_mean_4_cluster_max 1
# trade_seconds_gap_mean_6_cluster_max 1
# trade_tendency_0_cluster_max 0
# trade_tendency_1_cluster_max 0
# trade_tendency_3_cluster_max 1
# trade_tendency_4_cluster_max 0
# trade_tendency_6_cluster_max 0
# trade_energy_0_cluster_max 1
# trade_energy_1_cluster_max 0
# trade_energy_3_cluster_max 0
# trade_energy_4_cluster_max 1
# trade_energy_6_cluster_max 2
# log_return1_realized_volatility_0_cluster_min 4
# log_return1_realized_volatility_1_cluster_min 0
# log_return1_realized_volatility_3_cluster_min 17
# log_return1_realized_volatility_4_cluster_min 8
# log_return1_realized_volatility_6_cluster_min 1
# log_return2_realized_volatility_0_cluster_min 0
# log_return2_realized_volatility_1_cluster_min 0
# log_return2_realized_volatility_3_cluster_min 9
# log_return2_realized_volatility_4_cluster_min 1
# log_return2_realized_volatility_6_cluster_min 0
# order_flow_imbalance1_sum_0_cluster_min 0
# order_flow_imbalance1_sum_1_cluster_min 0
# order_flow_imbalance1_sum_3_cluster_min 0
# order_flow_imbalance1_sum_4_cluster_min 0
# order_flow_imbalance1_sum_6_cluster_min 0
# order_flow_imbalance2_sum_0_cluster_min 1
# order_flow_imbalance2_sum_1_cluster_min 0
# order_flow_imbalance2_sum_3_cluster_min 0
# order_flow_imbalance2_sum_4_cluster_min 0
# order_flow_imbalance2_sum_6_cluster_min 0
# order_book_slope_mean_0_cluster_min 0
# order_book_slope_mean_1_cluster_min 0
# order_book_slope_mean_3_cluster_min 3
# order_book_slope_mean_4_cluster_min 1
# order_book_slope_mean_6_cluster_min 0
# depth_imbalance1_std_0_cluster_min 0
# depth_imbalance1_std_1_cluster_min 0
# depth_imbalance1_std_3_cluster_min 0
# depth_imbalance1_std_4_cluster_min 0
# depth_imbalance1_std_6_cluster_min 1
# depth_imbalance2_std_0_cluster_min 10
# depth_imbalance2_std_1_cluster_min 1
# depth_imbalance2_std_3_cluster_min 1
# depth_imbalance2_std_4_cluster_min 0
# depth_imbalance2_std_6_cluster_min 0
# height_imbalance1_sum_0_cluster_min 0
# height_imbalance1_sum_1_cluster_min 1
# height_imbalance1_sum_3_cluster_min 3
# height_imbalance1_sum_4_cluster_min 0
# height_imbalance1_sum_6_cluster_min 2
# height_imbalance2_sum_0_cluster_min 1
# height_imbalance2_sum_1_cluster_min 0
# height_imbalance2_sum_3_cluster_min 15
# height_imbalance2_sum_4_cluster_min 0
# height_imbalance2_sum_6_cluster_min 1
# pressure_imbalance_std_0_cluster_min 0
# pressure_imbalance_std_1_cluster_min 0
# pressure_imbalance_std_3_cluster_min 0
# pressure_imbalance_std_4_cluster_min 0
# pressure_imbalance_std_6_cluster_min 0
# total_volume_sum_0_cluster_min 1
# total_volume_sum_1_cluster_min 0
# total_volume_sum_3_cluster_min 0
# total_volume_sum_4_cluster_min 0
# total_volume_sum_6_cluster_min 10
# seconds_gap_mean_0_cluster_min 0
# seconds_gap_mean_1_cluster_min 0
# seconds_gap_mean_3_cluster_min 0
# seconds_gap_mean_4_cluster_min 1
# seconds_gap_mean_6_cluster_min 3
# trade_price_log_return_realized_volatility_0_cluster_min 2
# trade_price_log_return_realized_volatility_1_cluster_min 1
# trade_price_log_return_realized_volatility_3_cluster_min 10
# trade_price_log_return_realized_volatility_4_cluster_min 0
# trade_price_log_return_realized_volatility_6_cluster_min 0
# trade_volumes_sum_0_cluster_min 0
# trade_volumes_sum_1_cluster_min 1
# trade_volumes_sum_3_cluster_min 0
# trade_volumes_sum_4_cluster_min 0
# trade_volumes_sum_6_cluster_min 5
# trade_order_count_sum_0_cluster_min 2
# trade_order_count_sum_1_cluster_min 0
# trade_order_count_sum_3_cluster_min 8
# trade_order_count_sum_4_cluster_min 7
# trade_order_count_sum_6_cluster_min 6
# trade_seconds_gap_mean_0_cluster_min 4
# trade_seconds_gap_mean_1_cluster_min 5
# trade_seconds_gap_mean_3_cluster_min 23
# trade_seconds_gap_mean_4_cluster_min 1
# trade_seconds_gap_mean_6_cluster_min 0
# trade_tendency_0_cluster_min 0
# trade_tendency_1_cluster_min 0
# trade_tendency_3_cluster_min 4
# trade_tendency_4_cluster_min 0
# trade_tendency_6_cluster_min 0
# trade_energy_0_cluster_min 0
# trade_energy_1_cluster_min 0
# trade_energy_3_cluster_min 3
# trade_energy_4_cluster_min 0
# trade_energy_6_cluster_min 0
# log_return1_realized_volatility_0_cluster_std 0
# log_return1_realized_volatility_1_cluster_std 0
# log_return1_realized_volatility_3_cluster_std 1
# log_return1_realized_volatility_4_cluster_std 0
# log_return1_realized_volatility_6_cluster_std 0
# log_return2_realized_volatility_0_cluster_std 3
# log_return2_realized_volatility_1_cluster_std 0
# log_return2_realized_volatility_3_cluster_std 1
# log_return2_realized_volatility_4_cluster_std 2
# log_return2_realized_volatility_6_cluster_std 1
# order_flow_imbalance1_sum_0_cluster_std 0
# order_flow_imbalance1_sum_1_cluster_std 0
# order_flow_imbalance1_sum_3_cluster_std 1
# order_flow_imbalance1_sum_4_cluster_std 0
# order_flow_imbalance1_sum_6_cluster_std 0
# order_flow_imbalance2_sum_0_cluster_std 0
# order_flow_imbalance2_sum_1_cluster_std 0
# order_flow_imbalance2_sum_3_cluster_std 0
# order_flow_imbalance2_sum_4_cluster_std 0
# order_flow_imbalance2_sum_6_cluster_std 16
# order_book_slope_mean_0_cluster_std 1
# order_book_slope_mean_1_cluster_std 2
# order_book_slope_mean_3_cluster_std 0
# order_book_slope_mean_4_cluster_std 0
# order_book_slope_mean_6_cluster_std 1
# depth_imbalance1_std_0_cluster_std 12
# depth_imbalance1_std_1_cluster_std 0
# depth_imbalance1_std_3_cluster_std 5
# depth_imbalance1_std_4_cluster_std 0
# depth_imbalance1_std_6_cluster_std 0
# depth_imbalance2_std_0_cluster_std 4
# depth_imbalance2_std_1_cluster_std 1
# depth_imbalance2_std_3_cluster_std 3
# depth_imbalance2_std_4_cluster_std 0
# depth_imbalance2_std_6_cluster_std 0
# height_imbalance1_sum_0_cluster_std 1
# height_imbalance1_sum_1_cluster_std 0
# height_imbalance1_sum_3_cluster_std 1
# height_imbalance1_sum_4_cluster_std 1
# height_imbalance1_sum_6_cluster_std 0
# height_imbalance2_sum_0_cluster_std 1
# height_imbalance2_sum_1_cluster_std 1
# height_imbalance2_sum_3_cluster_std 1
# height_imbalance2_sum_4_cluster_std 0
# height_imbalance2_sum_6_cluster_std 0
# pressure_imbalance_std_0_cluster_std 1
# pressure_imbalance_std_1_cluster_std 0
# pressure_imbalance_std_3_cluster_std 0
# pressure_imbalance_std_4_cluster_std 0
# pressure_imbalance_std_6_cluster_std 0
# total_volume_sum_0_cluster_std 5
# total_volume_sum_1_cluster_std 0
# total_volume_sum_3_cluster_std 3
# total_volume_sum_4_cluster_std 0
# total_volume_sum_6_cluster_std 0
# seconds_gap_mean_0_cluster_std 16
# seconds_gap_mean_1_cluster_std 0
# seconds_gap_mean_3_cluster_std 19
# seconds_gap_mean_4_cluster_std 0
# seconds_gap_mean_6_cluster_std 7
# trade_price_log_return_realized_volatility_0_cluster_std 0
# trade_price_log_return_realized_volatility_1_cluster_std 0
# trade_price_log_return_realized_volatility_3_cluster_std 1
# trade_price_log_return_realized_volatility_4_cluster_std 1
# trade_price_log_return_realized_volatility_6_cluster_std 0
# trade_volumes_sum_0_cluster_std 2
# trade_volumes_sum_1_cluster_std 0
# trade_volumes_sum_3_cluster_std 0
# trade_volumes_sum_4_cluster_std 0
# trade_volumes_sum_6_cluster_std 4
# trade_order_count_sum_0_cluster_std 0
# trade_order_count_sum_1_cluster_std 0
# trade_order_count_sum_3_cluster_std 0
# trade_order_count_sum_4_cluster_std 0
# trade_order_count_sum_6_cluster_std 0
# trade_seconds_gap_mean_0_cluster_std 1
# trade_seconds_gap_mean_1_cluster_std 0
# trade_seconds_gap_mean_3_cluster_std 1
# trade_seconds_gap_mean_4_cluster_std 0
# trade_seconds_gap_mean_6_cluster_std 1
# trade_tendency_0_cluster_std 0
# trade_tendency_1_cluster_std 0
# trade_tendency_3_cluster_std 0
# trade_tendency_4_cluster_std 0
# trade_tendency_6_cluster_std 0
# trade_energy_0_cluster_std 18
# trade_energy_1_cluster_std 2
# trade_energy_3_cluster_std 8
# trade_energy_4_cluster_std 14
# trade_energy_6_cluster_std 1
# Our out of folds RMSPE is 0.2331587574198586

# %%
# Kfold Our out of folds RMSPE is 0.2331587574198586
