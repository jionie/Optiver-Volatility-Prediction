# %%
import os
import gc
import glob
from joblib import Parallel, delayed, dump, load
import pandas as pd
from pandas.core.common import flatten
from collections import OrderedDict
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, QuantileTransformer
from sklearn.cluster import KMeans
import scipy as sc
from sklearn.model_selection import KFold, GroupKFold
import lightgbm as lgb
import warnings
warnings.filterwarnings("ignore")
pd.set_option("max_columns", 300)

# %% [markdown]
# # Parameters

# %%
CONFIG = {
    "root_dir": "../../input/optiver-realized-volatility-prediction/",
    "ckpt_dir": "../../ckpts",
    "kfold_seed": 42,
    "n_splits": 5,
    "n_clusters": 7,
    "shuffle": False,
    "shuffle_seed": 1996
}

# PARAMS = {
#         "objective": "rmse",
#         "boosting_type": "gbdt",
#         "max_depth": -1,
#         "max_bin":100,
#         "min_data_in_leaf":500,
#         "learning_rate": 0.05,
#         "subsample": 0.72,
#         "subsample_freq": 4,
#         "feature_fraction": 0.5,
#         "lambda_l1": 0.5,
#         "lambda_l2": 1.0,
#         "categorical_column":[0],
#         "seed":2021,
#         "feature_fraction_seed": 2021,
#         "bagging_seed": 2021,
#         "drop_seed": 2021,
#         "data_random_seed": 2021,
#         "n_jobs":-1,
#         "verbose": -1
# }   

PARAMS = {
        "objective": "rmse",
        "boosting_type": "gbdt",
        "max_depth": -1, # 4 to 20
        "max_bin":318, # 40 to 400
        "min_data_in_leaf":2000, # 100 to 2000
        "learning_rate": 0.01, # 0.01 to 0.1
        "subsample": 0.66, # 0.3 to 0.9
        "subsample_freq": 3, # 0 to 30
        "feature_fraction": 0.567, # 0.5 to 0.9
        "lambda_l1": 1.27, # 0.0 to 3.0
        "lambda_l2": 0.475, # 0.0 to 3.0
        "categorical_column":[0],
        "seed":2021,
        "feature_fraction_seed": 2021,
        "bagging_seed": 2021,
        "drop_seed": 2021,
        "data_random_seed": 2021,
        "n_jobs":-1,
        "verbose": -1
}

# %% [markdown]
# # Read train test

# %%
def read_train_test():
    
    train = pd.read_csv("../../input/optiver-realized-volatility-prediction/train.csv")
    test = pd.read_csv("../../input/optiver-realized-volatility-prediction/test.csv")
    
    # Create a key to merge with book and trade data
    train["row_id"] = train["stock_id"].astype(str) + "-" + train["time_id"].astype(str)
    test["row_id"] = test["stock_id"].astype(str) + "-" + test["time_id"].astype(str)
    
    print("Our training set has {} rows".format(train.shape[0]))
    
    return train, test

# %% [markdown]
# # Define basic metric function

# %%
def activity_counts(df):
    activity_counts_ = df.groupby(["time_id"])["seconds_in_bucket"].agg("count").reset_index()
    activity_counts_ = activity_counts_.rename(columns={"seconds_in_bucket": "activity_counts"})
    return activity_counts_


def calc_wap(df, pos=1):
    wap = (df["bid_price{}".format(pos)] * df["ask_size{}".format(pos)] + df["ask_price{}".format(pos)] * df[
        "bid_size{}".format(pos)]) / (df["bid_size{}".format(pos)] + df["ask_size{}".format(pos)])
    return wap


def calc_wap2(df, pos=1):
    wap = (df["bid_price{}".format(pos)] * df["bid_size{}".format(pos)] + df["ask_price{}".format(pos)] * df[
        "ask_size{}".format(pos)]) / (df["bid_size{}".format(pos)] + df["ask_size{}".format(pos)])
    return wap


def wp(df):
    wp_ = (df["bid_price1"] * df["bid_size1"] + df["ask_price1"] * df["ask_size1"] + df["bid_price2"] * df[
        "bid_size2"] + df["ask_price2"] * df["ask_size2"]) / (
                  df["bid_size1"] + df["ask_size1"] + df["bid_size2"] + df["ask_size2"])
    return wp_


def maximum_drawdown(series, window=600):
    # window for 10 minutes, use min_periods=1 if you want to allow the expanding window
    roll_max = series.rolling(window, min_periods=1).max()
    second_drawdown = series / roll_max - 1.0
    max_drawdown = second_drawdown.rolling(window, min_periods=1).min()

    return max_drawdown


def log_return(series):
    return np.log(series).diff().fillna(0)


def rolling_log_return(series, rolling=60):
    return np.log(series.rolling(rolling)).diff().fillna(0)


def realized_volatility(series):
    return np.sqrt(np.sum(series ** 2))


def diff(series):
    return series.diff().fillna(0)


def time_diff(series):
    return series.diff().fillna(series)


def order_flow_imbalance(df, pos=1):
    df["bid_price{}_diff".format(pos)] = df.groupby(["time_id"])["bid_price{}".format(pos)].apply(diff)
    df["bid_size{}_diff".format(pos)] = df.groupby(["time_id"])["bid_price{}".format(pos)].apply(diff)
    df["bid_order_flow{}".format(pos)] = df["bid_size{}".format(pos)].copy(deep=True)
    df["bid_order_flow{}".format(pos)].loc[df["bid_price{}_diff".format(pos)] < 0] *= -1
    df["bid_order_flow{}".format(pos)].loc[df["bid_price{}_diff".format(pos)] == 0] = \
        df["bid_size{}_diff".format(pos)].loc[df["bid_price{}_diff".format(pos)] == 0]

    df["ask_price{}_diff".format(pos)] = df.groupby(["time_id"])["ask_price{}".format(pos)].apply(diff)
    df["ask_size{}_diff".format(pos)] = df.groupby(["time_id"])["ask_price{}".format(pos)].apply(diff)
    df["ask_order_flow{}".format(pos)] = df["ask_size{}".format(pos)].copy(deep=True)
    df["ask_order_flow{}".format(pos)].loc[df["ask_price{}_diff".format(pos)] < 0] *= -1
    df["ask_order_flow{}".format(pos)].loc[df["ask_price{}_diff".format(pos)] == 0] = \
        df["ask_size{}_diff".format(pos)].loc[df["ask_price{}_diff".format(pos)] == 0]

    order_flow_imbalance_ = df["bid_order_flow{}".format(pos)] - df["ask_order_flow{}".format(pos)]

    df.drop(["bid_price{}_diff".format(pos), "bid_size{}_diff".format(pos), "bid_order_flow{}".format(pos),
             "ask_price{}_diff".format(pos), "ask_size{}_diff".format(pos), "ask_order_flow{}".format(pos)], axis=1,
            inplace=True)

    return order_flow_imbalance_ + 1e-8


def order_book_slope(df):

    df["mid_point"] = (df["bid_price1"] + df["ask_price1"]) / 2
    best_mid_point_ = df.groupby(["time_id"])["mid_point"].agg("max").reset_index()
    best_mid_point_ = best_mid_point_.rename(columns={"mid_point": "best_mid_point"})
    df = df.merge(best_mid_point_, how="left", on="time_id")

    best_mid_point = df["best_mid_point"].copy()
    df.drop(["mid_point", "best_mid_point"], axis=1, inplace=True)

    def ratio(series):
        ratio_ = series / series.shift()
        return ratio_

    bid_price1_ratio = df.groupby(["time_id"])["bid_price1"].apply(ratio)
    bid_price1_mid_point_ratio = df["bid_price1"] / best_mid_point
    bid_price1_ratio = abs(bid_price1_ratio.fillna(bid_price1_mid_point_ratio) - 1)

    bid_size1_ratio = df.groupby(["time_id"])["bid_size1"].apply(ratio) - 1
    bid_size1_ratio = bid_size1_ratio.fillna(df["bid_size1"])
    df["DE"] = (bid_size1_ratio / bid_price1_ratio).replace([np.inf, -np.inf], np.nan).fillna(0)

    ask_price1_ratio = df.groupby(["time_id"])["ask_price1"].apply(ratio)
    ask_price1_mid_point_ratio = df["ask_price1"] / best_mid_point
    ask_price1_ratio = abs(ask_price1_ratio.fillna(ask_price1_mid_point_ratio) - 1)

    ask_size1_ratio = df.groupby(["time_id"])["ask_size1"].apply(ratio) - 1
    ask_size1_ratio = ask_size1_ratio.fillna(df["ask_size1"])
    df["SE"] = (ask_size1_ratio / ask_price1_ratio).replace([np.inf, -np.inf], np.nan).fillna(0)

    df["order_book_slope"] = (df["DE"] + df["SE"]) / 2
    order_book_slope_ = df.groupby(["time_id"])["order_book_slope"].agg("mean").reset_index()
    df.drop(["order_book_slope", "DE", "SE"], axis=1, inplace=True)

    return order_book_slope_


def ldispersion(df):
    LDispersion = 1 / 2 * (
            df["bid_size1"] / (df["bid_size1"] + df["bid_size2"]) * abs(df["bid_price1"] - df["bid_price2"]) + df[
        "ask_size1"] / (df["ask_size1"] + df["ask_size2"]) * abs(df["ask_price1"] - df["ask_price2"]))
    return LDispersion


def depth_imbalance(df, pos=1):
    depth_imbalance_ = (df["bid_size{}".format(pos)] - df["ask_size{}".format(pos)]) / (
            df["bid_size{}".format(pos)] + df["ask_size{}".format(pos)])

    return depth_imbalance_


def height_imbalance(df, pos=1):
    height_imbalance_ = (df["bid_price{}".format(pos)] - df["ask_price{}".format(pos)]) / (
            df["bid_price{}".format(pos)] + df["ask_price{}".format(pos)])

    return height_imbalance_


def pressure_imbalance(df):
    mid_price = (df["bid_price1"] + df["ask_price1"]) / 2

    weight_buy = mid_price / (mid_price - df["bid_price1"]) + mid_price / (mid_price - df["bid_price2"])
    pressure_buy = df["bid_size1"] * (mid_price / (mid_price - df["bid_price1"])) / weight_buy + df["bid_size2"] * (
            mid_price / (mid_price - df["bid_price2"])) / weight_buy

    weight_sell = mid_price / (df["ask_price1"] - mid_price) + mid_price / (df["ask_price2"] - mid_price)
    pressure_sell = df["ask_size1"] * (mid_price / (df["ask_price1"] - mid_price)) / weight_sell + df["ask_size2"] * (
            mid_price / (df["ask_price2"] - mid_price)) / weight_sell

    pressure_imbalance_ = np.log(pressure_buy) - np.log(pressure_sell)

    return pressure_imbalance_


def relative_spread(df, pos=1):
    relative_spread_ = 2 * (df["ask_price{}".format(pos)] - df["bid_price{}".format(pos)]) / (
            df["ask_price{}".format(pos)] + df["bid_price{}".format(pos)])

    return relative_spread_


def count_unique(series):
    return len(np.unique(series))

# %%
# df = pd.read_parquet("../../input/optiver-realized-volatility-prediction/book_train.parquet/stock_id=0")
# df["order_flow_imbalance1"] = order_flow_imbalance(df, 1)
# df["order_flow_imbalance2"] = order_flow_imbalance(df, 2)

# %% [markdown]
# # Processor

# %%
# Function to fill missing seconds (for each stock id)
def fill_missing_seconds(df):
    
    time_ids = list(OrderedDict.fromkeys(df["time_id"]))
    
    filled_df = pd.DataFrame(index=range(len(time_ids) * 600), columns=df.columns)
    
    all_seconds_in_bucket = list(flatten([range(600) for i in range(len(time_ids))]))
    filled_df["seconds_in_bucket"] = all_seconds_in_bucket
    
    all_time_ids = list(flatten([[time_ids[i]] * 600 for i in range(len(time_ids))]))
    filled_df["time_id"] = all_time_ids
    
    filled_df = pd.merge(filled_df, df, on=["time_id", "seconds_in_bucket"], how="left", suffixes=("_to_move", ""))
    
    to_remove_columns = [column for column in filled_df.columns if "to_move" in column]
    filled_df = filled_df.drop(to_remove_columns, axis=1)
    
    filled_df = filled_df.fillna(method="ffill")
    
    return filled_df

# %%
# Function to preprocess book data (for each stock id)
def book_preprocessor(file_path):
    df = pd.read_parquet(file_path)

    # float 64 to float 32
    float_cols = df.select_dtypes(include=[np.float64]).columns
    df[float_cols] = df[float_cols].astype(np.float32)

    # int 64 to int 32
    int_cols = df.select_dtypes(include=[np.int64]).columns
    df[int_cols] = df[int_cols].astype(np.int32)
    
    # rebase seconds_in_bucket
    df["seconds_in_bucket"] = df["seconds_in_bucket"] - df["seconds_in_bucket"].min()

    # Calculate seconds gap
    df["seconds_gap"] = df.groupby(["time_id"])["seconds_in_bucket"].apply(time_diff)

    # Calculate Wap
    df["wap1"] = calc_wap(df, pos=1)
    df["wap2"] = calc_wap(df, pos=2)

    # Calculate wap balance
    df["wap_balance"] = abs(df["wap1"] - df["wap2"])

    # Calculate log returns
    df["log_return1"] = df.groupby(["time_id"])["wap1"].apply(log_return)
    df["log_return2"] = df.groupby(["time_id"])["wap2"].apply(log_return)

    # Calculate spread
    df["bid_ask_spread1"] = df["ask_price1"] / df["bid_price1"] - 1
    df["bid_ask_spread2"] = df["ask_price2"] / df["bid_price2"] - 1

    # order flow imbalance
    df["order_flow_imbalance1"] = order_flow_imbalance(df, 1)
    df["order_flow_imbalance2"] = order_flow_imbalance(df, 2)

    # order book slope
    order_slope_ = order_book_slope(df)
    df = df.merge(order_slope_, how="left", on="time_id")

    # depth imbalance
    df["depth_imbalance1"] = depth_imbalance(df, pos=1)
    df["depth_imbalance2"] = depth_imbalance(df, pos=2)

    # height imbalance
    df["height_imbalance1"] = height_imbalance(df, pos=1)
    df["height_imbalance2"] = height_imbalance(df, pos=2)

    # pressure imbalance
    df["pressure_imbalance"] = pressure_imbalance(df)

    # total volume
    df["total_volume"] = (df["ask_size1"] + df["ask_size2"]) + (df["bid_size1"] + df["bid_size2"])

    # Dict for aggregations
    create_feature_dict = {
        "wap1": [np.sum, np.std],
        "wap2": [np.sum, np.std],
        "log_return1": [realized_volatility],
        "log_return2": [realized_volatility],
        "wap_balance": [np.sum, np.max, np.min, np.std],
        "bid_ask_spread1": [np.sum, np.max, np.min, np.std],
        "bid_ask_spread2": [np.sum, np.max, np.min, np.std],
        "order_flow_imbalance1": [np.sum, np.max, np.min, np.std],
        "order_flow_imbalance2": [np.sum, np.max, np.min, np.std],
        "order_book_slope": [np.mean, np.max],
        "depth_imbalance1": [np.sum, np.max, np.std],
        "depth_imbalance2": [np.sum, np.max, np.std],
        "height_imbalance1": [np.sum, np.max, np.std],
        "height_imbalance2": [np.sum, np.max, np.std],
        "pressure_imbalance": [np.sum, np.max, np.std],
        "total_volume": [np.sum],
        "seconds_gap": [np.mean]
    }
    create_feature_dict_time = {
        "log_return1": [realized_volatility],
        "log_return2": [realized_volatility],
        "wap_balance": [np.sum, np.max, np.min, np.std],
        "bid_ask_spread1": [np.sum, np.max, np.min, np.std],
        "bid_ask_spread2": [np.sum, np.max, np.min, np.std],
        "order_flow_imbalance1": [np.sum, np.max, np.min, np.std],
        "order_flow_imbalance2": [np.sum, np.max, np.min, np.std],
        "total_volume": [np.sum],
        "seconds_gap": [np.mean]
    }

    # Function to get group stats for different windows (seconds in bucket)
    def get_stats_window(feature_dict, seconds_in_bucket, add_suffix=False):
        # Group by the window
        df_feature_ = df[df["seconds_in_bucket"] >= seconds_in_bucket].groupby(["time_id"]).agg(
            feature_dict).reset_index()
        # Rename columns joining suffix
        df_feature_.columns = ["_".join(col) for col in df_feature_.columns]
        # Add a suffix to differentiate windows
        if add_suffix:
            df_feature_ = df_feature_.add_suffix("_" + str(seconds_in_bucket))
        return df_feature_

    # Get the stats for different windows
    windows = [0, 150, 300, 450]
    add_suffixes = [False, True, True, True]
    df_feature = None

    for window, add_suffix in zip(windows, add_suffixes):
        if df_feature is None:
            df_feature = get_stats_window(feature_dict=create_feature_dict, seconds_in_bucket=window,
                                          add_suffix=add_suffix)
        else:
            new_df_feature = get_stats_window(feature_dict=create_feature_dict_time, seconds_in_bucket=window,
                                              add_suffix=add_suffix)
            df_feature = df_feature.merge(new_df_feature, how="left", left_on="time_id_",
                                          right_on="time_id__{}".format(window))

            # Drop unnecesary time_ids
            df_feature.drop(["time_id__{}".format(window)], axis=1, inplace=True)

    # Create row_id so we can merge
    stock_id = file_path.split("=")[1]
    df_feature["row_id"] = df_feature["time_id_"].apply(lambda x: f"{stock_id}-{x}")
    df_feature.drop(["time_id_"], axis=1, inplace=True)

    return df_feature

# %%
# Function to preprocess trade data (for each stock id)
def trade_preprocessor(file_path):
    df = pd.read_parquet(file_path)

    # float 64 to float 32
    float_cols = df.select_dtypes(include=[np.float64]).columns
    df[float_cols] = df[float_cols].astype(np.float32)

    # int 64 to int 32
    int_cols = df.select_dtypes(include=[np.int64]).columns
    df[int_cols] = df[int_cols].astype(np.int32)
    
    # rebase seconds_in_bucket
    df["seconds_in_bucket"] = df["seconds_in_bucket"] - df["seconds_in_bucket"].min()

    # Calculate seconds gap
    df["seconds_gap"] = df.groupby(["time_id"])["seconds_in_bucket"].apply(time_diff)

    # Calculate log return
    df["price_log_return"] = df.groupby("time_id")["price"].apply(log_return)

    # Calculate volumes
    df["volumes"] = df["price"] * df["size"]

    # Dict for aggregations
    create_feature_dict = {
        "price_log_return": [realized_volatility],
        "volumes": [np.sum, np.max, np.std],
        "order_count": [np.sum],
        "seconds_gap": [np.mean]
    }
    create_feature_dict_time = {
        "price_log_return": [realized_volatility],
        "volumes": [np.sum, np.max, np.std],
        "order_count": [np.sum],
        "seconds_gap": [np.mean]
    }

    # Function to get group stats for different windows (seconds in bucket)
    def get_stats_window(feature_dict, seconds_in_bucket, add_suffix=False):
        # Group by the window
        df_feature_ = df[df["seconds_in_bucket"] >= seconds_in_bucket].groupby(["time_id"]).agg(
            feature_dict).reset_index()
        # Rename columns joining suffix
        df_feature_.columns = ["_".join(col) for col in df_feature_.columns]
        # Add a suffix to differentiate windows
        if add_suffix:
            df_feature_ = df_feature_.add_suffix("_" + str(seconds_in_bucket))
        return df_feature_

    # Get the stats for different windows
    windows = [0, 150, 300, 450]
    add_suffixes = [False, True, True, True]
    df_feature = None

    for window, add_suffix in zip(windows, add_suffixes):
        if df_feature is None:
            df_feature = get_stats_window(feature_dict=create_feature_dict, seconds_in_bucket=window,
                                          add_suffix=add_suffix)
        else:
            new_df_feature = get_stats_window(feature_dict=create_feature_dict_time, seconds_in_bucket=window,
                                              add_suffix=add_suffix)
            df_feature = df_feature.merge(new_df_feature, how="left", left_on="time_id_",
                                          right_on="time_id__{}".format(window))

            # Drop unnecesary time_ids
            df_feature.drop(["time_id__{}".format(window)], axis=1, inplace=True)

    def tendency(price, vol):
        df_diff = np.diff(price)
        val = (df_diff / price[1:]) * 100
        power = np.sum(val * vol[1:])
        return (power)

    lis = []
    for n_time_id in df["time_id"].unique():
        
        df_id = df[df["time_id"] == n_time_id]
        
        tendencyV = tendency(df_id["price"].values, df_id["size"].values)
        energy = np.mean(df_id["price"].values ** 2)

        lis.append(
            {
                "time_id": n_time_id,
                "tendency": tendencyV,
                "energy": energy,
            }
        )

    df_lr = pd.DataFrame(lis)
    df_feature = df_feature.merge(df_lr, how="left", left_on="time_id_", right_on="time_id")

    # Create row_id so we can merge
    df_feature = df_feature.add_prefix("trade_")
    stock_id = file_path.split("=")[1]
    df_feature["row_id"] = df_feature["trade_time_id_"].apply(lambda x: f"{stock_id}-{x}")
    df_feature.drop(["trade_time_id_", "trade_time_id"], axis=1, inplace=True)
    return df_feature

# %%
# Funtion to make preprocessing function in parallel (for each stock id)
def preprocessor(list_stock_ids, is_train = True):
    
    # Parrallel for loop
    def for_joblib(stock_id):
        # Train
        if is_train:
            file_path_book = CONFIG["root_dir"] + "book_train.parquet/stock_id=" + str(stock_id)
            file_path_trade = CONFIG["root_dir"] + "trade_train.parquet/stock_id=" + str(stock_id)
        # Test
        else:
            file_path_book = CONFIG["root_dir"] + "book_test.parquet/stock_id=" + str(stock_id)
            file_path_trade = CONFIG["root_dir"] + "trade_test.parquet/stock_id=" + str(stock_id)
    
        # Preprocess book and trade data and merge them
        df_tmp = pd.merge(book_preprocessor(file_path_book), trade_preprocessor(file_path_trade), on = "row_id", how = "left")
        
        # Return the merge dataframe
        return df_tmp
    
    # Use parallel api to call paralle for loop
    df = Parallel(n_jobs = -1, verbose = 1)(delayed(for_joblib)(stock_id) for stock_id in list_stock_ids)
    
    # Concatenate all the dataframes that return from Parallel
    df = pd.concat(df, ignore_index = True)
    
    return df

# %%
# Read train and test
train, test = read_train_test()

# Get unique stock ids 
train_stock_ids = train["stock_id"].unique()

# Preprocess them using Parallel and our single stock id functions
train_ = preprocessor(train_stock_ids, is_train=True)
train = train.merge(train_, on=["row_id"], how="left")

# Get unique stock ids 
test_stock_ids = test["stock_id"].unique()

# Preprocess them using Parallel and our single stock id functions
test_ = preprocessor(test_stock_ids, is_train=False)
test = test.merge(test_, on=["row_id"], how="left")
# Out:
# Our training set has 428932 rows
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:   50.7s
# [Parallel(n_jobs=-1)]: Done 112 out of 112 | elapsed:  4.7min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.1s finished

# %% [markdown]
# # Log Transformation

# %%
# abs log columns
abs_log_columns = [column for column in train.columns if 
                       "order_flow_imbalance" in column or 
                       "order_book_slope" in column or 
                       "depth_imbalance" in column or 
                       "pressure_imbalance" in column or
                       "total_volume" in column or
                       "seconds_gap" in column or
                       "trade_volumes" in column or
                       "trade_order_count" in column or
                       "trade_seconds_gap" in column or
                       "trade_tendency" in column
                      ]

# apply abs + log1p
train[abs_log_columns] = (train[abs_log_columns].apply(np.abs)).apply(np.log1p)
test[abs_log_columns] = (test[abs_log_columns].apply(np.abs)).apply(np.log1p)

# %% [markdown]
# # Fill inf with nan

# %%
train = train.replace([np.inf, -np.inf], np.nan)
test = test.replace([np.inf, -np.inf], np.nan)

# %%
test.head()
# Out:
#    stock_id  time_id row_id  wap1_sum  wap1_std  wap2_sum  wap2_std  \
# 0         0        4    0-4  3.001215   0.00017   3.00165  0.000153
# 1         0       32   0-32       NaN       NaN       NaN       NaN
# 2         0       34   0-34       NaN       NaN       NaN       NaN
#
#    log_return1_realized_volatility  log_return2_realized_volatility  \
# 0                         0.000294                         0.000252
# 1                              NaN                              NaN
# 2                              NaN                              NaN
#
#    wap_balance_sum  wap_balance_amax  wap_balance_amin  wap_balance_std  \
# 0         0.000436          0.000169          0.000125         0.000022
# 1              NaN               NaN               NaN              NaN
# 2              NaN               NaN               NaN              NaN
#
#    bid_ask_spread1_sum  bid_ask_spread1_amax  bid_ask_spread1_amin  \
# 0             0.001672               0.00059              0.000541
# 1                  NaN                   NaN                   NaN
# 2                  NaN                   NaN                   NaN
#
#    bid_ask_spread1_std  bid_ask_spread2_sum  bid_ask_spread2_amax  \
# 0             0.000028             0.003197               0.00123
# 1                  NaN                  NaN                   NaN
# 2                  NaN                  NaN                   NaN
#
#    bid_ask_spread2_amin  bid_ask_spread2_std  order_flow_imbalance1_sum  \
# 0              0.000984             0.000142                   3.044522
# 1                   NaN                  NaN                        NaN
# 2                   NaN                  NaN                        NaN
#
#    order_flow_imbalance1_amax  order_flow_imbalance1_amin  \
# 0                1.000000e-08                    3.044522
# 1                         NaN                         NaN
# 2                         NaN                         NaN
#
#    order_flow_imbalance1_std  order_flow_imbalance2_sum  \
# 0                   2.529482                   2.772589
# 1                        NaN                        NaN
# 2                        NaN                        NaN
#
#    order_flow_imbalance2_amax  order_flow_imbalance2_amin  \
# 0                1.000000e-08                    2.772589
# 1                         NaN                         NaN
# 2                         NaN                         NaN
#
#    order_flow_imbalance2_std  order_book_slope_mean  order_book_slope_amax  \
# 0                    2.26802              11.666115              11.666115
# 1                        NaN                    NaN                    NaN
# 2                        NaN                    NaN                    NaN
#
#    depth_imbalance1_sum  depth_imbalance1_amax  depth_imbalance1_std  \
# 0              0.574773               0.626456              0.425306
# 1                   NaN                    NaN                   NaN
# 2                   NaN                    NaN                   NaN
#
#    depth_imbalance2_sum  depth_imbalance2_amax  depth_imbalance2_std  \
# 0              1.105571               0.554678              0.062526
# 1                   NaN                    NaN                   NaN
# 2                   NaN                    NaN                   NaN
#
#    height_imbalance1_sum  height_imbalance1_amax  height_imbalance1_std  \
# 0              -0.000836                -0.00027               0.000014
# 1                    NaN                     NaN                    NaN
# 2                    NaN                     NaN                    NaN
#
#    height_imbalance2_sum  height_imbalance2_amax  height_imbalance2_std  \
# 0              -0.001598               -0.000492               0.000071
# 1                    NaN                     NaN                    NaN
# 2                    NaN                     NaN                    NaN
#
#    pressure_imbalance_sum  pressure_imbalance_amax  pressure_imbalance_std  \
# 0                   1.459                  1.26665                0.812895
# 1                     NaN                      NaN                     NaN
# 2                     NaN                      NaN                     NaN
#
#    total_volume_sum  seconds_gap_mean  log_return1_realized_volatility_150  \
# 0          6.959399          0.980829                                  NaN
# 1               NaN               NaN                                  NaN
# 2               NaN               NaN                                  NaN
#
#    log_return2_realized_volatility_150  wap_balance_sum_150  \
# 0                                  NaN                  NaN
# 1                                  NaN                  NaN
# 2                                  NaN                  NaN
#
#    wap_balance_amax_150  wap_balance_amin_150  wap_balance_std_150  \
# 0                   NaN                   NaN                  NaN
# 1                   NaN                   NaN                  NaN
# 2                   NaN                   NaN                  NaN
#
#    bid_ask_spread1_sum_150  bid_ask_spread1_amax_150  \
# 0                      NaN                       NaN
# 1                      NaN                       NaN
# 2                      NaN                       NaN
#
#    bid_ask_spread1_amin_150  bid_ask_spread1_std_150  bid_ask_spread2_sum_150  \
# 0                       NaN                      NaN                      NaN
# 1                       NaN                      NaN                      NaN
# 2                       NaN                      NaN                      NaN
#
#    bid_ask_spread2_amax_150  bid_ask_spread2_amin_150  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
#
#    bid_ask_spread2_std_150  order_flow_imbalance1_sum_150  \
# 0                      NaN                            NaN
# 1                      NaN                            NaN
# 2                      NaN                            NaN
#
#    order_flow_imbalance1_amax_150  order_flow_imbalance1_amin_150  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
#
#    order_flow_imbalance1_std_150  order_flow_imbalance2_sum_150  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
#
#    order_flow_imbalance2_amax_150  order_flow_imbalance2_amin_150  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
#
#    order_flow_imbalance2_std_150  total_volume_sum_150  seconds_gap_mean_150  \
# 0                            NaN                   NaN                   NaN
# 1                            NaN                   NaN                   NaN
# 2                            NaN                   NaN                   NaN
#
#    log_return1_realized_volatility_300  log_return2_realized_volatility_300  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
#
#    wap_balance_sum_300  wap_balance_amax_300  wap_balance_amin_300  \
# 0                  NaN                   NaN                   NaN
# 1                  NaN                   NaN                   NaN
# 2                  NaN                   NaN                   NaN
#
#    wap_balance_std_300  bid_ask_spread1_sum_300  bid_ask_spread1_amax_300  \
# 0                  NaN                      NaN                       NaN
# 1                  NaN                      NaN                       NaN
# 2                  NaN                      NaN                       NaN
#
#    bid_ask_spread1_amin_300  bid_ask_spread1_std_300  bid_ask_spread2_sum_300  \
# 0                       NaN                      NaN                      NaN
# 1                       NaN                      NaN                      NaN
# 2                       NaN                      NaN                      NaN
#
#    bid_ask_spread2_amax_300  bid_ask_spread2_amin_300  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
#
#    bid_ask_spread2_std_300  order_flow_imbalance1_sum_300  \
# 0                      NaN                            NaN
# 1                      NaN                            NaN
# 2                      NaN                            NaN
#
#    order_flow_imbalance1_amax_300  order_flow_imbalance1_amin_300  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
#
#    order_flow_imbalance1_std_300  order_flow_imbalance2_sum_300  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
#
#    order_flow_imbalance2_amax_300  order_flow_imbalance2_amin_300  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
#
#    order_flow_imbalance2_std_300  total_volume_sum_300  seconds_gap_mean_300  \
# 0                            NaN                   NaN                   NaN
# 1                            NaN                   NaN                   NaN
# 2                            NaN                   NaN                   NaN
#
#    log_return1_realized_volatility_450  log_return2_realized_volatility_450  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
#
#    wap_balance_sum_450  wap_balance_amax_450  wap_balance_amin_450  \
# 0                  NaN                   NaN                   NaN
# 1                  NaN                   NaN                   NaN
# 2                  NaN                   NaN                   NaN
#
#    wap_balance_std_450  bid_ask_spread1_sum_450  bid_ask_spread1_amax_450  \
# 0                  NaN                      NaN                       NaN
# 1                  NaN                      NaN                       NaN
# 2                  NaN                      NaN                       NaN
#
#    bid_ask_spread1_amin_450  bid_ask_spread1_std_450  bid_ask_spread2_sum_450  \
# 0                       NaN                      NaN                      NaN
# 1                       NaN                      NaN                      NaN
# 2                       NaN                      NaN                      NaN
#
#    bid_ask_spread2_amax_450  bid_ask_spread2_amin_450  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
#
#    bid_ask_spread2_std_450  order_flow_imbalance1_sum_450  \
# 0                      NaN                            NaN
# 1                      NaN                            NaN
# 2                      NaN                            NaN
#
#    order_flow_imbalance1_amax_450  order_flow_imbalance1_amin_450  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
#
#    order_flow_imbalance1_std_450  order_flow_imbalance2_sum_450  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
#
#    order_flow_imbalance2_amax_450  order_flow_imbalance2_amin_450  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
#
#    order_flow_imbalance2_std_450  total_volume_sum_450  seconds_gap_mean_450  \
# 0                            NaN                   NaN                   NaN
# 1                            NaN                   NaN                   NaN
# 2                            NaN                   NaN                   NaN
#
#    trade_price_log_return_realized_volatility  trade_volumes_sum  \
# 0                                    0.000295           5.308323
# 1                                         NaN                NaN
# 2                                         NaN                NaN
#
#    trade_volumes_amax  trade_volumes_std  trade_order_count_sum  \
# 0            4.615179           4.063208               2.484907
# 1                 NaN                NaN                    NaN
# 2                 NaN                NaN                    NaN
#
#    trade_seconds_gap_mean  trade_price_log_return_realized_volatility_150  \
# 0                2.036882                                             NaN
# 1                     NaN                                             NaN
# 2                     NaN                                             NaN
#
#    trade_volumes_sum_150  trade_volumes_amax_150  trade_volumes_std_150  \
# 0                    NaN                     NaN                    NaN
# 1                    NaN                     NaN                    NaN
# 2                    NaN                     NaN                    NaN
#
#    trade_order_count_sum_150  trade_seconds_gap_mean_150  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
#
#    trade_price_log_return_realized_volatility_300  trade_volumes_sum_300  \
# 0                                             NaN                    NaN
# 1                                             NaN                    NaN
# 2                                             NaN                    NaN
#
#    trade_volumes_amax_300  trade_volumes_std_300  trade_order_count_sum_300  \
# 0                     NaN                    NaN                        NaN
# 1                     NaN                    NaN                        NaN
# 2                     NaN                    NaN                        NaN
#
#    trade_seconds_gap_mean_300  trade_price_log_return_realized_volatility_450  \
# 0                         NaN                                             NaN
# 1                         NaN                                             NaN
# 2                         NaN                                             NaN
#
#    trade_volumes_sum_450  trade_volumes_amax_450  trade_volumes_std_450  \
# 0                    NaN                     NaN                    NaN
# 1                    NaN                     NaN                    NaN
# 2                    NaN                     NaN                    NaN
#
#    trade_order_count_sum_450  trade_seconds_gap_mean_450  trade_tendency  \
# 0                        NaN                         NaN        1.348423
# 1                        NaN                         NaN             NaN
# 2                        NaN                         NaN             NaN
#
#    trade_energy
# 0      1.000302
# 1           NaN
# 2           NaN

# %%
train.head()
# Out:
#    stock_id  time_id    target row_id    wap1_sum  wap1_std    wap2_sum  \
# 0         0        5  0.004136    0-5  303.125061  0.000693  303.105530
# 1         0       11  0.001445   0-11  200.047775  0.000262  200.041168
# 2         0       16  0.002168   0-16  187.913849  0.000864  187.939819
# 3         0       31  0.002195   0-31  119.859779  0.000757  119.835945
# 4         0       62  0.001747   0-62  175.932861  0.000258  175.934250
#
#    wap2_std  log_return1_realized_volatility  log_return2_realized_volatility  \
# 0  0.000781                         0.004499                         0.006999
# 1  0.000272                         0.001204                         0.002476
# 2  0.000862                         0.002369                         0.004801
# 3  0.000656                         0.002574                         0.003637
# 4  0.000317                         0.001894                         0.003257
#
#    wap_balance_sum  wap_balance_amax  wap_balance_amin  wap_balance_std  \
# 0         0.117051          0.001414      1.192093e-07         0.000295
# 1         0.042309          0.000639      4.768372e-07         0.000155
# 2         0.062230          0.001135      4.887581e-06         0.000246
# 3         0.045610          0.001082      1.507998e-05         0.000248
# 4         0.044783          0.000724      3.278255e-06         0.000188
#
#    bid_ask_spread1_sum  bid_ask_spread1_amax  bid_ask_spread1_amin  \
# 0             0.257371              0.001394              0.000361
# 1             0.078856              0.000904              0.000151
# 2             0.136380              0.001150              0.000384
# 3             0.103301              0.001624              0.000324
# 4             0.069916              0.000793              0.000093
#
#    bid_ask_spread1_std  bid_ask_spread2_sum  bid_ask_spread2_amax  \
# 0             0.000212             0.355666              0.001701
# 1             0.000157             0.134233              0.001105
# 2             0.000164             0.210687              0.001917
# 3             0.000280             0.139155              0.002041
# 4             0.000130             0.122743              0.001166
#
#    bid_ask_spread2_amin  bid_ask_spread2_std  order_flow_imbalance1_sum  \
# 0              0.000670             0.000213                   7.596894
# 1              0.000301             0.000200                   7.241366
# 2              0.000575             0.000295                   7.341484
# 3              0.000648             0.000366                   7.674617
# 4              0.000373             0.000185                   5.455321
#
#    order_flow_imbalance1_amax  order_flow_imbalance1_amin  \
# 0                    6.008813                    5.313206
# 1                    4.927254                    5.888878
# 2                    5.327876                    5.720312
# 3                    5.916202                    5.308268
# 4                    5.327876                    5.323010
#
#    order_flow_imbalance1_std  order_flow_imbalance2_sum  \
# 0                   4.238948                   7.479300
# 1                   3.918187                   4.615121
# 2                   4.118797                   7.536897
# 3                   4.399096                   7.211557
# 4                   3.930325                   7.921898
#
#    order_flow_imbalance2_amax  order_flow_imbalance2_amin  \
# 0                    5.993961                    5.993961
# 1                    5.888878                    6.222576
# 2                    5.720312                    5.755742
# 3                    5.323010                    5.303305
# 4                    5.811141                    5.351858
#
#    order_flow_imbalance2_std  order_book_slope_mean  order_book_slope_amax  \
# 0                   4.508810              10.452362              10.452362
# 1                   4.496739               9.850664               9.850664
# 2                   4.373154               9.983159               9.983159
# 3                   4.374984              10.739791              10.739791
# 4                   4.226555              10.122064              10.122064
#
#    depth_imbalance1_sum  depth_imbalance1_amax  depth_imbalance1_std  \
# 0              1.071533               0.688160              0.535878
# 1              3.539013               0.689841              0.531865
# 2              3.036534               0.683197              0.459874
# 3              2.049676               0.685083              0.536172
# 4              2.809757               0.688184              0.515773
#
#    depth_imbalance2_sum  depth_imbalance2_amax  depth_imbalance2_std  \
# 0              3.387522               0.686546              0.538637
# 1              0.011786               0.689830              0.453311
# 2              3.714099               0.687785              0.457857
# 3              3.715545               0.629634              0.421633
# 4              3.502687               0.689819              0.516746
#
#    height_imbalance1_sum  height_imbalance1_amax  height_imbalance1_std  \
# 0              -0.128628               -0.000180               0.000106
# 1              -0.039418               -0.000075               0.000079
# 2              -0.068165               -0.000192               0.000082
# 3              -0.051626               -0.000162               0.000140
# 4              -0.034951               -0.000047               0.000065
#
#    height_imbalance2_sum  height_imbalance2_amax  height_imbalance2_std  \
# 0              -0.177725               -0.000335               0.000107
# 1              -0.067091               -0.000151               0.000100
# 2              -0.105282               -0.000288               0.000147
# 3              -0.069533               -0.000324               0.000183
# 4              -0.061349               -0.000186               0.000093
#
#    pressure_imbalance_sum  pressure_imbalance_amax  pressure_imbalance_std  \
# 0                2.947730                 1.723689                1.142321
# 1                4.699373                 1.648913                0.853735
# 2                1.547597                 1.579019                0.830320
# 3                3.237666                 1.543497                0.783040
# 4                5.022252                 1.719904                0.969896
#
#    total_volume_sum  seconds_gap_mean  log_return1_realized_volatility_150  \
# 0         11.489626          1.086397                             0.003796
# 1         11.318017          1.381282                             0.001058
# 2         11.267984          1.430515                             0.002138
# 3         10.863470          1.770706                             0.002196
# 4         11.008877          1.465463                             0.001609
#
#    log_return2_realized_volatility_150  wap_balance_sum_150  \
# 0                             0.006087             0.091996
# 1                             0.002262             0.035451
# 2                             0.004019             0.044348
# 3                             0.003273             0.029322
# 4                             0.002927             0.032718
#
#    wap_balance_amax_150  wap_balance_amin_150  wap_balance_std_150  \
# 0              0.001184          1.192093e-07             0.000281
# 1              0.000639          4.768372e-07             0.000158
# 2              0.001135          1.829863e-05             0.000276
# 3              0.001082          1.507998e-05             0.000247
# 4              0.000724          3.278255e-06             0.000193
#
#    bid_ask_spread1_sum_150  bid_ask_spread1_amax_150  \
# 0                 0.199148                  0.001392
# 1                 0.061031                  0.000753
# 2                 0.080841                  0.001150
# 3                 0.074589                  0.001624
# 4                 0.053359                  0.000793
#
#    bid_ask_spread1_amin_150  bid_ask_spread1_std_150  bid_ask_spread2_sum_150  \
# 0                  0.000361                 0.000221                 0.276655
# 1                  0.000151                 0.000112                 0.107468
# 2                  0.000384                 0.000164                 0.128644
# 3                  0.000324                 0.000297                 0.097188
# 4                  0.000093                 0.000137                 0.094379
#
#    bid_ask_spread2_amax_150  bid_ask_spread2_amin_150  \
# 0                  0.001649                  0.000670
# 1                  0.001054                  0.000301
# 2                  0.001917                  0.000575
# 3                  0.002041                  0.000648
# 4                  0.001120                  0.000373
#
#    bid_ask_spread2_std_150  order_flow_imbalance1_sum_150  \
# 0                 0.000208                       6.926577
# 1                 0.000164                       7.011214
# 2                 0.000301                       7.016610
# 3                 0.000381                       7.415777
# 4                 0.000197                       5.370638
#
#    order_flow_imbalance1_amax_150  order_flow_imbalance1_amin_150  \
# 0                        6.008813                        5.313206
# 1                        4.927254                        5.888878
# 2                        5.327876                        5.720312
# 3                        5.733341                        5.303305
# 4                        5.293305                        5.323010
#
#    order_flow_imbalance1_std_150  order_flow_imbalance2_sum_150  \
# 0                       4.237138                       6.253829
# 1                       3.913854                       4.276666
# 2                       4.175770                       6.701960
# 3                       4.397948                       6.865891
# 4                       3.813997                       7.643004
#
#    order_flow_imbalance2_amax_150  order_flow_imbalance2_amin_150  \
# 0                        5.583496                        5.713733
# 1                        5.888878                        6.222576
# 2                        5.720312                        5.755742
# 3                        5.303305                        5.303305
# 4                        5.811141                        5.351858
#
#    order_flow_imbalance2_std_150  total_volume_sum_150  seconds_gap_mean_150  \
# 0                       4.410463             11.238028              1.069456
# 1                       4.544952             11.191838              1.298757
# 2                       4.423792             10.839522              1.562998
# 3                       4.332281             10.444765              1.853594
# 4                       4.280457             10.822215              1.447355
#
#    log_return1_realized_volatility_300  log_return2_realized_volatility_300  \
# 0                             0.002953                             0.004864
# 1                             0.000981                             0.002009
# 2                             0.001295                             0.003196
# 3                             0.001776                             0.002713
# 4                             0.001520                             0.002188
#
#    wap_balance_sum_300  wap_balance_amax_300  wap_balance_amin_300  \
# 0             0.051757              0.001034          1.192093e-07
# 1             0.027443              0.000639          2.241135e-05
# 2             0.029308              0.001135          1.829863e-05
# 3             0.017524              0.000840          1.507998e-05
# 4             0.022397              0.000660          3.278255e-06
#
#    wap_balance_std_300  bid_ask_spread1_sum_300  bid_ask_spread1_amax_300  \
# 0             0.000273                 0.114324                  0.001340
# 1             0.000158                 0.040599                  0.000753
# 2             0.000294                 0.046882                  0.000958
# 3             0.000228                 0.044180                  0.001624
# 4             0.000188                 0.037829                  0.000793
#
#    bid_ask_spread1_amin_300  bid_ask_spread1_std_300  bid_ask_spread2_sum_300  \
# 0                  0.000361                 0.000237                 0.167702
# 1                  0.000151                 0.000121                 0.073630
# 2                  0.000384                 0.000162                 0.073504
# 3                  0.000324                 0.000278                 0.057634
# 4                  0.000187                 0.000140                 0.065599
#
#    bid_ask_spread2_amax_300  bid_ask_spread2_amin_300  \
# 0                  0.001599                  0.000670
# 1                  0.001054                  0.000301
# 2                  0.001825                  0.000575
# 3                  0.001716                  0.000648
# 4                  0.001120                  0.000420
#
#    bid_ask_spread2_std_300  order_flow_imbalance1_sum_300  \
# 0                 0.000214                       4.219508
# 1                 0.000175                       6.753438
# 2                 0.000321                       5.953243
# 3                 0.000316                       6.452049
# 4                 0.000174                       6.122493
#
#    order_flow_imbalance1_amax_300  order_flow_imbalance1_amin_300  \
# 0                        5.303305                        5.313206
# 1                        4.927254                        5.888878
# 2                        5.327876                        5.720312
# 3                        5.707110                        5.303305
# 4                        5.293305                        4.653960
#
#    order_flow_imbalance1_std_300  order_flow_imbalance2_sum_300  \
# 0                       4.074132                       4.553877
# 1                       4.064560                       6.030685
# 2                       4.320648                       7.414573
# 3                       4.431513                       6.282267
# 4                       3.872014                       7.043160
#
#    order_flow_imbalance2_amax_300  order_flow_imbalance2_amin_300  \
# 0                        5.442418                        5.713733
# 1                        5.888878                        6.222576
# 2                        5.720312                        4.804021
# 3                        5.303305                        5.231109
# 4                        5.811141                        5.323010
#
#    order_flow_imbalance2_std_300  total_volume_sum_300  seconds_gap_mean_300  \
# 0                       4.439823             10.621230              1.138571
# 1                       4.717200             10.928112              1.280934
# 2                       4.323410             10.340354              1.685854
# 3                       4.185490             10.006225              1.861591
# 4                       4.208909             10.498912              1.440953
#
#    log_return1_realized_volatility_450  log_return2_realized_volatility_450  \
# 0                             0.001722                             0.004114
# 1                             0.000918                             0.001883
# 2                             0.001158                             0.002972
# 3                             0.000993                             0.001424
# 4                             0.001378                             0.000966
#
#    wap_balance_sum_450  wap_balance_amax_450  wap_balance_amin_450  \
# 0             0.024869              0.001034          1.192093e-07
# 1             0.014525              0.000639          2.264977e-05
# 2             0.016056              0.001135          1.829863e-05
# 3             0.006441              0.000840          5.167723e-05
# 4             0.013088              0.000660          2.205372e-05
#
#    wap_balance_std_450  bid_ask_spread1_sum_450  bid_ask_spread1_amax_450  \
# 0             0.000277                 0.053258                  0.001135
# 1             0.000175                 0.018817                  0.000753
# 2             0.000282                 0.026617                  0.000815
# 3             0.000253                 0.019057                  0.001160
# 4             0.000203                 0.018705                  0.000793
#
#    bid_ask_spread1_amin_450  bid_ask_spread1_std_450  bid_ask_spread2_sum_450  \
# 0                  0.000361                 0.000181                 0.082251
# 1                  0.000201                 0.000144                 0.039147
# 2                  0.000384                 0.000105                 0.043991
# 3                  0.000973                 0.000074                 0.022027
# 4                  0.000233                 0.000138                 0.030654
#
#    bid_ask_spread2_amax_450  bid_ask_spread2_amin_450  \
# 0                  0.001599                  0.000670
# 1                  0.001054                  0.000502
# 2                  0.001825                  0.000575
# 3                  0.001392                  0.001113
# 4                  0.001027                  0.000606
#
#    bid_ask_spread2_std_450  order_flow_imbalance1_sum_450  \
# 0                 0.000250                       5.541264
# 1                 0.000206                       6.230481
# 2                 0.000314                       5.686975
# 3                 0.000113                       5.446737
# 4                 0.000130                       4.430817
#
#    order_flow_imbalance1_amax_450  order_flow_imbalance1_amin_450  \
# 0                        4.844187                        5.313206
# 1                        4.672829                        5.888878
# 2                        5.327876                        5.720312
# 3                        5.707110                        5.303305
# 4                        5.293305                        4.624973
#
#    order_flow_imbalance1_std_450  order_flow_imbalance2_sum_450  \
# 0                       4.007175                       5.389072
# 1                       4.281894                       7.061334
# 2                       4.506372                       7.398174
# 3                       4.696914                       3.610918
# 4                       3.877972                       2.197225
#
#    order_flow_imbalance2_amax_450  order_flow_imbalance2_amin_450  \
# 0                        5.442418                        5.713733
# 1                        5.888878                        5.937536
# 2                        5.720312                        4.615121
# 3                        4.844187                        5.231109
# 4                        5.273000                        5.323010
#
#    order_flow_imbalance2_std_450  total_volume_sum_450  seconds_gap_mean_450  \
# 0                       4.551579              9.795290              1.137079
# 1                       4.678709             10.093777              1.358123
# 2                       4.459797              9.913537              1.543687
# 3                       4.290236              9.182044              2.153053
# 4                       4.161524              9.554710              1.581267
#
#    trade_price_log_return_realized_volatility  trade_volumes_sum  \
# 0                                    0.002006           8.068133
# 1                                    0.000901           7.162672
# 2                                    0.001961           7.677682
# 3                                    0.001561           7.581008
# 4                                    0.000871           7.490672
#
#    trade_volumes_amax  trade_volumes_std  trade_order_count_sum  \
# 0            6.217788           4.785643               4.709530
# 1            5.638426           4.367356               4.060443
# 2            5.969841           4.740140               4.234107
# 3            6.109442           4.980851               4.094345
# 4            5.834239           4.777958               4.499810
#
#    trade_seconds_gap_mean  trade_price_log_return_realized_volatility_150  \
# 0                2.748872                                        0.001701
# 1                2.990720                                        0.000813
# 2                3.215671                                        0.001621
# 3                3.673766                                        0.001401
# 4                3.315838                                        0.000550
#
#    trade_volumes_sum_150  trade_volumes_amax_150  trade_volumes_std_150  \
# 0               7.638966                6.217788               4.817781
# 1               7.068471                5.638426               4.440647
# 2               7.605216                5.969841               4.802625
# 3               7.396166                6.109442               5.082127
# 4               7.359025                5.834239               4.853212
#
#    trade_order_count_sum_150  trade_seconds_gap_mean_150  \
# 0                   4.304065                    2.747271
# 1                   3.912023                    2.953173
# 2                   4.094345                    3.212858
# 3                   3.931826                    3.754838
# 4                   4.290459                    3.362976
#
#    trade_price_log_return_realized_volatility_300  trade_volumes_sum_300  \
# 0                                        0.001308               7.373764
# 1                                        0.000587               6.803867
# 2                                        0.001137               7.079922
# 3                                        0.001089               7.349132
# 4                                        0.000453               7.106132
#
#    trade_volumes_amax_300  trade_volumes_std_300  trade_order_count_sum_300  \
# 0                6.217788               4.964091                   4.007333
# 1                5.638426               4.516671                   3.610918
# 2                5.969841               4.878626                   3.663562
# 3                6.109442               5.126717                   3.850148
# 4                5.834239               4.948701                   4.007333
#
#    trade_seconds_gap_mean_300  trade_price_log_return_realized_volatility_450  \
# 0                    2.748491                                        0.001060
# 1                    2.904165                                        0.000501
# 2                    3.258096                                        0.001048
# 3                    3.561677                                        0.000802
# 4                    3.338677                                        0.000360
#
#    trade_volumes_sum_450  trade_volumes_amax_450  trade_volumes_std_450  \
# 0               6.953078                6.217788               4.936772
# 1               6.720592                5.638426               4.684676
# 2               6.988346                5.969841               4.971290
# 3               6.242149                6.109442               5.494478
# 4               3.783891                3.555104               2.808331
#
#    trade_order_count_sum_450  trade_seconds_gap_mean_450  trade_tendency  \
# 0                   3.637586                    2.460809        3.008903
# 1                   3.135494                    2.821379        1.916797
# 2                   3.526361                    3.049799        3.929138
# 3                   2.484907                    4.143135        2.770287
# 4                   2.708050                    3.663562        2.445418
#
#    trade_energy
# 0      1.007459
# 1      1.000413
# 2      0.998409
# 3      0.998041
# 4      0.999237

# %%
test.head()
# Out:
#    stock_id  time_id row_id  wap1_sum  wap1_std  wap2_sum  wap2_std  \
# 0         0        4    0-4  3.001215   0.00017   3.00165  0.000153
# 1         0       32   0-32       NaN       NaN       NaN       NaN
# 2         0       34   0-34       NaN       NaN       NaN       NaN
#
#    log_return1_realized_volatility  log_return2_realized_volatility  \
# 0                         0.000294                         0.000252
# 1                              NaN                              NaN
# 2                              NaN                              NaN
#
#    wap_balance_sum  wap_balance_amax  wap_balance_amin  wap_balance_std  \
# 0         0.000436          0.000169          0.000125         0.000022
# 1              NaN               NaN               NaN              NaN
# 2              NaN               NaN               NaN              NaN
#
#    bid_ask_spread1_sum  bid_ask_spread1_amax  bid_ask_spread1_amin  \
# 0             0.001672               0.00059              0.000541
# 1                  NaN                   NaN                   NaN
# 2                  NaN                   NaN                   NaN
#
#    bid_ask_spread1_std  bid_ask_spread2_sum  bid_ask_spread2_amax  \
# 0             0.000028             0.003197               0.00123
# 1                  NaN                  NaN                   NaN
# 2                  NaN                  NaN                   NaN
#
#    bid_ask_spread2_amin  bid_ask_spread2_std  order_flow_imbalance1_sum  \
# 0              0.000984             0.000142                   3.044522
# 1                   NaN                  NaN                        NaN
# 2                   NaN                  NaN                        NaN
#
#    order_flow_imbalance1_amax  order_flow_imbalance1_amin  \
# 0                1.000000e-08                    3.044522
# 1                         NaN                         NaN
# 2                         NaN                         NaN
#
#    order_flow_imbalance1_std  order_flow_imbalance2_sum  \
# 0                   2.529482                   2.772589
# 1                        NaN                        NaN
# 2                        NaN                        NaN
#
#    order_flow_imbalance2_amax  order_flow_imbalance2_amin  \
# 0                1.000000e-08                    2.772589
# 1                         NaN                         NaN
# 2                         NaN                         NaN
#
#    order_flow_imbalance2_std  order_book_slope_mean  order_book_slope_amax  \
# 0                    2.26802              11.666115              11.666115
# 1                        NaN                    NaN                    NaN
# 2                        NaN                    NaN                    NaN
#
#    depth_imbalance1_sum  depth_imbalance1_amax  depth_imbalance1_std  \
# 0              0.574773               0.626456              0.425306
# 1                   NaN                    NaN                   NaN
# 2                   NaN                    NaN                   NaN
#
#    depth_imbalance2_sum  depth_imbalance2_amax  depth_imbalance2_std  \
# 0              1.105571               0.554678              0.062526
# 1                   NaN                    NaN                   NaN
# 2                   NaN                    NaN                   NaN
#
#    height_imbalance1_sum  height_imbalance1_amax  height_imbalance1_std  \
# 0              -0.000836                -0.00027               0.000014
# 1                    NaN                     NaN                    NaN
# 2                    NaN                     NaN                    NaN
#
#    height_imbalance2_sum  height_imbalance2_amax  height_imbalance2_std  \
# 0              -0.001598               -0.000492               0.000071
# 1                    NaN                     NaN                    NaN
# 2                    NaN                     NaN                    NaN
#
#    pressure_imbalance_sum  pressure_imbalance_amax  pressure_imbalance_std  \
# 0                   1.459                  1.26665                0.812895
# 1                     NaN                      NaN                     NaN
# 2                     NaN                      NaN                     NaN
#
#    total_volume_sum  seconds_gap_mean  log_return1_realized_volatility_150  \
# 0          6.959399          0.980829                                  NaN
# 1               NaN               NaN                                  NaN
# 2               NaN               NaN                                  NaN
#
#    log_return2_realized_volatility_150  wap_balance_sum_150  \
# 0                                  NaN                  NaN
# 1                                  NaN                  NaN
# 2                                  NaN                  NaN
#
#    wap_balance_amax_150  wap_balance_amin_150  wap_balance_std_150  \
# 0                   NaN                   NaN                  NaN
# 1                   NaN                   NaN                  NaN
# 2                   NaN                   NaN                  NaN
#
#    bid_ask_spread1_sum_150  bid_ask_spread1_amax_150  \
# 0                      NaN                       NaN
# 1                      NaN                       NaN
# 2                      NaN                       NaN
#
#    bid_ask_spread1_amin_150  bid_ask_spread1_std_150  bid_ask_spread2_sum_150  \
# 0                       NaN                      NaN                      NaN
# 1                       NaN                      NaN                      NaN
# 2                       NaN                      NaN                      NaN
#
#    bid_ask_spread2_amax_150  bid_ask_spread2_amin_150  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
#
#    bid_ask_spread2_std_150  order_flow_imbalance1_sum_150  \
# 0                      NaN                            NaN
# 1                      NaN                            NaN
# 2                      NaN                            NaN
#
#    order_flow_imbalance1_amax_150  order_flow_imbalance1_amin_150  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
#
#    order_flow_imbalance1_std_150  order_flow_imbalance2_sum_150  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
#
#    order_flow_imbalance2_amax_150  order_flow_imbalance2_amin_150  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
#
#    order_flow_imbalance2_std_150  total_volume_sum_150  seconds_gap_mean_150  \
# 0                            NaN                   NaN                   NaN
# 1                            NaN                   NaN                   NaN
# 2                            NaN                   NaN                   NaN
#
#    log_return1_realized_volatility_300  log_return2_realized_volatility_300  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
#
#    wap_balance_sum_300  wap_balance_amax_300  wap_balance_amin_300  \
# 0                  NaN                   NaN                   NaN
# 1                  NaN                   NaN                   NaN
# 2                  NaN                   NaN                   NaN
#
#    wap_balance_std_300  bid_ask_spread1_sum_300  bid_ask_spread1_amax_300  \
# 0                  NaN                      NaN                       NaN
# 1                  NaN                      NaN                       NaN
# 2                  NaN                      NaN                       NaN
#
#    bid_ask_spread1_amin_300  bid_ask_spread1_std_300  bid_ask_spread2_sum_300  \
# 0                       NaN                      NaN                      NaN
# 1                       NaN                      NaN                      NaN
# 2                       NaN                      NaN                      NaN
#
#    bid_ask_spread2_amax_300  bid_ask_spread2_amin_300  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
#
#    bid_ask_spread2_std_300  order_flow_imbalance1_sum_300  \
# 0                      NaN                            NaN
# 1                      NaN                            NaN
# 2                      NaN                            NaN
#
#    order_flow_imbalance1_amax_300  order_flow_imbalance1_amin_300  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
#
#    order_flow_imbalance1_std_300  order_flow_imbalance2_sum_300  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
#
#    order_flow_imbalance2_amax_300  order_flow_imbalance2_amin_300  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
#
#    order_flow_imbalance2_std_300  total_volume_sum_300  seconds_gap_mean_300  \
# 0                            NaN                   NaN                   NaN
# 1                            NaN                   NaN                   NaN
# 2                            NaN                   NaN                   NaN
#
#    log_return1_realized_volatility_450  log_return2_realized_volatility_450  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
#
#    wap_balance_sum_450  wap_balance_amax_450  wap_balance_amin_450  \
# 0                  NaN                   NaN                   NaN
# 1                  NaN                   NaN                   NaN
# 2                  NaN                   NaN                   NaN
#
#    wap_balance_std_450  bid_ask_spread1_sum_450  bid_ask_spread1_amax_450  \
# 0                  NaN                      NaN                       NaN
# 1                  NaN                      NaN                       NaN
# 2                  NaN                      NaN                       NaN
#
#    bid_ask_spread1_amin_450  bid_ask_spread1_std_450  bid_ask_spread2_sum_450  \
# 0                       NaN                      NaN                      NaN
# 1                       NaN                      NaN                      NaN
# 2                       NaN                      NaN                      NaN
#
#    bid_ask_spread2_amax_450  bid_ask_spread2_amin_450  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
#
#    bid_ask_spread2_std_450  order_flow_imbalance1_sum_450  \
# 0                      NaN                            NaN
# 1                      NaN                            NaN
# 2                      NaN                            NaN
#
#    order_flow_imbalance1_amax_450  order_flow_imbalance1_amin_450  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
#
#    order_flow_imbalance1_std_450  order_flow_imbalance2_sum_450  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
#
#    order_flow_imbalance2_amax_450  order_flow_imbalance2_amin_450  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
#
#    order_flow_imbalance2_std_450  total_volume_sum_450  seconds_gap_mean_450  \
# 0                            NaN                   NaN                   NaN
# 1                            NaN                   NaN                   NaN
# 2                            NaN                   NaN                   NaN
#
#    trade_price_log_return_realized_volatility  trade_volumes_sum  \
# 0                                    0.000295           5.308323
# 1                                         NaN                NaN
# 2                                         NaN                NaN
#
#    trade_volumes_amax  trade_volumes_std  trade_order_count_sum  \
# 0            4.615179           4.063208               2.484907
# 1                 NaN                NaN                    NaN
# 2                 NaN                NaN                    NaN
#
#    trade_seconds_gap_mean  trade_price_log_return_realized_volatility_150  \
# 0                2.036882                                             NaN
# 1                     NaN                                             NaN
# 2                     NaN                                             NaN
#
#    trade_volumes_sum_150  trade_volumes_amax_150  trade_volumes_std_150  \
# 0                    NaN                     NaN                    NaN
# 1                    NaN                     NaN                    NaN
# 2                    NaN                     NaN                    NaN
#
#    trade_order_count_sum_150  trade_seconds_gap_mean_150  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
#
#    trade_price_log_return_realized_volatility_300  trade_volumes_sum_300  \
# 0                                             NaN                    NaN
# 1                                             NaN                    NaN
# 2                                             NaN                    NaN
#
#    trade_volumes_amax_300  trade_volumes_std_300  trade_order_count_sum_300  \
# 0                     NaN                    NaN                        NaN
# 1                     NaN                    NaN                        NaN
# 2                     NaN                    NaN                        NaN
#
#    trade_seconds_gap_mean_300  trade_price_log_return_realized_volatility_450  \
# 0                         NaN                                             NaN
# 1                         NaN                                             NaN
# 2                         NaN                                             NaN
#
#    trade_volumes_sum_450  trade_volumes_amax_450  trade_volumes_std_450  \
# 0                    NaN                     NaN                    NaN
# 1                    NaN                     NaN                    NaN
# 2                    NaN                     NaN                    NaN
#
#    trade_order_count_sum_450  trade_seconds_gap_mean_450  trade_tendency  \
# 0                        NaN                         NaN        1.348423
# 1                        NaN                         NaN             NaN
# 2                        NaN                         NaN             NaN
#
#    trade_energy
# 0      1.000302
# 1           NaN
# 2           NaN

# %% [markdown]
# # Agg features inside fold

# %%
# Process agg by kmeans
def get_kmeans_idx(n_clusters=7):
    train_p = pd.read_csv("../../input/optiver-realized-volatility-prediction/train.csv")
    train_p = train_p.pivot(index="time_id", columns="stock_id", values="target")

    corr = train_p.corr()

    ids = corr.index

    kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(corr.values)

    kmeans_clusters = []
    for n in range(n_clusters):
        kmeans_clusters.append ([(x - 1) for x in ((ids + 1)*(kmeans.labels_ == n)) if x > 0])
        
    return kmeans_clusters
    

def agg_stat_features_by_clusters(df, n_clusters=7, function=np.nanmean, post_fix="_cluster_mean"):

    kmeans_clusters = get_kmeans_idx(n_clusters=n_clusters)

    clusters = []
    agg_columns = [
        "time_id",
        "stock_id",
        "log_return1_realized_volatility",
        "log_return2_realized_volatility",
        "order_flow_imbalance1_sum",
        "order_flow_imbalance2_sum",
        "order_book_slope_mean",
        "depth_imbalance1_std",
        "depth_imbalance2_std",
        "height_imbalance1_sum",
        "height_imbalance2_sum",
        "pressure_imbalance_std",
        "total_volume_sum",
        "seconds_gap_mean",
        "trade_price_log_return_realized_volatility",
        "trade_volumes_sum",
        "trade_order_count_sum",
        "trade_seconds_gap_mean",
        "trade_tendency",
        "trade_energy"
    ]

    for cluster_idx, ind in enumerate(kmeans_clusters):
        cluster_df = df.loc[df["stock_id"].isin(ind), agg_columns].groupby(["time_id"]).agg(function)
        cluster_df.loc[:, "stock_id"] = str(cluster_idx) + post_fix
        clusters.append(cluster_df)

    clusters_df = pd.concat(clusters).reset_index()
    # multi index (column, c1)
    clusters_df = clusters_df.pivot(index="time_id", columns="stock_id")
    # ravel multi index to list of tuple [(target, c1), ...]
    clusters_df.columns = ["_".join(x) for x in clusters_df.columns.ravel()]
    clusters_df.reset_index(inplace=True)

    postfixes = [
        "0" + post_fix,
        "1" + post_fix,
        "3" + post_fix,
        "4" + post_fix,
        "6" + post_fix,
    ]
    merge_columns = []
    for column in agg_columns:
        if column == "time_id":
            merge_columns.append(column)
        elif column == "stock_id":
            continue
        else:
            for postfix in postfixes:
                merge_columns.append(column + "_" + postfix)
                
    not_exist_columns = [column for column in merge_columns if column not in clusters_df.columns]
    clusters_df[not_exist_columns] = 0
    
    df = pd.merge(df, clusters_df[merge_columns], how="left", on="time_id")

    return df


# Function to get group stats for the time_id
def agg_stat_features_by_market(df, operations=None, operations_names=None):
    def percentile(n):
        def percentile_(x):
            return np.percentile(x, n)

        percentile_.__name__ = "percentile_%s" % n
        return percentile_

    if operations is None:
        operations = [
            np.nanmean,
        ]
        operations_names = [
            "mean",
        ]

    # Get realized volatility columns
    vol_cols = [
        "log_return1_realized_volatility",
        "log_return1_realized_volatility_150",
        "log_return1_realized_volatility_300",
        "log_return1_realized_volatility_450",
    ]

    # Group by the stock id
    df_stock_id = df.groupby(["stock_id"])[vol_cols].agg(operations).reset_index()
    # Rename columns joining suffix
    df_stock_id.columns = ["_".join(col) for col in df_stock_id.columns]
    df_stock_id = df_stock_id.add_suffix("_" + "stock")

    # Group by the stock id
    df_time_id = df.groupby(["time_id"])[vol_cols].agg(operations).reset_index()
    # Rename columns joining suffix
    df_time_id.columns = ["_".join(col) for col in df_time_id.columns]
    df_time_id = df_time_id.add_suffix("_" + "time")

    # Merge with original dataframe
    df = df.merge(df_stock_id, how="left", left_on=["stock_id"], right_on=["stock_id__stock"])
    df.drop("stock_id__stock", axis=1, inplace=True)

    df = df.merge(df_time_id, how="left", left_on=["time_id"], right_on=["time_id__time"])
    df.drop("time_id__time", axis=1, inplace=True)

    return df

# %%
train.head()
# Out:
#    stock_id  time_id    target row_id    wap1_sum  wap1_std    wap2_sum  \
# 0         0        5  0.004136    0-5  303.125061  0.000693  303.105530
# 1         0       11  0.001445   0-11  200.047775  0.000262  200.041168
# 2         0       16  0.002168   0-16  187.913849  0.000864  187.939819
# 3         0       31  0.002195   0-31  119.859779  0.000757  119.835945
# 4         0       62  0.001747   0-62  175.932861  0.000258  175.934250
#
#    wap2_std  log_return1_realized_volatility  log_return2_realized_volatility  \
# 0  0.000781                         0.004499                         0.006999
# 1  0.000272                         0.001204                         0.002476
# 2  0.000862                         0.002369                         0.004801
# 3  0.000656                         0.002574                         0.003637
# 4  0.000317                         0.001894                         0.003257
#
#    wap_balance_sum  wap_balance_amax  wap_balance_amin  wap_balance_std  \
# 0         0.117051          0.001414      1.192093e-07         0.000295
# 1         0.042309          0.000639      4.768372e-07         0.000155
# 2         0.062230          0.001135      4.887581e-06         0.000246
# 3         0.045610          0.001082      1.507998e-05         0.000248
# 4         0.044783          0.000724      3.278255e-06         0.000188
#
#    bid_ask_spread1_sum  bid_ask_spread1_amax  bid_ask_spread1_amin  \
# 0             0.257371              0.001394              0.000361
# 1             0.078856              0.000904              0.000151
# 2             0.136380              0.001150              0.000384
# 3             0.103301              0.001624              0.000324
# 4             0.069916              0.000793              0.000093
#
#    bid_ask_spread1_std  bid_ask_spread2_sum  bid_ask_spread2_amax  \
# 0             0.000212             0.355666              0.001701
# 1             0.000157             0.134233              0.001105
# 2             0.000164             0.210687              0.001917
# 3             0.000280             0.139155              0.002041
# 4             0.000130             0.122743              0.001166
#
#    bid_ask_spread2_amin  bid_ask_spread2_std  order_flow_imbalance1_sum  \
# 0              0.000670             0.000213                   7.596894
# 1              0.000301             0.000200                   7.241366
# 2              0.000575             0.000295                   7.341484
# 3              0.000648             0.000366                   7.674617
# 4              0.000373             0.000185                   5.455321
#
#    order_flow_imbalance1_amax  order_flow_imbalance1_amin  \
# 0                    6.008813                    5.313206
# 1                    4.927254                    5.888878
# 2                    5.327876                    5.720312
# 3                    5.916202                    5.308268
# 4                    5.327876                    5.323010
#
#    order_flow_imbalance1_std  order_flow_imbalance2_sum  \
# 0                   4.238948                   7.479300
# 1                   3.918187                   4.615121
# 2                   4.118797                   7.536897
# 3                   4.399096                   7.211557
# 4                   3.930325                   7.921898
#
#    order_flow_imbalance2_amax  order_flow_imbalance2_amin  \
# 0                    5.993961                    5.993961
# 1                    5.888878                    6.222576
# 2                    5.720312                    5.755742
# 3                    5.323010                    5.303305
# 4                    5.811141                    5.351858
#
#    order_flow_imbalance2_std  order_book_slope_mean  order_book_slope_amax  \
# 0                   4.508810              10.452362              10.452362
# 1                   4.496739               9.850664               9.850664
# 2                   4.373154               9.983159               9.983159
# 3                   4.374984              10.739791              10.739791
# 4                   4.226555              10.122064              10.122064
#
#    depth_imbalance1_sum  depth_imbalance1_amax  depth_imbalance1_std  \
# 0              1.071533               0.688160              0.535878
# 1              3.539013               0.689841              0.531865
# 2              3.036534               0.683197              0.459874
# 3              2.049676               0.685083              0.536172
# 4              2.809757               0.688184              0.515773
#
#    depth_imbalance2_sum  depth_imbalance2_amax  depth_imbalance2_std  \
# 0              3.387522               0.686546              0.538637
# 1              0.011786               0.689830              0.453311
# 2              3.714099               0.687785              0.457857
# 3              3.715545               0.629634              0.421633
# 4              3.502687               0.689819              0.516746
#
#    height_imbalance1_sum  height_imbalance1_amax  height_imbalance1_std  \
# 0              -0.128628               -0.000180               0.000106
# 1              -0.039418               -0.000075               0.000079
# 2              -0.068165               -0.000192               0.000082
# 3              -0.051626               -0.000162               0.000140
# 4              -0.034951               -0.000047               0.000065
#
#    height_imbalance2_sum  height_imbalance2_amax  height_imbalance2_std  \
# 0              -0.177725               -0.000335               0.000107
# 1              -0.067091               -0.000151               0.000100
# 2              -0.105282               -0.000288               0.000147
# 3              -0.069533               -0.000324               0.000183
# 4              -0.061349               -0.000186               0.000093
#
#    pressure_imbalance_sum  pressure_imbalance_amax  pressure_imbalance_std  \
# 0                2.947730                 1.723689                1.142321
# 1                4.699373                 1.648913                0.853735
# 2                1.547597                 1.579019                0.830320
# 3                3.237666                 1.543497                0.783040
# 4                5.022252                 1.719904                0.969896
#
#    total_volume_sum  seconds_gap_mean  log_return1_realized_volatility_150  \
# 0         11.489626          1.086397                             0.003796
# 1         11.318017          1.381282                             0.001058
# 2         11.267984          1.430515                             0.002138
# 3         10.863470          1.770706                             0.002196
# 4         11.008877          1.465463                             0.001609
#
#    log_return2_realized_volatility_150  wap_balance_sum_150  \
# 0                             0.006087             0.091996
# 1                             0.002262             0.035451
# 2                             0.004019             0.044348
# 3                             0.003273             0.029322
# 4                             0.002927             0.032718
#
#    wap_balance_amax_150  wap_balance_amin_150  wap_balance_std_150  \
# 0              0.001184          1.192093e-07             0.000281
# 1              0.000639          4.768372e-07             0.000158
# 2              0.001135          1.829863e-05             0.000276
# 3              0.001082          1.507998e-05             0.000247
# 4              0.000724          3.278255e-06             0.000193
#
#    bid_ask_spread1_sum_150  bid_ask_spread1_amax_150  \
# 0                 0.199148                  0.001392
# 1                 0.061031                  0.000753
# 2                 0.080841                  0.001150
# 3                 0.074589                  0.001624
# 4                 0.053359                  0.000793
#
#    bid_ask_spread1_amin_150  bid_ask_spread1_std_150  bid_ask_spread2_sum_150  \
# 0                  0.000361                 0.000221                 0.276655
# 1                  0.000151                 0.000112                 0.107468
# 2                  0.000384                 0.000164                 0.128644
# 3                  0.000324                 0.000297                 0.097188
# 4                  0.000093                 0.000137                 0.094379
#
#    bid_ask_spread2_amax_150  bid_ask_spread2_amin_150  \
# 0                  0.001649                  0.000670
# 1                  0.001054                  0.000301
# 2                  0.001917                  0.000575
# 3                  0.002041                  0.000648
# 4                  0.001120                  0.000373
#
#    bid_ask_spread2_std_150  order_flow_imbalance1_sum_150  \
# 0                 0.000208                       6.926577
# 1                 0.000164                       7.011214
# 2                 0.000301                       7.016610
# 3                 0.000381                       7.415777
# 4                 0.000197                       5.370638
#
#    order_flow_imbalance1_amax_150  order_flow_imbalance1_amin_150  \
# 0                        6.008813                        5.313206
# 1                        4.927254                        5.888878
# 2                        5.327876                        5.720312
# 3                        5.733341                        5.303305
# 4                        5.293305                        5.323010
#
#    order_flow_imbalance1_std_150  order_flow_imbalance2_sum_150  \
# 0                       4.237138                       6.253829
# 1                       3.913854                       4.276666
# 2                       4.175770                       6.701960
# 3                       4.397948                       6.865891
# 4                       3.813997                       7.643004
#
#    order_flow_imbalance2_amax_150  order_flow_imbalance2_amin_150  \
# 0                        5.583496                        5.713733
# 1                        5.888878                        6.222576
# 2                        5.720312                        5.755742
# 3                        5.303305                        5.303305
# 4                        5.811141                        5.351858
#
#    order_flow_imbalance2_std_150  total_volume_sum_150  seconds_gap_mean_150  \
# 0                       4.410463             11.238028              1.069456
# 1                       4.544952             11.191838              1.298757
# 2                       4.423792             10.839522              1.562998
# 3                       4.332281             10.444765              1.853594
# 4                       4.280457             10.822215              1.447355
#
#    log_return1_realized_volatility_300  log_return2_realized_volatility_300  \
# 0                             0.002953                             0.004864
# 1                             0.000981                             0.002009
# 2                             0.001295                             0.003196
# 3                             0.001776                             0.002713
# 4                             0.001520                             0.002188
#
#    wap_balance_sum_300  wap_balance_amax_300  wap_balance_amin_300  \
# 0             0.051757              0.001034          1.192093e-07
# 1             0.027443              0.000639          2.241135e-05
# 2             0.029308              0.001135          1.829863e-05
# 3             0.017524              0.000840          1.507998e-05
# 4             0.022397              0.000660          3.278255e-06
#
#    wap_balance_std_300  bid_ask_spread1_sum_300  bid_ask_spread1_amax_300  \
# 0             0.000273                 0.114324                  0.001340
# 1             0.000158                 0.040599                  0.000753
# 2             0.000294                 0.046882                  0.000958
# 3             0.000228                 0.044180                  0.001624
# 4             0.000188                 0.037829                  0.000793
#
#    bid_ask_spread1_amin_300  bid_ask_spread1_std_300  bid_ask_spread2_sum_300  \
# 0                  0.000361                 0.000237                 0.167702
# 1                  0.000151                 0.000121                 0.073630
# 2                  0.000384                 0.000162                 0.073504
# 3                  0.000324                 0.000278                 0.057634
# 4                  0.000187                 0.000140                 0.065599
#
#    bid_ask_spread2_amax_300  bid_ask_spread2_amin_300  \
# 0                  0.001599                  0.000670
# 1                  0.001054                  0.000301
# 2                  0.001825                  0.000575
# 3                  0.001716                  0.000648
# 4                  0.001120                  0.000420
#
#    bid_ask_spread2_std_300  order_flow_imbalance1_sum_300  \
# 0                 0.000214                       4.219508
# 1                 0.000175                       6.753438
# 2                 0.000321                       5.953243
# 3                 0.000316                       6.452049
# 4                 0.000174                       6.122493
#
#    order_flow_imbalance1_amax_300  order_flow_imbalance1_amin_300  \
# 0                        5.303305                        5.313206
# 1                        4.927254                        5.888878
# 2                        5.327876                        5.720312
# 3                        5.707110                        5.303305
# 4                        5.293305                        4.653960
#
#    order_flow_imbalance1_std_300  order_flow_imbalance2_sum_300  \
# 0                       4.074132                       4.553877
# 1                       4.064560                       6.030685
# 2                       4.320648                       7.414573
# 3                       4.431513                       6.282267
# 4                       3.872014                       7.043160
#
#    order_flow_imbalance2_amax_300  order_flow_imbalance2_amin_300  \
# 0                        5.442418                        5.713733
# 1                        5.888878                        6.222576
# 2                        5.720312                        4.804021
# 3                        5.303305                        5.231109
# 4                        5.811141                        5.323010
#
#    order_flow_imbalance2_std_300  total_volume_sum_300  seconds_gap_mean_300  \
# 0                       4.439823             10.621230              1.138571
# 1                       4.717200             10.928112              1.280934
# 2                       4.323410             10.340354              1.685854
# 3                       4.185490             10.006225              1.861591
# 4                       4.208909             10.498912              1.440953
#
#    log_return1_realized_volatility_450  log_return2_realized_volatility_450  \
# 0                             0.001722                             0.004114
# 1                             0.000918                             0.001883
# 2                             0.001158                             0.002972
# 3                             0.000993                             0.001424
# 4                             0.001378                             0.000966
#
#    wap_balance_sum_450  wap_balance_amax_450  wap_balance_amin_450  \
# 0             0.024869              0.001034          1.192093e-07
# 1             0.014525              0.000639          2.264977e-05
# 2             0.016056              0.001135          1.829863e-05
# 3             0.006441              0.000840          5.167723e-05
# 4             0.013088              0.000660          2.205372e-05
#
#    wap_balance_std_450  bid_ask_spread1_sum_450  bid_ask_spread1_amax_450  \
# 0             0.000277                 0.053258                  0.001135
# 1             0.000175                 0.018817                  0.000753
# 2             0.000282                 0.026617                  0.000815
# 3             0.000253                 0.019057                  0.001160
# 4             0.000203                 0.018705                  0.000793
#
#    bid_ask_spread1_amin_450  bid_ask_spread1_std_450  bid_ask_spread2_sum_450  \
# 0                  0.000361                 0.000181                 0.082251
# 1                  0.000201                 0.000144                 0.039147
# 2                  0.000384                 0.000105                 0.043991
# 3                  0.000973                 0.000074                 0.022027
# 4                  0.000233                 0.000138                 0.030654
#
#    bid_ask_spread2_amax_450  bid_ask_spread2_amin_450  \
# 0                  0.001599                  0.000670
# 1                  0.001054                  0.000502
# 2                  0.001825                  0.000575
# 3                  0.001392                  0.001113
# 4                  0.001027                  0.000606
#
#    bid_ask_spread2_std_450  order_flow_imbalance1_sum_450  \
# 0                 0.000250                       5.541264
# 1                 0.000206                       6.230481
# 2                 0.000314                       5.686975
# 3                 0.000113                       5.446737
# 4                 0.000130                       4.430817
#
#    order_flow_imbalance1_amax_450  order_flow_imbalance1_amin_450  \
# 0                        4.844187                        5.313206
# 1                        4.672829                        5.888878
# 2                        5.327876                        5.720312
# 3                        5.707110                        5.303305
# 4                        5.293305                        4.624973
#
#    order_flow_imbalance1_std_450  order_flow_imbalance2_sum_450  \
# 0                       4.007175                       5.389072
# 1                       4.281894                       7.061334
# 2                       4.506372                       7.398174
# 3                       4.696914                       3.610918
# 4                       3.877972                       2.197225
#
#    order_flow_imbalance2_amax_450  order_flow_imbalance2_amin_450  \
# 0                        5.442418                        5.713733
# 1                        5.888878                        5.937536
# 2                        5.720312                        4.615121
# 3                        4.844187                        5.231109
# 4                        5.273000                        5.323010
#
#    order_flow_imbalance2_std_450  total_volume_sum_450  seconds_gap_mean_450  \
# 0                       4.551579              9.795290              1.137079
# 1                       4.678709             10.093777              1.358123
# 2                       4.459797              9.913537              1.543687
# 3                       4.290236              9.182044              2.153053
# 4                       4.161524              9.554710              1.581267
#
#    trade_price_log_return_realized_volatility  trade_volumes_sum  \
# 0                                    0.002006           8.068133
# 1                                    0.000901           7.162672
# 2                                    0.001961           7.677682
# 3                                    0.001561           7.581008
# 4                                    0.000871           7.490672
#
#    trade_volumes_amax  trade_volumes_std  trade_order_count_sum  \
# 0            6.217788           4.785643               4.709530
# 1            5.638426           4.367356               4.060443
# 2            5.969841           4.740140               4.234107
# 3            6.109442           4.980851               4.094345
# 4            5.834239           4.777958               4.499810
#
#    trade_seconds_gap_mean  trade_price_log_return_realized_volatility_150  \
# 0                2.748872                                        0.001701
# 1                2.990720                                        0.000813
# 2                3.215671                                        0.001621
# 3                3.673766                                        0.001401
# 4                3.315838                                        0.000550
#
#    trade_volumes_sum_150  trade_volumes_amax_150  trade_volumes_std_150  \
# 0               7.638966                6.217788               4.817781
# 1               7.068471                5.638426               4.440647
# 2               7.605216                5.969841               4.802625
# 3               7.396166                6.109442               5.082127
# 4               7.359025                5.834239               4.853212
#
#    trade_order_count_sum_150  trade_seconds_gap_mean_150  \
# 0                   4.304065                    2.747271
# 1                   3.912023                    2.953173
# 2                   4.094345                    3.212858
# 3                   3.931826                    3.754838
# 4                   4.290459                    3.362976
#
#    trade_price_log_return_realized_volatility_300  trade_volumes_sum_300  \
# 0                                        0.001308               7.373764
# 1                                        0.000587               6.803867
# 2                                        0.001137               7.079922
# 3                                        0.001089               7.349132
# 4                                        0.000453               7.106132
#
#    trade_volumes_amax_300  trade_volumes_std_300  trade_order_count_sum_300  \
# 0                6.217788               4.964091                   4.007333
# 1                5.638426               4.516671                   3.610918
# 2                5.969841               4.878626                   3.663562
# 3                6.109442               5.126717                   3.850148
# 4                5.834239               4.948701                   4.007333
#
#    trade_seconds_gap_mean_300  trade_price_log_return_realized_volatility_450  \
# 0                    2.748491                                        0.001060
# 1                    2.904165                                        0.000501
# 2                    3.258096                                        0.001048
# 3                    3.561677                                        0.000802
# 4                    3.338677                                        0.000360
#
#    trade_volumes_sum_450  trade_volumes_amax_450  trade_volumes_std_450  \
# 0               6.953078                6.217788               4.936772
# 1               6.720592                5.638426               4.684676
# 2               6.988346                5.969841               4.971290
# 3               6.242149                6.109442               5.494478
# 4               3.783891                3.555104               2.808331
#
#    trade_order_count_sum_450  trade_seconds_gap_mean_450  trade_tendency  \
# 0                   3.637586                    2.460809        3.008903
# 1                   3.135494                    2.821379        1.916797
# 2                   3.526361                    3.049799        3.929138
# 3                   2.484907                    4.143135        2.770287
# 4                   2.708050                    3.663562        2.445418
#
#    trade_energy
# 0      1.007459
# 1      1.000413
# 2      0.998409
# 3      0.998041
# 4      0.999237

# %%
# Function to calculate the root mean squared percentage error
def rmspe(y_true, y_pred):
    return np.sqrt(np.mean(np.square((y_true - y_pred) / y_true)))

# Function to early stop with root mean squared percentage error
def feval_rmspe(y_pred, lgb_train):
    y_true = lgb_train.get_label()
    return "RMSPE", rmspe(y_true, y_pred), False

def train_and_evaluate(train, test):
    
    # scale
    # scaler = QuantileTransformer(n_quantiles=2000, random_state=2021)
    scaler = StandardScaler()
    
    # Split features and target
    x = train.drop(["row_id", "target"], axis=1)
    y = train["target"]
    
    # x_test with train feature
    x_test = test.drop("row_id", axis=1)
    x_test = agg_stat_features_by_market(x_test)
    x_test = agg_stat_features_by_clusters(x_test, n_clusters=CONFIG["n_clusters"], function=np.nanmean, post_fix="_cluster_mean")
    x_test = agg_stat_features_by_clusters(x_test, n_clusters=CONFIG["n_clusters"], function=np.nanmax, post_fix="_cluster_max")
    x_test = agg_stat_features_by_clusters(x_test, n_clusters=CONFIG["n_clusters"], function=np.nanmin, post_fix="_cluster_min")
    x_test = agg_stat_features_by_clusters(x_test, n_clusters=CONFIG["n_clusters"], function=np.nanstd, post_fix="_cluster_std")

    # define normalize columns
    except_columns = ["stock_id", "time_id", "target", "row_id"]
    normalized_columns = [column for column in x_test.columns if column not in except_columns]
    x_test.drop("time_id", axis=1, inplace=True)
    
    # Transform stock id to a numeric value
    x["stock_id"] = x["stock_id"].astype(int)
    x_test["stock_id"] = x_test["stock_id"].astype(int)
    
    # Create out of folds array
    oof_predictions = np.zeros(x.shape[0])
    
    # Create test array to store predictions
    test_predictions = np.zeros(x_test.shape[0])
    
    # Create a KFold object
    kfold = GroupKFold(n_splits=CONFIG["n_splits"])
    
    # Iterate through each fold
    for fold, (trn_ind, val_ind) in enumerate(kfold.split(x, groups=x["time_id"])):
        
        print(f"Training fold {fold + 1}")
        x_train = x.iloc[trn_ind]
        x_train = agg_stat_features_by_market(x_train)
        x_train = agg_stat_features_by_clusters(x_train, n_clusters=CONFIG["n_clusters"], function=np.nanmean, post_fix="_cluster_mean")
        x_train = agg_stat_features_by_clusters(x_train, n_clusters=CONFIG["n_clusters"], function=np.nanmax, post_fix="_cluster_max")
        x_train = agg_stat_features_by_clusters(x_train, n_clusters=CONFIG["n_clusters"], function=np.nanmin, post_fix="_cluster_min")
        x_train = agg_stat_features_by_clusters(x_train, n_clusters=CONFIG["n_clusters"], function=np.nanstd, post_fix="_cluster_std")
        x_train.drop("time_id", axis=1, inplace=True)
        
        scaler = scaler.fit(x_train[normalized_columns])
        dump(scaler, os.path.join(CONFIG["ckpt_dir"], "std_scaler_fold_{}.bin".format(fold + 1)), compress=True)
        
        x_train = x_train.fillna(x_train.mean())
        x_train[normalized_columns] = scaler.transform(x_train[normalized_columns])
        
        fill_value = scaler.mean_
        fill_value_dict = {normalized_columns[idx] : fill_value[idx] for idx in range(len(normalized_columns))}
        
        x_val = x.iloc[val_ind]
        x_val = agg_stat_features_by_market(x_val)
        x_val = agg_stat_features_by_clusters(x_val, n_clusters=CONFIG["n_clusters"], function=np.nanmean, post_fix="_cluster_mean")
        x_val = agg_stat_features_by_clusters(x_val, n_clusters=CONFIG["n_clusters"], function=np.nanmax, post_fix="_cluster_max")
        x_val = agg_stat_features_by_clusters(x_val, n_clusters=CONFIG["n_clusters"], function=np.nanmin, post_fix="_cluster_min")
        x_val = agg_stat_features_by_clusters(x_val, n_clusters=CONFIG["n_clusters"], function=np.nanstd, post_fix="_cluster_std")
        x_val.drop("time_id", axis=1, inplace=True)
        
        x_val[normalized_columns] = x_val[normalized_columns].fillna(fill_value_dict)
        x_val[normalized_columns] = scaler.transform(x_val[normalized_columns])
        
        y_train, y_val = y.iloc[trn_ind], y.iloc[val_ind]
        
        # Root mean squared percentage error weights
        train_weights = 1 / np.square(y_train)
        val_weights = 1 / np.square(y_val)
        train_dataset = lgb.Dataset(x_train, y_train, weight = train_weights, categorical_feature = ["stock_id"])
        val_dataset = lgb.Dataset(x_val, y_val, weight = val_weights, categorical_feature = ["stock_id"])
        
        # Train
        model = lgb.train(params = PARAMS, 
                          train_set = train_dataset, 
                          valid_sets = [train_dataset, val_dataset], 
                          num_boost_round = 8000, 
                          early_stopping_rounds = 400, 
                          verbose_eval = 100,
                          feval = feval_rmspe
                         )
        
        model.save_model(os.path.join(CONFIG["ckpt_dir"], "lgbm_fold_{}.txt".format(fold + 1)))
        
        # Feature Importance
        fig, ax = plt.subplots(figsize=(12, 30))
        for feature, importance in zip(model.feature_name(), model.feature_importance()):
            print(feature, importance)
        lgb.plot_importance(model, max_num_features=50, ax=ax)
        plt.title("Feature importance")
        plt.show()
        
        # Add predictions to the out of folds array
        oof_predictions[val_ind] = model.predict(x_val)
        
        # Predict the test set
        x_test_ = x_test.copy()

        x_test_[normalized_columns] = x_test_[normalized_columns].fillna(fill_value_dict)
        x_test_[normalized_columns] = scaler.transform(x_test_[normalized_columns])
        
        test_predictions += model.predict(x_test_) / CONFIG["n_splits"]
        
    rmspe_score = rmspe(y, oof_predictions)
    print(f"Our out of folds RMSPE is {rmspe_score}")
    
    # Return test predictions
    return test_predictions

# %%
# Traing and evaluate
if CONFIG["shuffle"]:
    print("shuffling dataset")
    train = train.sample(frac=1, random_state=CONFIG["shuffle_seed"]).reset_index(drop=True)
test_predictions = train_and_evaluate(train, test)

# Save test predictions
# test["target"] = test_predictions
# test[["row_id", "target"]].to_csv("submission.csv",index = False)
# Out:
# shuffling dataset
# Training fold 1
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 0.000447093	training's RMSPE: 0.207101	valid_1's rmse: 0.000481053	valid_1's RMSPE: 0.221859
# [200]	training's rmse: 0.000422702	training's RMSPE: 0.195802	valid_1's rmse: 0.000474063	valid_1's RMSPE: 0.218636
# [300]	training's rmse: 0.000408429	training's RMSPE: 0.189191	valid_1's rmse: 0.000471107	valid_1's RMSPE: 0.217272
# [400]	training's rmse: 0.000398246	training's RMSPE: 0.184474	valid_1's rmse: 0.000468943	valid_1's RMSPE: 0.216274
# [500]	training's rmse: 0.000390913	training's RMSPE: 0.181077	valid_1's rmse: 0.000467722	valid_1's RMSPE: 0.215711
# [600]	training's rmse: 0.000384752	training's RMSPE: 0.178223	valid_1's rmse: 0.000466834	valid_1's RMSPE: 0.215301
# [700]	training's rmse: 0.000379694	training's RMSPE: 0.17588	valid_1's rmse: 0.000466477	valid_1's RMSPE: 0.215137
# [800]	training's rmse: 0.000375184	training's RMSPE: 0.173791	valid_1's rmse: 0.000466228	valid_1's RMSPE: 0.215022
# [900]	training's rmse: 0.000371201	training's RMSPE: 0.171947	valid_1's rmse: 0.000465879	valid_1's RMSPE: 0.214861
# [1000]	training's rmse: 0.000367568	training's RMSPE: 0.170264	valid_1's rmse: 0.000465809	valid_1's RMSPE: 0.214829
# [1100]	training's rmse: 0.000364269	training's RMSPE: 0.168735	valid_1's rmse: 0.000465812	valid_1's RMSPE: 0.21483
# [1200]	training's rmse: 0.00036124	training's RMSPE: 0.167332	valid_1's rmse: 0.000465896	valid_1's RMSPE: 0.214869
# [1300]	training's rmse: 0.000358361	training's RMSPE: 0.165999	valid_1's rmse: 0.000465833	valid_1's RMSPE: 0.21484
# [1400]	training's rmse: 0.000355601	training's RMSPE: 0.16472	valid_1's rmse: 0.000465954	valid_1's RMSPE: 0.214896
# Early stopping, best iteration is:
# [1036]	training's rmse: 0.00036637	training's RMSPE: 0.169708	valid_1's rmse: 0.000465691	valid_1's RMSPE: 0.214774
# stock_id 4797
# wap1_sum 43
# wap1_std 62
# wap2_sum 34
# wap2_std 67
# log_return1_realized_volatility 266
# log_return2_realized_volatility 123
# wap_balance_sum 50
# wap_balance_amax 36
# wap_balance_amin 45
# wap_balance_std 42
# bid_ask_spread1_sum 132
# bid_ask_spread1_amax 49
# bid_ask_spread1_amin 67
# bid_ask_spread1_std 46
# bid_ask_spread2_sum 54
# bid_ask_spread2_amax 48
# bid_ask_spread2_amin 66
# bid_ask_spread2_std 44
# order_flow_imbalance1_sum 21
# order_flow_imbalance1_amax 41
# order_flow_imbalance1_amin 26
# order_flow_imbalance1_std 28
# order_flow_imbalance2_sum 50
# order_flow_imbalance2_amax 20
# order_flow_imbalance2_amin 26
# order_flow_imbalance2_std 29
# order_book_slope_mean 39
# order_book_slope_amax 20
# depth_imbalance1_sum 24
# depth_imbalance1_amax 33
# depth_imbalance1_std 64
# depth_imbalance2_sum 38
# depth_imbalance2_amax 30
# depth_imbalance2_std 57
# height_imbalance1_sum 114
# height_imbalance1_amax 48
# height_imbalance1_std 51
# height_imbalance2_sum 37
# height_imbalance2_amax 62
# height_imbalance2_std 35
# pressure_imbalance_sum 51
# pressure_imbalance_amax 27
# pressure_imbalance_std 73
# total_volume_sum 54
# seconds_gap_mean 40
# log_return1_realized_volatility_150 569
# log_return2_realized_volatility_150 204
# wap_balance_sum_150 42
# wap_balance_amax_150 23
# wap_balance_amin_150 35
# wap_balance_std_150 33
# bid_ask_spread1_sum_150 34
# bid_ask_spread1_amax_150 39
# bid_ask_spread1_amin_150 46
# bid_ask_spread1_std_150 38
# bid_ask_spread2_sum_150 22
# bid_ask_spread2_amax_150 41
# bid_ask_spread2_amin_150 30
# bid_ask_spread2_std_150 20
# order_flow_imbalance1_sum_150 20
# order_flow_imbalance1_amax_150 35
# order_flow_imbalance1_amin_150 30
# order_flow_imbalance1_std_150 23
# order_flow_imbalance2_sum_150 26
# order_flow_imbalance2_amax_150 13
# order_flow_imbalance2_amin_150 26
# order_flow_imbalance2_std_150 30
# total_volume_sum_150 49
# seconds_gap_mean_150 43
# log_return1_realized_volatility_300 360
# log_return2_realized_volatility_300 153
# wap_balance_sum_300 52
# wap_balance_amax_300 32
# wap_balance_amin_300 31
# wap_balance_std_300 27
# bid_ask_spread1_sum_300 37
# bid_ask_spread1_amax_300 27
# bid_ask_spread1_amin_300 36
# bid_ask_spread1_std_300 31
# bid_ask_spread2_sum_300 28
# bid_ask_spread2_amax_300 46
# bid_ask_spread2_amin_300 22
# bid_ask_spread2_std_300 24
# order_flow_imbalance1_sum_300 11
# order_flow_imbalance1_amax_300 31
# order_flow_imbalance1_amin_300 36
# order_flow_imbalance1_std_300 22
# order_flow_imbalance2_sum_300 30
# order_flow_imbalance2_amax_300 27
# order_flow_imbalance2_amin_300 45
# order_flow_imbalance2_std_300 14
# total_volume_sum_300 24
# seconds_gap_mean_300 46
# log_return1_realized_volatility_450 76
# log_return2_realized_volatility_450 74
# wap_balance_sum_450 46
# wap_balance_amax_450 32
# wap_balance_amin_450 39
# wap_balance_std_450 49
# bid_ask_spread1_sum_450 86
# bid_ask_spread1_amax_450 67
# bid_ask_spread1_amin_450 51
# bid_ask_spread1_std_450 21
# bid_ask_spread2_sum_450 18
# bid_ask_spread2_amax_450 90
# bid_ask_spread2_amin_450 32
# bid_ask_spread2_std_450 49
# order_flow_imbalance1_sum_450 19
# order_flow_imbalance1_amax_450 36
# order_flow_imbalance1_amin_450 28
# order_flow_imbalance1_std_450 18
# order_flow_imbalance2_sum_450 12
# order_flow_imbalance2_amax_450 26
# order_flow_imbalance2_amin_450 38
# order_flow_imbalance2_std_450 22
# total_volume_sum_450 27
# seconds_gap_mean_450 49
# trade_price_log_return_realized_volatility 114
# trade_volumes_sum 31
# trade_volumes_amax 35
# trade_volumes_std 50
# trade_order_count_sum 32
# trade_seconds_gap_mean 64
# trade_price_log_return_realized_volatility_150 43
# trade_volumes_sum_150 22
# trade_volumes_amax_150 16
# trade_volumes_std_150 38
# trade_order_count_sum_150 31
# trade_seconds_gap_mean_150 81
# trade_price_log_return_realized_volatility_300 57
# trade_volumes_sum_300 21
# trade_volumes_amax_300 17
# trade_volumes_std_300 18
# trade_order_count_sum_300 37
# trade_seconds_gap_mean_300 97
# trade_price_log_return_realized_volatility_450 97
# trade_volumes_sum_450 39
# trade_volumes_amax_450 21
# trade_volumes_std_450 27
# trade_order_count_sum_450 111
# trade_seconds_gap_mean_450 87
# trade_tendency 74
# trade_energy 114
# log_return1_realized_volatility_nanmean_stock 67
# log_return1_realized_volatility_150_nanmean_stock 63
# log_return1_realized_volatility_300_nanmean_stock 36
# log_return1_realized_volatility_450_nanmean_stock 53
# log_return1_realized_volatility_nanmean_time 8
# log_return1_realized_volatility_150_nanmean_time 10
# log_return1_realized_volatility_300_nanmean_time 15
# log_return1_realized_volatility_450_nanmean_time 44
# log_return1_realized_volatility_0_cluster_mean 5
# log_return1_realized_volatility_1_cluster_mean 19
# log_return1_realized_volatility_3_cluster_mean 16
# log_return1_realized_volatility_4_cluster_mean 14
# log_return1_realized_volatility_6_cluster_mean 20
# log_return2_realized_volatility_0_cluster_mean 6
# log_return2_realized_volatility_1_cluster_mean 26
# log_return2_realized_volatility_3_cluster_mean 16
# log_return2_realized_volatility_4_cluster_mean 11
# log_return2_realized_volatility_6_cluster_mean 8
# order_flow_imbalance1_sum_0_cluster_mean 43
# order_flow_imbalance1_sum_1_cluster_mean 101
# order_flow_imbalance1_sum_3_cluster_mean 43
# order_flow_imbalance1_sum_4_cluster_mean 56
# order_flow_imbalance1_sum_6_cluster_mean 64
# order_flow_imbalance2_sum_0_cluster_mean 107
# order_flow_imbalance2_sum_1_cluster_mean 50
# order_flow_imbalance2_sum_3_cluster_mean 126
# order_flow_imbalance2_sum_4_cluster_mean 62
# order_flow_imbalance2_sum_6_cluster_mean 61
# order_book_slope_mean_0_cluster_mean 77
# order_book_slope_mean_1_cluster_mean 84
# order_book_slope_mean_3_cluster_mean 82
# order_book_slope_mean_4_cluster_mean 72
# order_book_slope_mean_6_cluster_mean 48
# depth_imbalance1_std_0_cluster_mean 46
# depth_imbalance1_std_1_cluster_mean 57
# depth_imbalance1_std_3_cluster_mean 43
# depth_imbalance1_std_4_cluster_mean 53
# depth_imbalance1_std_6_cluster_mean 75
# depth_imbalance2_std_0_cluster_mean 59
# depth_imbalance2_std_1_cluster_mean 76
# depth_imbalance2_std_3_cluster_mean 75
# depth_imbalance2_std_4_cluster_mean 54
# depth_imbalance2_std_6_cluster_mean 59
# height_imbalance1_sum_0_cluster_mean 10
# height_imbalance1_sum_1_cluster_mean 24
# height_imbalance1_sum_3_cluster_mean 27
# height_imbalance1_sum_4_cluster_mean 17
# height_imbalance1_sum_6_cluster_mean 25
# height_imbalance2_sum_0_cluster_mean 13
# height_imbalance2_sum_1_cluster_mean 16
# height_imbalance2_sum_3_cluster_mean 40
# height_imbalance2_sum_4_cluster_mean 9
# height_imbalance2_sum_6_cluster_mean 28
# pressure_imbalance_std_0_cluster_mean 43
# pressure_imbalance_std_1_cluster_mean 46
# pressure_imbalance_std_3_cluster_mean 70
# pressure_imbalance_std_4_cluster_mean 40
# pressure_imbalance_std_6_cluster_mean 62
# total_volume_sum_0_cluster_mean 94
# total_volume_sum_1_cluster_mean 47
# total_volume_sum_3_cluster_mean 63
# total_volume_sum_4_cluster_mean 64
# total_volume_sum_6_cluster_mean 113
# seconds_gap_mean_0_cluster_mean 56
# seconds_gap_mean_1_cluster_mean 59
# seconds_gap_mean_3_cluster_mean 104
# seconds_gap_mean_4_cluster_mean 36
# seconds_gap_mean_6_cluster_mean 37
# trade_price_log_return_realized_volatility_0_cluster_mean 17
# trade_price_log_return_realized_volatility_1_cluster_mean 28
# trade_price_log_return_realized_volatility_3_cluster_mean 20
# trade_price_log_return_realized_volatility_4_cluster_mean 10
# trade_price_log_return_realized_volatility_6_cluster_mean 9
# trade_volumes_sum_0_cluster_mean 38
# trade_volumes_sum_1_cluster_mean 49
# trade_volumes_sum_3_cluster_mean 38
# trade_volumes_sum_4_cluster_mean 38
# trade_volumes_sum_6_cluster_mean 42
# trade_order_count_sum_0_cluster_mean 45
# trade_order_count_sum_1_cluster_mean 68
# trade_order_count_sum_3_cluster_mean 62
# trade_order_count_sum_4_cluster_mean 34
# trade_order_count_sum_6_cluster_mean 48
# trade_seconds_gap_mean_0_cluster_mean 42
# trade_seconds_gap_mean_1_cluster_mean 46
# trade_seconds_gap_mean_3_cluster_mean 35
# trade_seconds_gap_mean_4_cluster_mean 38
# trade_seconds_gap_mean_6_cluster_mean 39
# trade_tendency_0_cluster_mean 57
# trade_tendency_1_cluster_mean 49
# trade_tendency_3_cluster_mean 72
# trade_tendency_4_cluster_mean 28
# trade_tendency_6_cluster_mean 56
# trade_energy_0_cluster_mean 50
# trade_energy_1_cluster_mean 50
# trade_energy_3_cluster_mean 42
# trade_energy_4_cluster_mean 38
# trade_energy_6_cluster_mean 49
# log_return1_realized_volatility_0_cluster_max 27
# log_return1_realized_volatility_1_cluster_max 24
# log_return1_realized_volatility_3_cluster_max 33
# log_return1_realized_volatility_4_cluster_max 31
# log_return1_realized_volatility_6_cluster_max 41
# log_return2_realized_volatility_0_cluster_max 24
# log_return2_realized_volatility_1_cluster_max 40
# log_return2_realized_volatility_3_cluster_max 23
# log_return2_realized_volatility_4_cluster_max 25
# log_return2_realized_volatility_6_cluster_max 24
# order_flow_imbalance1_sum_0_cluster_max 94
# order_flow_imbalance1_sum_1_cluster_max 46
# order_flow_imbalance1_sum_3_cluster_max 79
# order_flow_imbalance1_sum_4_cluster_max 62
# order_flow_imbalance1_sum_6_cluster_max 72
# order_flow_imbalance2_sum_0_cluster_max 56
# order_flow_imbalance2_sum_1_cluster_max 61
# order_flow_imbalance2_sum_3_cluster_max 52
# order_flow_imbalance2_sum_4_cluster_max 61
# order_flow_imbalance2_sum_6_cluster_max 79
# order_book_slope_mean_0_cluster_max 62
# order_book_slope_mean_1_cluster_max 67
# order_book_slope_mean_3_cluster_max 79
# order_book_slope_mean_4_cluster_max 83
# order_book_slope_mean_6_cluster_max 65
# depth_imbalance1_std_0_cluster_max 55
# depth_imbalance1_std_1_cluster_max 80
# depth_imbalance1_std_3_cluster_max 57
# depth_imbalance1_std_4_cluster_max 53
# depth_imbalance1_std_6_cluster_max 76
# depth_imbalance2_std_0_cluster_max 59
# depth_imbalance2_std_1_cluster_max 64
# depth_imbalance2_std_3_cluster_max 69
# depth_imbalance2_std_4_cluster_max 43
# depth_imbalance2_std_6_cluster_max 66
# height_imbalance1_sum_0_cluster_max 72
# height_imbalance1_sum_1_cluster_max 54
# height_imbalance1_sum_3_cluster_max 89
# height_imbalance1_sum_4_cluster_max 27
# height_imbalance1_sum_6_cluster_max 32
# height_imbalance2_sum_0_cluster_max 91
# height_imbalance2_sum_1_cluster_max 47
# height_imbalance2_sum_3_cluster_max 179
# height_imbalance2_sum_4_cluster_max 49
# height_imbalance2_sum_6_cluster_max 36
# pressure_imbalance_std_0_cluster_max 81
# pressure_imbalance_std_1_cluster_max 57
# pressure_imbalance_std_3_cluster_max 51
# pressure_imbalance_std_4_cluster_max 69
# pressure_imbalance_std_6_cluster_max 52
# total_volume_sum_0_cluster_max 108
# total_volume_sum_1_cluster_max 72
# total_volume_sum_3_cluster_max 72
# total_volume_sum_4_cluster_max 68
# total_volume_sum_6_cluster_max 87
# seconds_gap_mean_0_cluster_max 53
# seconds_gap_mean_1_cluster_max 40
# seconds_gap_mean_3_cluster_max 55
# seconds_gap_mean_4_cluster_max 35
# seconds_gap_mean_6_cluster_max 55
# trade_price_log_return_realized_volatility_0_cluster_max 20
# trade_price_log_return_realized_volatility_1_cluster_max 35
# trade_price_log_return_realized_volatility_3_cluster_max 31
# trade_price_log_return_realized_volatility_4_cluster_max 34
# trade_price_log_return_realized_volatility_6_cluster_max 35
# trade_volumes_sum_0_cluster_max 31
# trade_volumes_sum_1_cluster_max 62
# trade_volumes_sum_3_cluster_max 66
# trade_volumes_sum_4_cluster_max 56
# trade_volumes_sum_6_cluster_max 63
# trade_order_count_sum_0_cluster_max 44
# trade_order_count_sum_1_cluster_max 63
# trade_order_count_sum_3_cluster_max 62
# trade_order_count_sum_4_cluster_max 36
# trade_order_count_sum_6_cluster_max 69
# trade_seconds_gap_mean_0_cluster_max 50
# trade_seconds_gap_mean_1_cluster_max 60
# trade_seconds_gap_mean_3_cluster_max 56
# trade_seconds_gap_mean_4_cluster_max 78
# trade_seconds_gap_mean_6_cluster_max 42
# trade_tendency_0_cluster_max 52
# trade_tendency_1_cluster_max 52
# trade_tendency_3_cluster_max 48
# trade_tendency_4_cluster_max 44
# trade_tendency_6_cluster_max 68
# trade_energy_0_cluster_max 55
# trade_energy_1_cluster_max 46
# trade_energy_3_cluster_max 58
# trade_energy_4_cluster_max 79
# trade_energy_6_cluster_max 43
# log_return1_realized_volatility_0_cluster_min 32
# log_return1_realized_volatility_1_cluster_min 23
# log_return1_realized_volatility_3_cluster_min 69
# log_return1_realized_volatility_4_cluster_min 26
# log_return1_realized_volatility_6_cluster_min 17
# log_return2_realized_volatility_0_cluster_min 41
# log_return2_realized_volatility_1_cluster_min 28
# log_return2_realized_volatility_3_cluster_min 67
# log_return2_realized_volatility_4_cluster_min 34
# log_return2_realized_volatility_6_cluster_min 37
# order_flow_imbalance1_sum_0_cluster_min 47
# order_flow_imbalance1_sum_1_cluster_min 45
# order_flow_imbalance1_sum_3_cluster_min 72
# order_flow_imbalance1_sum_4_cluster_min 42
# order_flow_imbalance1_sum_6_cluster_min 70
# order_flow_imbalance2_sum_0_cluster_min 41
# order_flow_imbalance2_sum_1_cluster_min 46
# order_flow_imbalance2_sum_3_cluster_min 67
# order_flow_imbalance2_sum_4_cluster_min 69
# order_flow_imbalance2_sum_6_cluster_min 66
# order_book_slope_mean_0_cluster_min 81
# order_book_slope_mean_1_cluster_min 73
# order_book_slope_mean_3_cluster_min 84
# order_book_slope_mean_4_cluster_min 89
# order_book_slope_mean_6_cluster_min 53
# depth_imbalance1_std_0_cluster_min 47
# depth_imbalance1_std_1_cluster_min 78
# depth_imbalance1_std_3_cluster_min 33
# depth_imbalance1_std_4_cluster_min 53
# depth_imbalance1_std_6_cluster_min 69
# depth_imbalance2_std_0_cluster_min 66
# depth_imbalance2_std_1_cluster_min 57
# depth_imbalance2_std_3_cluster_min 48
# depth_imbalance2_std_4_cluster_min 54
# depth_imbalance2_std_6_cluster_min 61
# height_imbalance1_sum_0_cluster_min 30
# height_imbalance1_sum_1_cluster_min 39
# height_imbalance1_sum_3_cluster_min 34
# height_imbalance1_sum_4_cluster_min 33
# height_imbalance1_sum_6_cluster_min 43
# height_imbalance2_sum_0_cluster_min 17
# height_imbalance2_sum_1_cluster_min 24
# height_imbalance2_sum_3_cluster_min 81
# height_imbalance2_sum_4_cluster_min 25
# height_imbalance2_sum_6_cluster_min 51
# pressure_imbalance_std_0_cluster_min 68
# pressure_imbalance_std_1_cluster_min 52
# pressure_imbalance_std_3_cluster_min 54
# pressure_imbalance_std_4_cluster_min 84
# pressure_imbalance_std_6_cluster_min 60
# total_volume_sum_0_cluster_min 51
# total_volume_sum_1_cluster_min 78
# total_volume_sum_3_cluster_min 71
# total_volume_sum_4_cluster_min 57
# total_volume_sum_6_cluster_min 70
# seconds_gap_mean_0_cluster_min 8
# seconds_gap_mean_1_cluster_min 64
# seconds_gap_mean_3_cluster_min 6
# seconds_gap_mean_4_cluster_min 53
# seconds_gap_mean_6_cluster_min 53
# trade_price_log_return_realized_volatility_0_cluster_min 33
# trade_price_log_return_realized_volatility_1_cluster_min 42
# trade_price_log_return_realized_volatility_3_cluster_min 33
# trade_price_log_return_realized_volatility_4_cluster_min 25
# trade_price_log_return_realized_volatility_6_cluster_min 27
# trade_volumes_sum_0_cluster_min 61
# trade_volumes_sum_1_cluster_min 69
# trade_volumes_sum_3_cluster_min 60
# trade_volumes_sum_4_cluster_min 56
# trade_volumes_sum_6_cluster_min 43
# trade_order_count_sum_0_cluster_min 51
# trade_order_count_sum_1_cluster_min 88
# trade_order_count_sum_3_cluster_min 48
# trade_order_count_sum_4_cluster_min 77
# trade_order_count_sum_6_cluster_min 43
# trade_seconds_gap_mean_0_cluster_min 66
# trade_seconds_gap_mean_1_cluster_min 64
# trade_seconds_gap_mean_3_cluster_min 64
# trade_seconds_gap_mean_4_cluster_min 35
# trade_seconds_gap_mean_6_cluster_min 37
# trade_tendency_0_cluster_min 50
# trade_tendency_1_cluster_min 58
# trade_tendency_3_cluster_min 61
# trade_tendency_4_cluster_min 72
# trade_tendency_6_cluster_min 40
# trade_energy_0_cluster_min 62
# trade_energy_1_cluster_min 60
# trade_energy_3_cluster_min 51
# trade_energy_4_cluster_min 52
# trade_energy_6_cluster_min 49
# log_return1_realized_volatility_0_cluster_std 30
# log_return1_realized_volatility_1_cluster_std 48
# log_return1_realized_volatility_3_cluster_std 23
# log_return1_realized_volatility_4_cluster_std 26
# log_return1_realized_volatility_6_cluster_std 45
# log_return2_realized_volatility_0_cluster_std 25
# log_return2_realized_volatility_1_cluster_std 22
# log_return2_realized_volatility_3_cluster_std 18
# log_return2_realized_volatility_4_cluster_std 41
# log_return2_realized_volatility_6_cluster_std 34
# order_flow_imbalance1_sum_0_cluster_std 47
# order_flow_imbalance1_sum_1_cluster_std 65
# order_flow_imbalance1_sum_3_cluster_std 80
# order_flow_imbalance1_sum_4_cluster_std 72
# order_flow_imbalance1_sum_6_cluster_std 52
# order_flow_imbalance2_sum_0_cluster_std 74
# order_flow_imbalance2_sum_1_cluster_std 45
# order_flow_imbalance2_sum_3_cluster_std 69
# order_flow_imbalance2_sum_4_cluster_std 55
# order_flow_imbalance2_sum_6_cluster_std 110
# order_book_slope_mean_0_cluster_std 52
# order_book_slope_mean_1_cluster_std 53
# order_book_slope_mean_3_cluster_std 39
# order_book_slope_mean_4_cluster_std 65
# order_book_slope_mean_6_cluster_std 66
# depth_imbalance1_std_0_cluster_std 103
# depth_imbalance1_std_1_cluster_std 59
# depth_imbalance1_std_3_cluster_std 49
# depth_imbalance1_std_4_cluster_std 63
# depth_imbalance1_std_6_cluster_std 48
# depth_imbalance2_std_0_cluster_std 44
# depth_imbalance2_std_1_cluster_std 51
# depth_imbalance2_std_3_cluster_std 65
# depth_imbalance2_std_4_cluster_std 74
# depth_imbalance2_std_6_cluster_std 61
# height_imbalance1_sum_0_cluster_std 16
# height_imbalance1_sum_1_cluster_std 20
# height_imbalance1_sum_3_cluster_std 20
# height_imbalance1_sum_4_cluster_std 24
# height_imbalance1_sum_6_cluster_std 33
# height_imbalance2_sum_0_cluster_std 23
# height_imbalance2_sum_1_cluster_std 37
# height_imbalance2_sum_3_cluster_std 71
# height_imbalance2_sum_4_cluster_std 34
# height_imbalance2_sum_6_cluster_std 48
# pressure_imbalance_std_0_cluster_std 36
# pressure_imbalance_std_1_cluster_std 65
# pressure_imbalance_std_3_cluster_std 45
# pressure_imbalance_std_4_cluster_std 46
# pressure_imbalance_std_6_cluster_std 38
# total_volume_sum_0_cluster_std 59
# total_volume_sum_1_cluster_std 54
# total_volume_sum_3_cluster_std 54
# total_volume_sum_4_cluster_std 80
# total_volume_sum_6_cluster_std 72
# seconds_gap_mean_0_cluster_std 59
# seconds_gap_mean_1_cluster_std 50
# seconds_gap_mean_3_cluster_std 80
# seconds_gap_mean_4_cluster_std 40
# seconds_gap_mean_6_cluster_std 50
# trade_price_log_return_realized_volatility_0_cluster_std 30
# trade_price_log_return_realized_volatility_1_cluster_std 37
# trade_price_log_return_realized_volatility_3_cluster_std 37
# trade_price_log_return_realized_volatility_4_cluster_std 41
# trade_price_log_return_realized_volatility_6_cluster_std 45
# trade_volumes_sum_0_cluster_std 55
# trade_volumes_sum_1_cluster_std 40
# trade_volumes_sum_3_cluster_std 74
# trade_volumes_sum_4_cluster_std 58
# trade_volumes_sum_6_cluster_std 64
# trade_order_count_sum_0_cluster_std 37
# trade_order_count_sum_1_cluster_std 55
# trade_order_count_sum_3_cluster_std 53
# trade_order_count_sum_4_cluster_std 60
# trade_order_count_sum_6_cluster_std 40
# trade_seconds_gap_mean_0_cluster_std 55
# trade_seconds_gap_mean_1_cluster_std 53
# trade_seconds_gap_mean_3_cluster_std 54
# trade_seconds_gap_mean_4_cluster_std 41
# trade_seconds_gap_mean_6_cluster_std 48
# trade_tendency_0_cluster_std 69
# trade_tendency_1_cluster_std 43
# trade_tendency_3_cluster_std 66
# trade_tendency_4_cluster_std 73
# trade_tendency_6_cluster_std 53
# trade_energy_0_cluster_std 57
# trade_energy_1_cluster_std 47
# trade_energy_3_cluster_std 58
# trade_energy_4_cluster_std 45
# trade_energy_6_cluster_std 55
# Training fold 2
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 0.000446895	training's RMSPE: 0.206411	valid_1's rmse: 0.000497302	valid_1's RMSPE: 0.232006
# [200]	training's rmse: 0.00042241	training's RMSPE: 0.195102	valid_1's rmse: 0.000490997	valid_1's RMSPE: 0.229065
# [300]	training's rmse: 0.000408313	training's RMSPE: 0.188591	valid_1's rmse: 0.000488179	valid_1's RMSPE: 0.22775
# [400]	training's rmse: 0.000398417	training's RMSPE: 0.18402	valid_1's rmse: 0.000486413	valid_1's RMSPE: 0.226926
# [500]	training's rmse: 0.000390748	training's RMSPE: 0.180478	valid_1's rmse: 0.000485302	valid_1's RMSPE: 0.226408
# [600]	training's rmse: 0.000384757	training's RMSPE: 0.177711	valid_1's rmse: 0.000484776	valid_1's RMSPE: 0.226162
# [700]	training's rmse: 0.000379624	training's RMSPE: 0.17534	valid_1's rmse: 0.000484531	valid_1's RMSPE: 0.226048
# [800]	training's rmse: 0.000375099	training's RMSPE: 0.17325	valid_1's rmse: 0.000485299	valid_1's RMSPE: 0.226406
# [900]	training's rmse: 0.000371061	training's RMSPE: 0.171385	valid_1's rmse: 0.000485565	valid_1's RMSPE: 0.22653
# [1000]	training's rmse: 0.000367491	training's RMSPE: 0.169736	valid_1's rmse: 0.000485707	valid_1's RMSPE: 0.226597
# Early stopping, best iteration is:
# [672]	training's rmse: 0.000381025	training's RMSPE: 0.175988	valid_1's rmse: 0.000484259	valid_1's RMSPE: 0.225921
# stock_id 3282
# wap1_sum 23
# wap1_std 41
# wap2_sum 19
# wap2_std 42
# log_return1_realized_volatility 189
# log_return2_realized_volatility 100
# wap_balance_sum 26
# wap_balance_amax 14
# wap_balance_amin 28
# wap_balance_std 12
# bid_ask_spread1_sum 105
# bid_ask_spread1_amax 21
# bid_ask_spread1_amin 47
# bid_ask_spread1_std 27
# bid_ask_spread2_sum 27
# bid_ask_spread2_amax 40
# bid_ask_spread2_amin 46
# bid_ask_spread2_std 16
# order_flow_imbalance1_sum 8
# order_flow_imbalance1_amax 30
# order_flow_imbalance1_amin 9
# order_flow_imbalance1_std 11
# order_flow_imbalance2_sum 21
# order_flow_imbalance2_amax 10
# order_flow_imbalance2_amin 11
# order_flow_imbalance2_std 11
# order_book_slope_mean 18
# order_book_slope_amax 9
# depth_imbalance1_sum 9
# depth_imbalance1_amax 11
# depth_imbalance1_std 39
# depth_imbalance2_sum 18
# depth_imbalance2_amax 10
# depth_imbalance2_std 29
# height_imbalance1_sum 85
# height_imbalance1_amax 45
# height_imbalance1_std 28
# height_imbalance2_sum 12
# height_imbalance2_amax 33
# height_imbalance2_std 16
# pressure_imbalance_sum 28
# pressure_imbalance_amax 8
# pressure_imbalance_std 26
# total_volume_sum 22
# seconds_gap_mean 16
# log_return1_realized_volatility_150 452
# log_return2_realized_volatility_150 147
# wap_balance_sum_150 29
# wap_balance_amax_150 20
# wap_balance_amin_150 19
# wap_balance_std_150 20
# bid_ask_spread1_sum_150 12
# bid_ask_spread1_amax_150 13
# bid_ask_spread1_amin_150 29
# bid_ask_spread1_std_150 17
# bid_ask_spread2_sum_150 7
# bid_ask_spread2_amax_150 13
# bid_ask_spread2_amin_150 11
# bid_ask_spread2_std_150 12
# order_flow_imbalance1_sum_150 7
# order_flow_imbalance1_amax_150 13
# order_flow_imbalance1_amin_150 14
# order_flow_imbalance1_std_150 9
# order_flow_imbalance2_sum_150 13
# order_flow_imbalance2_amax_150 6
# order_flow_imbalance2_amin_150 22
# order_flow_imbalance2_std_150 14
# total_volume_sum_150 25
# seconds_gap_mean_150 30
# log_return1_realized_volatility_300 280
# log_return2_realized_volatility_300 87
# wap_balance_sum_300 30
# wap_balance_amax_300 15
# wap_balance_amin_300 12
# wap_balance_std_300 12
# bid_ask_spread1_sum_300 35
# bid_ask_spread1_amax_300 13
# bid_ask_spread1_amin_300 34
# bid_ask_spread1_std_300 12
# bid_ask_spread2_sum_300 13
# bid_ask_spread2_amax_300 30
# bid_ask_spread2_amin_300 16
# bid_ask_spread2_std_300 11
# order_flow_imbalance1_sum_300 2
# order_flow_imbalance1_amax_300 18
# order_flow_imbalance1_amin_300 22
# order_flow_imbalance1_std_300 14
# order_flow_imbalance2_sum_300 13
# order_flow_imbalance2_amax_300 5
# order_flow_imbalance2_amin_300 28
# order_flow_imbalance2_std_300 12
# total_volume_sum_300 16
# seconds_gap_mean_300 26
# log_return1_realized_volatility_450 58
# log_return2_realized_volatility_450 40
# wap_balance_sum_450 19
# wap_balance_amax_450 29
# wap_balance_amin_450 17
# wap_balance_std_450 18
# bid_ask_spread1_sum_450 48
# bid_ask_spread1_amax_450 40
# bid_ask_spread1_amin_450 33
# bid_ask_spread1_std_450 11
# bid_ask_spread2_sum_450 12
# bid_ask_spread2_amax_450 51
# bid_ask_spread2_amin_450 19
# bid_ask_spread2_std_450 26
# order_flow_imbalance1_sum_450 8
# order_flow_imbalance1_amax_450 19
# order_flow_imbalance1_amin_450 19
# order_flow_imbalance1_std_450 9
# order_flow_imbalance2_sum_450 4
# order_flow_imbalance2_amax_450 13
# order_flow_imbalance2_amin_450 13
# order_flow_imbalance2_std_450 17
# total_volume_sum_450 18
# seconds_gap_mean_450 21
# trade_price_log_return_realized_volatility 97
# trade_volumes_sum 38
# trade_volumes_amax 27
# trade_volumes_std 34
# trade_order_count_sum 19
# trade_seconds_gap_mean 42
# trade_price_log_return_realized_volatility_150 22
# trade_volumes_sum_150 6
# trade_volumes_amax_150 13
# trade_volumes_std_150 16
# trade_order_count_sum_150 13
# trade_seconds_gap_mean_150 29
# trade_price_log_return_realized_volatility_300 31
# trade_volumes_sum_300 10
# trade_volumes_amax_300 2
# trade_volumes_std_300 10
# trade_order_count_sum_300 27
# trade_seconds_gap_mean_300 57
# trade_price_log_return_realized_volatility_450 104
# trade_volumes_sum_450 10
# trade_volumes_amax_450 12
# trade_volumes_std_450 1
# trade_order_count_sum_450 68
# trade_seconds_gap_mean_450 41
# trade_tendency 56
# trade_energy 74
# log_return1_realized_volatility_nanmean_stock 44
# log_return1_realized_volatility_150_nanmean_stock 51
# log_return1_realized_volatility_300_nanmean_stock 30
# log_return1_realized_volatility_450_nanmean_stock 44
# log_return1_realized_volatility_nanmean_time 5
# log_return1_realized_volatility_150_nanmean_time 5
# log_return1_realized_volatility_300_nanmean_time 18
# log_return1_realized_volatility_450_nanmean_time 55
# log_return1_realized_volatility_0_cluster_mean 6
# log_return1_realized_volatility_1_cluster_mean 15
# log_return1_realized_volatility_3_cluster_mean 9
# log_return1_realized_volatility_4_cluster_mean 8
# log_return1_realized_volatility_6_cluster_mean 13
# log_return2_realized_volatility_0_cluster_mean 5
# log_return2_realized_volatility_1_cluster_mean 25
# log_return2_realized_volatility_3_cluster_mean 12
# log_return2_realized_volatility_4_cluster_mean 9
# log_return2_realized_volatility_6_cluster_mean 8
# order_flow_imbalance1_sum_0_cluster_mean 24
# order_flow_imbalance1_sum_1_cluster_mean 47
# order_flow_imbalance1_sum_3_cluster_mean 24
# order_flow_imbalance1_sum_4_cluster_mean 40
# order_flow_imbalance1_sum_6_cluster_mean 39
# order_flow_imbalance2_sum_0_cluster_mean 88
# order_flow_imbalance2_sum_1_cluster_mean 33
# order_flow_imbalance2_sum_3_cluster_mean 99
# order_flow_imbalance2_sum_4_cluster_mean 42
# order_flow_imbalance2_sum_6_cluster_mean 35
# order_book_slope_mean_0_cluster_mean 43
# order_book_slope_mean_1_cluster_mean 71
# order_book_slope_mean_3_cluster_mean 40
# order_book_slope_mean_4_cluster_mean 45
# order_book_slope_mean_6_cluster_mean 31
# depth_imbalance1_std_0_cluster_mean 26
# depth_imbalance1_std_1_cluster_mean 50
# depth_imbalance1_std_3_cluster_mean 38
# depth_imbalance1_std_4_cluster_mean 42
# depth_imbalance1_std_6_cluster_mean 53
# depth_imbalance2_std_0_cluster_mean 27
# depth_imbalance2_std_1_cluster_mean 49
# depth_imbalance2_std_3_cluster_mean 64
# depth_imbalance2_std_4_cluster_mean 39
# depth_imbalance2_std_6_cluster_mean 37
# height_imbalance1_sum_0_cluster_mean 15
# height_imbalance1_sum_1_cluster_mean 15
# height_imbalance1_sum_3_cluster_mean 25
# height_imbalance1_sum_4_cluster_mean 6
# height_imbalance1_sum_6_cluster_mean 16
# height_imbalance2_sum_0_cluster_mean 17
# height_imbalance2_sum_1_cluster_mean 8
# height_imbalance2_sum_3_cluster_mean 41
# height_imbalance2_sum_4_cluster_mean 12
# height_imbalance2_sum_6_cluster_mean 16
# pressure_imbalance_std_0_cluster_mean 37
# pressure_imbalance_std_1_cluster_mean 29
# pressure_imbalance_std_3_cluster_mean 41
# pressure_imbalance_std_4_cluster_mean 33
# pressure_imbalance_std_6_cluster_mean 37
# total_volume_sum_0_cluster_mean 68
# total_volume_sum_1_cluster_mean 41
# total_volume_sum_3_cluster_mean 44
# total_volume_sum_4_cluster_mean 54
# total_volume_sum_6_cluster_mean 86
# seconds_gap_mean_0_cluster_mean 44
# seconds_gap_mean_1_cluster_mean 48
# seconds_gap_mean_3_cluster_mean 89
# seconds_gap_mean_4_cluster_mean 22
# seconds_gap_mean_6_cluster_mean 33
# trade_price_log_return_realized_volatility_0_cluster_mean 5
# trade_price_log_return_realized_volatility_1_cluster_mean 15
# trade_price_log_return_realized_volatility_3_cluster_mean 15
# trade_price_log_return_realized_volatility_4_cluster_mean 11
# trade_price_log_return_realized_volatility_6_cluster_mean 12
# trade_volumes_sum_0_cluster_mean 22
# trade_volumes_sum_1_cluster_mean 24
# trade_volumes_sum_3_cluster_mean 37
# trade_volumes_sum_4_cluster_mean 23
# trade_volumes_sum_6_cluster_mean 33
# trade_order_count_sum_0_cluster_mean 29
# trade_order_count_sum_1_cluster_mean 56
# trade_order_count_sum_3_cluster_mean 60
# trade_order_count_sum_4_cluster_mean 24
# trade_order_count_sum_6_cluster_mean 42
# trade_seconds_gap_mean_0_cluster_mean 28
# trade_seconds_gap_mean_1_cluster_mean 26
# trade_seconds_gap_mean_3_cluster_mean 40
# trade_seconds_gap_mean_4_cluster_mean 36
# trade_seconds_gap_mean_6_cluster_mean 32
# trade_tendency_0_cluster_mean 28
# trade_tendency_1_cluster_mean 35
# trade_tendency_3_cluster_mean 49
# trade_tendency_4_cluster_mean 25
# trade_tendency_6_cluster_mean 25
# trade_energy_0_cluster_mean 30
# trade_energy_1_cluster_mean 29
# trade_energy_3_cluster_mean 17
# trade_energy_4_cluster_mean 29
# trade_energy_6_cluster_mean 40
# log_return1_realized_volatility_0_cluster_max 15
# log_return1_realized_volatility_1_cluster_max 25
# log_return1_realized_volatility_3_cluster_max 21
# log_return1_realized_volatility_4_cluster_max 16
# log_return1_realized_volatility_6_cluster_max 21
# log_return2_realized_volatility_0_cluster_max 8
# log_return2_realized_volatility_1_cluster_max 27
# log_return2_realized_volatility_3_cluster_max 12
# log_return2_realized_volatility_4_cluster_max 23
# log_return2_realized_volatility_6_cluster_max 17
# order_flow_imbalance1_sum_0_cluster_max 37
# order_flow_imbalance1_sum_1_cluster_max 34
# order_flow_imbalance1_sum_3_cluster_max 35
# order_flow_imbalance1_sum_4_cluster_max 31
# order_flow_imbalance1_sum_6_cluster_max 51
# order_flow_imbalance2_sum_0_cluster_max 49
# order_flow_imbalance2_sum_1_cluster_max 47
# order_flow_imbalance2_sum_3_cluster_max 34
# order_flow_imbalance2_sum_4_cluster_max 34
# order_flow_imbalance2_sum_6_cluster_max 61
# order_book_slope_mean_0_cluster_max 48
# order_book_slope_mean_1_cluster_max 56
# order_book_slope_mean_3_cluster_max 46
# order_book_slope_mean_4_cluster_max 47
# order_book_slope_mean_6_cluster_max 26
# depth_imbalance1_std_0_cluster_max 23
# depth_imbalance1_std_1_cluster_max 47
# depth_imbalance1_std_3_cluster_max 39
# depth_imbalance1_std_4_cluster_max 25
# depth_imbalance1_std_6_cluster_max 45
# depth_imbalance2_std_0_cluster_max 49
# depth_imbalance2_std_1_cluster_max 57
# depth_imbalance2_std_3_cluster_max 39
# depth_imbalance2_std_4_cluster_max 34
# depth_imbalance2_std_6_cluster_max 34
# height_imbalance1_sum_0_cluster_max 58
# height_imbalance1_sum_1_cluster_max 31
# height_imbalance1_sum_3_cluster_max 61
# height_imbalance1_sum_4_cluster_max 27
# height_imbalance1_sum_6_cluster_max 18
# height_imbalance2_sum_0_cluster_max 81
# height_imbalance2_sum_1_cluster_max 28
# height_imbalance2_sum_3_cluster_max 123
# height_imbalance2_sum_4_cluster_max 29
# height_imbalance2_sum_6_cluster_max 17
# pressure_imbalance_std_0_cluster_max 54
# pressure_imbalance_std_1_cluster_max 41
# pressure_imbalance_std_3_cluster_max 37
# pressure_imbalance_std_4_cluster_max 32
# pressure_imbalance_std_6_cluster_max 24
# total_volume_sum_0_cluster_max 79
# total_volume_sum_1_cluster_max 36
# total_volume_sum_3_cluster_max 57
# total_volume_sum_4_cluster_max 44
# total_volume_sum_6_cluster_max 42
# seconds_gap_mean_0_cluster_max 30
# seconds_gap_mean_1_cluster_max 30
# seconds_gap_mean_3_cluster_max 44
# seconds_gap_mean_4_cluster_max 18
# seconds_gap_mean_6_cluster_max 33
# trade_price_log_return_realized_volatility_0_cluster_max 23
# trade_price_log_return_realized_volatility_1_cluster_max 34
# trade_price_log_return_realized_volatility_3_cluster_max 24
# trade_price_log_return_realized_volatility_4_cluster_max 35
# trade_price_log_return_realized_volatility_6_cluster_max 26
# trade_volumes_sum_0_cluster_max 15
# trade_volumes_sum_1_cluster_max 29
# trade_volumes_sum_3_cluster_max 45
# trade_volumes_sum_4_cluster_max 31
# trade_volumes_sum_6_cluster_max 47
# trade_order_count_sum_0_cluster_max 17
# trade_order_count_sum_1_cluster_max 22
# trade_order_count_sum_3_cluster_max 32
# trade_order_count_sum_4_cluster_max 42
# trade_order_count_sum_6_cluster_max 38
# trade_seconds_gap_mean_0_cluster_max 27
# trade_seconds_gap_mean_1_cluster_max 23
# trade_seconds_gap_mean_3_cluster_max 27
# trade_seconds_gap_mean_4_cluster_max 58
# trade_seconds_gap_mean_6_cluster_max 29
# trade_tendency_0_cluster_max 38
# trade_tendency_1_cluster_max 15
# trade_tendency_3_cluster_max 27
# trade_tendency_4_cluster_max 39
# trade_tendency_6_cluster_max 40
# trade_energy_0_cluster_max 55
# trade_energy_1_cluster_max 37
# trade_energy_3_cluster_max 29
# trade_energy_4_cluster_max 32
# trade_energy_6_cluster_max 41
# log_return1_realized_volatility_0_cluster_min 18
# log_return1_realized_volatility_1_cluster_min 18
# log_return1_realized_volatility_3_cluster_min 37
# log_return1_realized_volatility_4_cluster_min 17
# log_return1_realized_volatility_6_cluster_min 14
# log_return2_realized_volatility_0_cluster_min 20
# log_return2_realized_volatility_1_cluster_min 25
# log_return2_realized_volatility_3_cluster_min 28
# log_return2_realized_volatility_4_cluster_min 18
# log_return2_realized_volatility_6_cluster_min 21
# order_flow_imbalance1_sum_0_cluster_min 29
# order_flow_imbalance1_sum_1_cluster_min 41
# order_flow_imbalance1_sum_3_cluster_min 46
# order_flow_imbalance1_sum_4_cluster_min 31
# order_flow_imbalance1_sum_6_cluster_min 24
# order_flow_imbalance2_sum_0_cluster_min 39
# order_flow_imbalance2_sum_1_cluster_min 35
# order_flow_imbalance2_sum_3_cluster_min 33
# order_flow_imbalance2_sum_4_cluster_min 36
# order_flow_imbalance2_sum_6_cluster_min 49
# order_book_slope_mean_0_cluster_min 38
# order_book_slope_mean_1_cluster_min 36
# order_book_slope_mean_3_cluster_min 55
# order_book_slope_mean_4_cluster_min 47
# order_book_slope_mean_6_cluster_min 30
# depth_imbalance1_std_0_cluster_min 32
# depth_imbalance1_std_1_cluster_min 44
# depth_imbalance1_std_3_cluster_min 35
# depth_imbalance1_std_4_cluster_min 43
# depth_imbalance1_std_6_cluster_min 45
# depth_imbalance2_std_0_cluster_min 47
# depth_imbalance2_std_1_cluster_min 39
# depth_imbalance2_std_3_cluster_min 27
# depth_imbalance2_std_4_cluster_min 38
# depth_imbalance2_std_6_cluster_min 26
# height_imbalance1_sum_0_cluster_min 6
# height_imbalance1_sum_1_cluster_min 18
# height_imbalance1_sum_3_cluster_min 18
# height_imbalance1_sum_4_cluster_min 13
# height_imbalance1_sum_6_cluster_min 24
# height_imbalance2_sum_0_cluster_min 16
# height_imbalance2_sum_1_cluster_min 11
# height_imbalance2_sum_3_cluster_min 58
# height_imbalance2_sum_4_cluster_min 9
# height_imbalance2_sum_6_cluster_min 32
# pressure_imbalance_std_0_cluster_min 59
# pressure_imbalance_std_1_cluster_min 28
# pressure_imbalance_std_3_cluster_min 36
# pressure_imbalance_std_4_cluster_min 46
# pressure_imbalance_std_6_cluster_min 28
# total_volume_sum_0_cluster_min 36
# total_volume_sum_1_cluster_min 26
# total_volume_sum_3_cluster_min 35
# total_volume_sum_4_cluster_min 53
# total_volume_sum_6_cluster_min 30
# seconds_gap_mean_0_cluster_min 8
# seconds_gap_mean_1_cluster_min 43
# seconds_gap_mean_3_cluster_min 6
# seconds_gap_mean_4_cluster_min 29
# seconds_gap_mean_6_cluster_min 35
# trade_price_log_return_realized_volatility_0_cluster_min 41
# trade_price_log_return_realized_volatility_1_cluster_min 14
# trade_price_log_return_realized_volatility_3_cluster_min 22
# trade_price_log_return_realized_volatility_4_cluster_min 15
# trade_price_log_return_realized_volatility_6_cluster_min 13
# trade_volumes_sum_0_cluster_min 32
# trade_volumes_sum_1_cluster_min 37
# trade_volumes_sum_3_cluster_min 44
# trade_volumes_sum_4_cluster_min 29
# trade_volumes_sum_6_cluster_min 44
# trade_order_count_sum_0_cluster_min 40
# trade_order_count_sum_1_cluster_min 48
# trade_order_count_sum_3_cluster_min 39
# trade_order_count_sum_4_cluster_min 31
# trade_order_count_sum_6_cluster_min 27
# trade_seconds_gap_mean_0_cluster_min 49
# trade_seconds_gap_mean_1_cluster_min 42
# trade_seconds_gap_mean_3_cluster_min 72
# trade_seconds_gap_mean_4_cluster_min 18
# trade_seconds_gap_mean_6_cluster_min 20
# trade_tendency_0_cluster_min 24
# trade_tendency_1_cluster_min 37
# trade_tendency_3_cluster_min 42
# trade_tendency_4_cluster_min 36
# trade_tendency_6_cluster_min 15
# trade_energy_0_cluster_min 32
# trade_energy_1_cluster_min 31
# trade_energy_3_cluster_min 49
# trade_energy_4_cluster_min 25
# trade_energy_6_cluster_min 31
# log_return1_realized_volatility_0_cluster_std 29
# log_return1_realized_volatility_1_cluster_std 25
# log_return1_realized_volatility_3_cluster_std 23
# log_return1_realized_volatility_4_cluster_std 34
# log_return1_realized_volatility_6_cluster_std 31
# log_return2_realized_volatility_0_cluster_std 20
# log_return2_realized_volatility_1_cluster_std 32
# log_return2_realized_volatility_3_cluster_std 15
# log_return2_realized_volatility_4_cluster_std 31
# log_return2_realized_volatility_6_cluster_std 16
# order_flow_imbalance1_sum_0_cluster_std 26
# order_flow_imbalance1_sum_1_cluster_std 28
# order_flow_imbalance1_sum_3_cluster_std 36
# order_flow_imbalance1_sum_4_cluster_std 63
# order_flow_imbalance1_sum_6_cluster_std 18
# order_flow_imbalance2_sum_0_cluster_std 60
# order_flow_imbalance2_sum_1_cluster_std 33
# order_flow_imbalance2_sum_3_cluster_std 52
# order_flow_imbalance2_sum_4_cluster_std 24
# order_flow_imbalance2_sum_6_cluster_std 56
# order_book_slope_mean_0_cluster_std 48
# order_book_slope_mean_1_cluster_std 33
# order_book_slope_mean_3_cluster_std 22
# order_book_slope_mean_4_cluster_std 37
# order_book_slope_mean_6_cluster_std 42
# depth_imbalance1_std_0_cluster_std 65
# depth_imbalance1_std_1_cluster_std 28
# depth_imbalance1_std_3_cluster_std 48
# depth_imbalance1_std_4_cluster_std 30
# depth_imbalance1_std_6_cluster_std 31
# depth_imbalance2_std_0_cluster_std 47
# depth_imbalance2_std_1_cluster_std 27
# depth_imbalance2_std_3_cluster_std 30
# depth_imbalance2_std_4_cluster_std 34
# depth_imbalance2_std_6_cluster_std 36
# height_imbalance1_sum_0_cluster_std 6
# height_imbalance1_sum_1_cluster_std 23
# height_imbalance1_sum_3_cluster_std 15
# height_imbalance1_sum_4_cluster_std 6
# height_imbalance1_sum_6_cluster_std 13
# height_imbalance2_sum_0_cluster_std 13
# height_imbalance2_sum_1_cluster_std 17
# height_imbalance2_sum_3_cluster_std 49
# height_imbalance2_sum_4_cluster_std 20
# height_imbalance2_sum_6_cluster_std 52
# pressure_imbalance_std_0_cluster_std 33
# pressure_imbalance_std_1_cluster_std 36
# pressure_imbalance_std_3_cluster_std 26
# pressure_imbalance_std_4_cluster_std 23
# pressure_imbalance_std_6_cluster_std 27
# total_volume_sum_0_cluster_std 44
# total_volume_sum_1_cluster_std 45
# total_volume_sum_3_cluster_std 31
# total_volume_sum_4_cluster_std 46
# total_volume_sum_6_cluster_std 50
# seconds_gap_mean_0_cluster_std 43
# seconds_gap_mean_1_cluster_std 41
# seconds_gap_mean_3_cluster_std 53
# seconds_gap_mean_4_cluster_std 25
# seconds_gap_mean_6_cluster_std 42
# trade_price_log_return_realized_volatility_0_cluster_std 18
# trade_price_log_return_realized_volatility_1_cluster_std 30
# trade_price_log_return_realized_volatility_3_cluster_std 29
# trade_price_log_return_realized_volatility_4_cluster_std 29
# trade_price_log_return_realized_volatility_6_cluster_std 40
# trade_volumes_sum_0_cluster_std 18
# trade_volumes_sum_1_cluster_std 25
# trade_volumes_sum_3_cluster_std 25
# trade_volumes_sum_4_cluster_std 39
# trade_volumes_sum_6_cluster_std 42
# trade_order_count_sum_0_cluster_std 21
# trade_order_count_sum_1_cluster_std 21
# trade_order_count_sum_3_cluster_std 23
# trade_order_count_sum_4_cluster_std 23
# trade_order_count_sum_6_cluster_std 35
# trade_seconds_gap_mean_0_cluster_std 30
# trade_seconds_gap_mean_1_cluster_std 42
# trade_seconds_gap_mean_3_cluster_std 30
# trade_seconds_gap_mean_4_cluster_std 40
# trade_seconds_gap_mean_6_cluster_std 33
# trade_tendency_0_cluster_std 54
# trade_tendency_1_cluster_std 34
# trade_tendency_3_cluster_std 41
# trade_tendency_4_cluster_std 42
# trade_tendency_6_cluster_std 30
# trade_energy_0_cluster_std 35
# trade_energy_1_cluster_std 36
# trade_energy_3_cluster_std 58
# trade_energy_4_cluster_std 42
# trade_energy_6_cluster_std 28
# Training fold 3
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 0.000449971	training's RMSPE: 0.207962	valid_1's rmse: 0.000466908	valid_1's RMSPE: 0.217293
# [200]	training's rmse: 0.000424701	training's RMSPE: 0.196283	valid_1's rmse: 0.000464072	valid_1's RMSPE: 0.215973
# [300]	training's rmse: 0.000410072	training's RMSPE: 0.189522	valid_1's rmse: 0.00046279	valid_1's RMSPE: 0.215376
# [400]	training's rmse: 0.000400202	training's RMSPE: 0.18496	valid_1's rmse: 0.000462654	valid_1's RMSPE: 0.215313
# [500]	training's rmse: 0.000392784	training's RMSPE: 0.181532	valid_1's rmse: 0.000462499	valid_1's RMSPE: 0.215241
# [600]	training's rmse: 0.00038663	training's RMSPE: 0.178687	valid_1's rmse: 0.000462244	valid_1's RMSPE: 0.215122
# [700]	training's rmse: 0.000381369	training's RMSPE: 0.176256	valid_1's rmse: 0.000462738	valid_1's RMSPE: 0.215352
# [800]	training's rmse: 0.000376927	training's RMSPE: 0.174203	valid_1's rmse: 0.000463142	valid_1's RMSPE: 0.21554
# [900]	training's rmse: 0.000372907	training's RMSPE: 0.172345	valid_1's rmse: 0.000463932	valid_1's RMSPE: 0.215908
# Early stopping, best iteration is:
# [579]	training's rmse: 0.000387877	training's RMSPE: 0.179264	valid_1's rmse: 0.000462093	valid_1's RMSPE: 0.215052
# stock_id 2894
# wap1_sum 18
# wap1_std 44
# wap2_sum 8
# wap2_std 40
# log_return1_realized_volatility 190
# log_return2_realized_volatility 90
# wap_balance_sum 19
# wap_balance_amax 14
# wap_balance_amin 7
# wap_balance_std 17
# bid_ask_spread1_sum 89
# bid_ask_spread1_amax 13
# bid_ask_spread1_amin 35
# bid_ask_spread1_std 34
# bid_ask_spread2_sum 20
# bid_ask_spread2_amax 40
# bid_ask_spread2_amin 28
# bid_ask_spread2_std 16
# order_flow_imbalance1_sum 10
# order_flow_imbalance1_amax 25
# order_flow_imbalance1_amin 8
# order_flow_imbalance1_std 10
# order_flow_imbalance2_sum 25
# order_flow_imbalance2_amax 3
# order_flow_imbalance2_amin 12
# order_flow_imbalance2_std 16
# order_book_slope_mean 6
# order_book_slope_amax 2
# depth_imbalance1_sum 7
# depth_imbalance1_amax 4
# depth_imbalance1_std 32
# depth_imbalance2_sum 5
# depth_imbalance2_amax 11
# depth_imbalance2_std 18
# height_imbalance1_sum 73
# height_imbalance1_amax 34
# height_imbalance1_std 16
# height_imbalance2_sum 23
# height_imbalance2_amax 33
# height_imbalance2_std 13
# pressure_imbalance_sum 22
# pressure_imbalance_amax 8
# pressure_imbalance_std 23
# total_volume_sum 28
# seconds_gap_mean 12
# log_return1_realized_volatility_150 424
# log_return2_realized_volatility_150 138
# wap_balance_sum_150 15
# wap_balance_amax_150 13
# wap_balance_amin_150 11
# wap_balance_std_150 15
# bid_ask_spread1_sum_150 17
# bid_ask_spread1_amax_150 19
# bid_ask_spread1_amin_150 26
# bid_ask_spread1_std_150 23
# bid_ask_spread2_sum_150 8
# bid_ask_spread2_amax_150 12
# bid_ask_spread2_amin_150 15
# bid_ask_spread2_std_150 8
# order_flow_imbalance1_sum_150 8
# order_flow_imbalance1_amax_150 15
# order_flow_imbalance1_amin_150 7
# order_flow_imbalance1_std_150 14
# order_flow_imbalance2_sum_150 7
# order_flow_imbalance2_amax_150 6
# order_flow_imbalance2_amin_150 9
# order_flow_imbalance2_std_150 9
# total_volume_sum_150 22
# seconds_gap_mean_150 26
# log_return1_realized_volatility_300 271
# log_return2_realized_volatility_300 73
# wap_balance_sum_300 32
# wap_balance_amax_300 11
# wap_balance_amin_300 11
# wap_balance_std_300 16
# bid_ask_spread1_sum_300 23
# bid_ask_spread1_amax_300 13
# bid_ask_spread1_amin_300 29
# bid_ask_spread1_std_300 11
# bid_ask_spread2_sum_300 17
# bid_ask_spread2_amax_300 25
# bid_ask_spread2_amin_300 9
# bid_ask_spread2_std_300 3
# order_flow_imbalance1_sum_300 4
# order_flow_imbalance1_amax_300 17
# order_flow_imbalance1_amin_300 7
# order_flow_imbalance1_std_300 9
# order_flow_imbalance2_sum_300 23
# order_flow_imbalance2_amax_300 8
# order_flow_imbalance2_amin_300 12
# order_flow_imbalance2_std_300 9
# total_volume_sum_300 17
# seconds_gap_mean_300 14
# log_return1_realized_volatility_450 60
# log_return2_realized_volatility_450 39
# wap_balance_sum_450 27
# wap_balance_amax_450 16
# wap_balance_amin_450 9
# wap_balance_std_450 13
# bid_ask_spread1_sum_450 51
# bid_ask_spread1_amax_450 41
# bid_ask_spread1_amin_450 34
# bid_ask_spread1_std_450 12
# bid_ask_spread2_sum_450 16
# bid_ask_spread2_amax_450 35
# bid_ask_spread2_amin_450 13
# bid_ask_spread2_std_450 24
# order_flow_imbalance1_sum_450 5
# order_flow_imbalance1_amax_450 15
# order_flow_imbalance1_amin_450 14
# order_flow_imbalance1_std_450 5
# order_flow_imbalance2_sum_450 4
# order_flow_imbalance2_amax_450 8
# order_flow_imbalance2_amin_450 8
# order_flow_imbalance2_std_450 7
# total_volume_sum_450 8
# seconds_gap_mean_450 13
# trade_price_log_return_realized_volatility 90
# trade_volumes_sum 23
# trade_volumes_amax 17
# trade_volumes_std 37
# trade_order_count_sum 10
# trade_seconds_gap_mean 21
# trade_price_log_return_realized_volatility_150 16
# trade_volumes_sum_150 10
# trade_volumes_amax_150 12
# trade_volumes_std_150 10
# trade_order_count_sum_150 5
# trade_seconds_gap_mean_150 33
# trade_price_log_return_realized_volatility_300 31
# trade_volumes_sum_300 7
# trade_volumes_amax_300 5
# trade_volumes_std_300 8
# trade_order_count_sum_300 16
# trade_seconds_gap_mean_300 37
# trade_price_log_return_realized_volatility_450 88
# trade_volumes_sum_450 11
# trade_volumes_amax_450 4
# trade_volumes_std_450 4
# trade_order_count_sum_450 52
# trade_seconds_gap_mean_450 50
# trade_tendency 44
# trade_energy 68
# log_return1_realized_volatility_nanmean_stock 47
# log_return1_realized_volatility_150_nanmean_stock 51
# log_return1_realized_volatility_300_nanmean_stock 20
# log_return1_realized_volatility_450_nanmean_stock 52
# log_return1_realized_volatility_nanmean_time 2
# log_return1_realized_volatility_150_nanmean_time 3
# log_return1_realized_volatility_300_nanmean_time 8
# log_return1_realized_volatility_450_nanmean_time 49
# log_return1_realized_volatility_0_cluster_mean 7
# log_return1_realized_volatility_1_cluster_mean 22
# log_return1_realized_volatility_3_cluster_mean 7
# log_return1_realized_volatility_4_cluster_mean 8
# log_return1_realized_volatility_6_cluster_mean 5
# log_return2_realized_volatility_0_cluster_mean 4
# log_return2_realized_volatility_1_cluster_mean 15
# log_return2_realized_volatility_3_cluster_mean 16
# log_return2_realized_volatility_4_cluster_mean 6
# log_return2_realized_volatility_6_cluster_mean 8
# order_flow_imbalance1_sum_0_cluster_mean 21
# order_flow_imbalance1_sum_1_cluster_mean 37
# order_flow_imbalance1_sum_3_cluster_mean 17
# order_flow_imbalance1_sum_4_cluster_mean 41
# order_flow_imbalance1_sum_6_cluster_mean 22
# order_flow_imbalance2_sum_0_cluster_mean 59
# order_flow_imbalance2_sum_1_cluster_mean 26
# order_flow_imbalance2_sum_3_cluster_mean 105
# order_flow_imbalance2_sum_4_cluster_mean 53
# order_flow_imbalance2_sum_6_cluster_mean 20
# order_book_slope_mean_0_cluster_mean 28
# order_book_slope_mean_1_cluster_mean 44
# order_book_slope_mean_3_cluster_mean 37
# order_book_slope_mean_4_cluster_mean 29
# order_book_slope_mean_6_cluster_mean 37
# depth_imbalance1_std_0_cluster_mean 22
# depth_imbalance1_std_1_cluster_mean 27
# depth_imbalance1_std_3_cluster_mean 29
# depth_imbalance1_std_4_cluster_mean 34
# depth_imbalance1_std_6_cluster_mean 29
# ...
# order_flow_imbalance1_amax_450 18
# order_flow_imbalance1_amin_450 28
# order_flow_imbalance1_std_450 15
# order_flow_imbalance2_sum_450 6
# order_flow_imbalance2_amax_450 9
# order_flow_imbalance2_amin_450 20
# order_flow_imbalance2_std_450 16
# total_volume_sum_450 9
# seconds_gap_mean_450 29
# trade_price_log_return_realized_volatility 101
# trade_volumes_sum 18
# trade_volumes_amax 21
# trade_volumes_std 45
# trade_order_count_sum 15
# trade_seconds_gap_mean 35
# trade_price_log_return_realized_volatility_150 26
# trade_volumes_sum_150 16
# trade_volumes_amax_150 14
# trade_volumes_std_150 20
# trade_order_count_sum_150 14
# trade_seconds_gap_mean_150 46
# trade_price_log_return_realized_volatility_300 36
# trade_volumes_sum_300 9
# trade_volumes_amax_300 13
# trade_volumes_std_300 15
# trade_order_count_sum_300 32
# trade_seconds_gap_mean_300 47
# trade_price_log_return_realized_volatility_450 91
# trade_volumes_sum_450 8
# trade_volumes_amax_450 12
# trade_volumes_std_450 7
# trade_order_count_sum_450 76
# trade_seconds_gap_mean_450 60
# trade_tendency 66
# trade_energy 86
# log_return1_realized_volatility_nanmean_stock 67
# log_return1_realized_volatility_150_nanmean_stock 45
# log_return1_realized_volatility_300_nanmean_stock 30
# log_return1_realized_volatility_450_nanmean_stock 50
# log_return1_realized_volatility_nanmean_time 7
# log_return1_realized_volatility_150_nanmean_time 2
# log_return1_realized_volatility_300_nanmean_time 10
# log_return1_realized_volatility_450_nanmean_time 46
# log_return1_realized_volatility_0_cluster_mean 9
# log_return1_realized_volatility_1_cluster_mean 23
# log_return1_realized_volatility_3_cluster_mean 7
# log_return1_realized_volatility_4_cluster_mean 1
# log_return1_realized_volatility_6_cluster_mean 14
# log_return2_realized_volatility_0_cluster_mean 6
# log_return2_realized_volatility_1_cluster_mean 24
# log_return2_realized_volatility_3_cluster_mean 13
# log_return2_realized_volatility_4_cluster_mean 9
# log_return2_realized_volatility_6_cluster_mean 9
# order_flow_imbalance1_sum_0_cluster_mean 31
# order_flow_imbalance1_sum_1_cluster_mean 40
# order_flow_imbalance1_sum_3_cluster_mean 21
# order_flow_imbalance1_sum_4_cluster_mean 45
# order_flow_imbalance1_sum_6_cluster_mean 27
# order_flow_imbalance2_sum_0_cluster_mean 72
# order_flow_imbalance2_sum_1_cluster_mean 37
# order_flow_imbalance2_sum_3_cluster_mean 120
# order_flow_imbalance2_sum_4_cluster_mean 42
# order_flow_imbalance2_sum_6_cluster_mean 24
# order_book_slope_mean_0_cluster_mean 47
# order_book_slope_mean_1_cluster_mean 69
# order_book_slope_mean_3_cluster_mean 40
# order_book_slope_mean_4_cluster_mean 34
# order_book_slope_mean_6_cluster_mean 28
# depth_imbalance1_std_0_cluster_mean 28
# depth_imbalance1_std_1_cluster_mean 47
# depth_imbalance1_std_3_cluster_mean 35
# depth_imbalance1_std_4_cluster_mean 41
# depth_imbalance1_std_6_cluster_mean 41
# depth_imbalance2_std_0_cluster_mean 53
# depth_imbalance2_std_1_cluster_mean 50
# depth_imbalance2_std_3_cluster_mean 66
# depth_imbalance2_std_4_cluster_mean 55
# depth_imbalance2_std_6_cluster_mean 43
# height_imbalance1_sum_0_cluster_mean 18
# height_imbalance1_sum_1_cluster_mean 12
# height_imbalance1_sum_3_cluster_mean 22
# height_imbalance1_sum_4_cluster_mean 15
# height_imbalance1_sum_6_cluster_mean 24
# height_imbalance2_sum_0_cluster_mean 12
# height_imbalance2_sum_1_cluster_mean 13
# height_imbalance2_sum_3_cluster_mean 23
# height_imbalance2_sum_4_cluster_mean 9
# height_imbalance2_sum_6_cluster_mean 19
# pressure_imbalance_std_0_cluster_mean 34
# pressure_imbalance_std_1_cluster_mean 43
# pressure_imbalance_std_3_cluster_mean 60
# pressure_imbalance_std_4_cluster_mean 40
# pressure_imbalance_std_6_cluster_mean 45
# total_volume_sum_0_cluster_mean 59
# total_volume_sum_1_cluster_mean 31
# total_volume_sum_3_cluster_mean 41
# total_volume_sum_4_cluster_mean 45
# total_volume_sum_6_cluster_mean 114
# seconds_gap_mean_0_cluster_mean 37
# seconds_gap_mean_1_cluster_mean 37
# seconds_gap_mean_3_cluster_mean 88
# seconds_gap_mean_4_cluster_mean 25
# seconds_gap_mean_6_cluster_mean 40
# trade_price_log_return_realized_volatility_0_cluster_mean 14
# trade_price_log_return_realized_volatility_1_cluster_mean 22
# trade_price_log_return_realized_volatility_3_cluster_mean 20
# trade_price_log_return_realized_volatility_4_cluster_mean 7
# trade_price_log_return_realized_volatility_6_cluster_mean 13
# trade_volumes_sum_0_cluster_mean 29
# trade_volumes_sum_1_cluster_mean 19
# trade_volumes_sum_3_cluster_mean 25
# trade_volumes_sum_4_cluster_mean 28
# trade_volumes_sum_6_cluster_mean 32
# trade_order_count_sum_0_cluster_mean 31
# trade_order_count_sum_1_cluster_mean 53
# trade_order_count_sum_3_cluster_mean 75
# trade_order_count_sum_4_cluster_mean 38
# trade_order_count_sum_6_cluster_mean 41
# trade_seconds_gap_mean_0_cluster_mean 31
# trade_seconds_gap_mean_1_cluster_mean 36
# trade_seconds_gap_mean_3_cluster_mean 47
# trade_seconds_gap_mean_4_cluster_mean 33
# trade_seconds_gap_mean_6_cluster_mean 26
# trade_tendency_0_cluster_mean 35
# trade_tendency_1_cluster_mean 30
# trade_tendency_3_cluster_mean 63
# trade_tendency_4_cluster_mean 18
# trade_tendency_6_cluster_mean 16
# trade_energy_0_cluster_mean 29
# trade_energy_1_cluster_mean 30
# trade_energy_3_cluster_mean 25
# trade_energy_4_cluster_mean 36
# trade_energy_6_cluster_mean 42
# log_return1_realized_volatility_0_cluster_max 11
# log_return1_realized_volatility_1_cluster_max 28
# log_return1_realized_volatility_3_cluster_max 20
# log_return1_realized_volatility_4_cluster_max 13
# log_return1_realized_volatility_6_cluster_max 26
# log_return2_realized_volatility_0_cluster_max 18
# log_return2_realized_volatility_1_cluster_max 20
# log_return2_realized_volatility_3_cluster_max 14
# log_return2_realized_volatility_4_cluster_max 21
# log_return2_realized_volatility_6_cluster_max 27
# order_flow_imbalance1_sum_0_cluster_max 50
# order_flow_imbalance1_sum_1_cluster_max 28
# order_flow_imbalance1_sum_3_cluster_max 45
# order_flow_imbalance1_sum_4_cluster_max 37
# order_flow_imbalance1_sum_6_cluster_max 64
# order_flow_imbalance2_sum_0_cluster_max 51
# order_flow_imbalance2_sum_1_cluster_max 47
# order_flow_imbalance2_sum_3_cluster_max 46
# order_flow_imbalance2_sum_4_cluster_max 43
# order_flow_imbalance2_sum_6_cluster_max 68
# order_book_slope_mean_0_cluster_max 24
# order_book_slope_mean_1_cluster_max 54
# order_book_slope_mean_3_cluster_max 49
# order_book_slope_mean_4_cluster_max 51
# order_book_slope_mean_6_cluster_max 54
# depth_imbalance1_std_0_cluster_max 38
# depth_imbalance1_std_1_cluster_max 37
# depth_imbalance1_std_3_cluster_max 40
# depth_imbalance1_std_4_cluster_max 31
# depth_imbalance1_std_6_cluster_max 58
# depth_imbalance2_std_0_cluster_max 49
# depth_imbalance2_std_1_cluster_max 49
# depth_imbalance2_std_3_cluster_max 43
# depth_imbalance2_std_4_cluster_max 40
# depth_imbalance2_std_6_cluster_max 56
# height_imbalance1_sum_0_cluster_max 90
# height_imbalance1_sum_1_cluster_max 27
# height_imbalance1_sum_3_cluster_max 69
# height_imbalance1_sum_4_cluster_max 37
# height_imbalance1_sum_6_cluster_max 33
# height_imbalance2_sum_0_cluster_max 89
# height_imbalance2_sum_1_cluster_max 29
# height_imbalance2_sum_3_cluster_max 119
# height_imbalance2_sum_4_cluster_max 32
# height_imbalance2_sum_6_cluster_max 27
# pressure_imbalance_std_0_cluster_max 50
# pressure_imbalance_std_1_cluster_max 39
# pressure_imbalance_std_3_cluster_max 55
# pressure_imbalance_std_4_cluster_max 38
# pressure_imbalance_std_6_cluster_max 28
# total_volume_sum_0_cluster_max 88
# total_volume_sum_1_cluster_max 41
# total_volume_sum_3_cluster_max 67
# total_volume_sum_4_cluster_max 53
# total_volume_sum_6_cluster_max 61
# seconds_gap_mean_0_cluster_max 48
# seconds_gap_mean_1_cluster_max 34
# seconds_gap_mean_3_cluster_max 52
# seconds_gap_mean_4_cluster_max 43
# seconds_gap_mean_6_cluster_max 29
# trade_price_log_return_realized_volatility_0_cluster_max 13
# trade_price_log_return_realized_volatility_1_cluster_max 23
# trade_price_log_return_realized_volatility_3_cluster_max 18
# trade_price_log_return_realized_volatility_4_cluster_max 17
# trade_price_log_return_realized_volatility_6_cluster_max 23
# trade_volumes_sum_0_cluster_max 27
# trade_volumes_sum_1_cluster_max 36
# trade_volumes_sum_3_cluster_max 48
# trade_volumes_sum_4_cluster_max 40
# trade_volumes_sum_6_cluster_max 35
# trade_order_count_sum_0_cluster_max 24
# trade_order_count_sum_1_cluster_max 31
# trade_order_count_sum_3_cluster_max 28
# trade_order_count_sum_4_cluster_max 40
# trade_order_count_sum_6_cluster_max 37
# trade_seconds_gap_mean_0_cluster_max 48
# trade_seconds_gap_mean_1_cluster_max 44
# trade_seconds_gap_mean_3_cluster_max 35
# trade_seconds_gap_mean_4_cluster_max 84
# trade_seconds_gap_mean_6_cluster_max 40
# trade_tendency_0_cluster_max 46
# trade_tendency_1_cluster_max 31
# trade_tendency_3_cluster_max 24
# trade_tendency_4_cluster_max 36
# trade_tendency_6_cluster_max 47
# trade_energy_0_cluster_max 41
# trade_energy_1_cluster_max 28
# trade_energy_3_cluster_max 32
# trade_energy_4_cluster_max 53
# trade_energy_6_cluster_max 47
# log_return1_realized_volatility_0_cluster_min 26
# log_return1_realized_volatility_1_cluster_min 22
# log_return1_realized_volatility_3_cluster_min 30
# log_return1_realized_volatility_4_cluster_min 26
# log_return1_realized_volatility_6_cluster_min 17
# log_return2_realized_volatility_0_cluster_min 25
# log_return2_realized_volatility_1_cluster_min 21
# log_return2_realized_volatility_3_cluster_min 42
# log_return2_realized_volatility_4_cluster_min 13
# log_return2_realized_volatility_6_cluster_min 20
# order_flow_imbalance1_sum_0_cluster_min 43
# order_flow_imbalance1_sum_1_cluster_min 36
# order_flow_imbalance1_sum_3_cluster_min 42
# order_flow_imbalance1_sum_4_cluster_min 36
# order_flow_imbalance1_sum_6_cluster_min 30
# order_flow_imbalance2_sum_0_cluster_min 34
# order_flow_imbalance2_sum_1_cluster_min 54
# order_flow_imbalance2_sum_3_cluster_min 45
# order_flow_imbalance2_sum_4_cluster_min 58
# order_flow_imbalance2_sum_6_cluster_min 40
# order_book_slope_mean_0_cluster_min 57
# order_book_slope_mean_1_cluster_min 45
# order_book_slope_mean_3_cluster_min 70
# order_book_slope_mean_4_cluster_min 64
# order_book_slope_mean_6_cluster_min 48
# depth_imbalance1_std_0_cluster_min 36
# depth_imbalance1_std_1_cluster_min 36
# depth_imbalance1_std_3_cluster_min 33
# depth_imbalance1_std_4_cluster_min 26
# depth_imbalance1_std_6_cluster_min 47
# depth_imbalance2_std_0_cluster_min 57
# depth_imbalance2_std_1_cluster_min 45
# depth_imbalance2_std_3_cluster_min 49
# depth_imbalance2_std_4_cluster_min 58
# depth_imbalance2_std_6_cluster_min 35
# height_imbalance1_sum_0_cluster_min 13
# height_imbalance1_sum_1_cluster_min 19
# height_imbalance1_sum_3_cluster_min 24
# height_imbalance1_sum_4_cluster_min 10
# height_imbalance1_sum_6_cluster_min 31
# height_imbalance2_sum_0_cluster_min 18
# height_imbalance2_sum_1_cluster_min 16
# height_imbalance2_sum_3_cluster_min 61
# height_imbalance2_sum_4_cluster_min 12
# height_imbalance2_sum_6_cluster_min 42
# pressure_imbalance_std_0_cluster_min 58
# pressure_imbalance_std_1_cluster_min 22
# pressure_imbalance_std_3_cluster_min 44
# pressure_imbalance_std_4_cluster_min 67
# pressure_imbalance_std_6_cluster_min 22
# total_volume_sum_0_cluster_min 72
# total_volume_sum_1_cluster_min 50
# total_volume_sum_3_cluster_min 33
# total_volume_sum_4_cluster_min 60
# total_volume_sum_6_cluster_min 34
# seconds_gap_mean_0_cluster_min 3
# seconds_gap_mean_1_cluster_min 41
# seconds_gap_mean_3_cluster_min 4
# seconds_gap_mean_4_cluster_min 39
# seconds_gap_mean_6_cluster_min 34
# trade_price_log_return_realized_volatility_0_cluster_min 22
# trade_price_log_return_realized_volatility_1_cluster_min 20
# trade_price_log_return_realized_volatility_3_cluster_min 30
# trade_price_log_return_realized_volatility_4_cluster_min 17
# trade_price_log_return_realized_volatility_6_cluster_min 26
# trade_volumes_sum_0_cluster_min 36
# trade_volumes_sum_1_cluster_min 32
# trade_volumes_sum_3_cluster_min 39
# trade_volumes_sum_4_cluster_min 39
# trade_volumes_sum_6_cluster_min 39
# trade_order_count_sum_0_cluster_min 39
# trade_order_count_sum_1_cluster_min 47
# trade_order_count_sum_3_cluster_min 43
# trade_order_count_sum_4_cluster_min 45
# trade_order_count_sum_6_cluster_min 46
# trade_seconds_gap_mean_0_cluster_min 46
# trade_seconds_gap_mean_1_cluster_min 43
# trade_seconds_gap_mean_3_cluster_min 77
# trade_seconds_gap_mean_4_cluster_min 15
# trade_seconds_gap_mean_6_cluster_min 29
# trade_tendency_0_cluster_min 40
# trade_tendency_1_cluster_min 35
# trade_tendency_3_cluster_min 56
# trade_tendency_4_cluster_min 46
# trade_tendency_6_cluster_min 15
# trade_energy_0_cluster_min 39
# trade_energy_1_cluster_min 57
# trade_energy_3_cluster_min 43
# trade_energy_4_cluster_min 34
# trade_energy_6_cluster_min 45
# log_return1_realized_volatility_0_cluster_std 17
# log_return1_realized_volatility_1_cluster_std 20
# log_return1_realized_volatility_3_cluster_std 25
# log_return1_realized_volatility_4_cluster_std 26
# log_return1_realized_volatility_6_cluster_std 32
# log_return2_realized_volatility_0_cluster_std 9
# log_return2_realized_volatility_1_cluster_std 26
# log_return2_realized_volatility_3_cluster_std 14
# log_return2_realized_volatility_4_cluster_std 24
# log_return2_realized_volatility_6_cluster_std 21
# order_flow_imbalance1_sum_0_cluster_std 39
# order_flow_imbalance1_sum_1_cluster_std 28
# order_flow_imbalance1_sum_3_cluster_std 44
# order_flow_imbalance1_sum_4_cluster_std 71
# order_flow_imbalance1_sum_6_cluster_std 50
# order_flow_imbalance2_sum_0_cluster_std 47
# order_flow_imbalance2_sum_1_cluster_std 31
# order_flow_imbalance2_sum_3_cluster_std 39
# order_flow_imbalance2_sum_4_cluster_std 28
# order_flow_imbalance2_sum_6_cluster_std 78
# order_book_slope_mean_0_cluster_std 45
# order_book_slope_mean_1_cluster_std 40
# order_book_slope_mean_3_cluster_std 42
# order_book_slope_mean_4_cluster_std 41
# order_book_slope_mean_6_cluster_std 39
# depth_imbalance1_std_0_cluster_std 102
# depth_imbalance1_std_1_cluster_std 37
# depth_imbalance1_std_3_cluster_std 47
# depth_imbalance1_std_4_cluster_std 40
# depth_imbalance1_std_6_cluster_std 43
# depth_imbalance2_std_0_cluster_std 45
# depth_imbalance2_std_1_cluster_std 37
# depth_imbalance2_std_3_cluster_std 30
# depth_imbalance2_std_4_cluster_std 44
# depth_imbalance2_std_6_cluster_std 53
# height_imbalance1_sum_0_cluster_std 13
# height_imbalance1_sum_1_cluster_std 18
# height_imbalance1_sum_3_cluster_std 16
# height_imbalance1_sum_4_cluster_std 11
# height_imbalance1_sum_6_cluster_std 20
# height_imbalance2_sum_0_cluster_std 11
# height_imbalance2_sum_1_cluster_std 32
# height_imbalance2_sum_3_cluster_std 55
# height_imbalance2_sum_4_cluster_std 20
# height_imbalance2_sum_6_cluster_std 45
# pressure_imbalance_std_0_cluster_std 20
# pressure_imbalance_std_1_cluster_std 43
# pressure_imbalance_std_3_cluster_std 28
# pressure_imbalance_std_4_cluster_std 43
# pressure_imbalance_std_6_cluster_std 19
# total_volume_sum_0_cluster_std 41
# total_volume_sum_1_cluster_std 38
# total_volume_sum_3_cluster_std 31
# total_volume_sum_4_cluster_std 38
# total_volume_sum_6_cluster_std 52
# seconds_gap_mean_0_cluster_std 45
# seconds_gap_mean_1_cluster_std 32
# seconds_gap_mean_3_cluster_std 63
# seconds_gap_mean_4_cluster_std 20
# seconds_gap_mean_6_cluster_std 35
# trade_price_log_return_realized_volatility_0_cluster_std 17
# trade_price_log_return_realized_volatility_1_cluster_std 35
# trade_price_log_return_realized_volatility_3_cluster_std 19
# trade_price_log_return_realized_volatility_4_cluster_std 29
# trade_price_log_return_realized_volatility_6_cluster_std 38
# trade_volumes_sum_0_cluster_std 35
# trade_volumes_sum_1_cluster_std 39
# trade_volumes_sum_3_cluster_std 32
# trade_volumes_sum_4_cluster_std 42
# trade_volumes_sum_6_cluster_std 37
# trade_order_count_sum_0_cluster_std 15
# trade_order_count_sum_1_cluster_std 33
# trade_order_count_sum_3_cluster_std 32
# trade_order_count_sum_4_cluster_std 42
# trade_order_count_sum_6_cluster_std 34
# trade_seconds_gap_mean_0_cluster_std 56
# trade_seconds_gap_mean_1_cluster_std 33
# trade_seconds_gap_mean_3_cluster_std 38
# trade_seconds_gap_mean_4_cluster_std 37
# trade_seconds_gap_mean_6_cluster_std 36
# trade_tendency_0_cluster_std 65
# trade_tendency_1_cluster_std 63
# trade_tendency_3_cluster_std 31
# trade_tendency_4_cluster_std 59
# trade_tendency_6_cluster_std 51
# trade_energy_0_cluster_std 61
# trade_energy_1_cluster_std 34
# trade_energy_3_cluster_std 34
# trade_energy_4_cluster_std 35
# trade_energy_6_cluster_std 39
# Our out of folds RMSPE is 0.21608988632815976

# %%
# GroupKfold Our out of folds RMSPE is 0.215819325606304
